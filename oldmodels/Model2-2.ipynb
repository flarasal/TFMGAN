# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import time

# Definir el generador y el discriminador
class Generator(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(Generator, self).__init__()
        self.net = nn.Sequential(
            #nn.Linear(input_dim, 128),
            #nn.ReLU(),
            #nn.Linear(128, 256),
            #nn.ReLU(),
            #nn.Linear(256, output_dim),
            #nn.Tanh()
                    
            nn.Linear(input_dim, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            
            nn.Linear(512, 768),
            nn.BatchNorm1d(768),
            nn.ReLU(),
            
            nn.Linear(768, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),

            nn.Linear(1024, 768),
            nn.BatchNorm1d(768),
            nn.ReLU(),
            
            nn.Linear(768, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            
            nn.Linear(512, output_dim),
            nn.Sigmoid()
        )
        
    def forward(self, x):
        return self.net(x)

class Discriminator(nn.Module):
    def __init__(self, input_dim):
        super(Discriminator, self).__init__()
        self.net = nn.Sequential(
            #nn.Linear(input_dim, 256),
            #nn.LeakyReLU(0.2),
            #nn.Linear(256, 256),
            #nn.LeakyReLU(0.2),
            #nn.Linear(256, 128),
            #nn.LeakyReLU(0.2),
            #nn.Linear(128, 1),
            #nn.Sigmoid()
            
            nn.Linear(input_dim, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.3),
        
            #nn.Linear(256, 128),
            #nn.BatchNorm1d(128),
            #nn.ReLU(),
            #nn.Dropout(0.3),
            
            #nn.Linear(128, 64),
            #nn.BatchNorm1d(64),
            #nn.ReLU(),
            #nn.Dropout(0.3),
    
            nn.Linear(256, 1),
            nn.Sigmoid(),
        )
        
    def forward(self, x):
        return self.net(x)
        
# Leer datos
expression_data = pd.read_csv('exprLOW.csv')
methylation_data = pd.read_csv('methylLOW.csv')
assign_data = pd.read_csv('assignLOW.csv')

expression_data = expression_data.iloc[:, 1:]
methylation_data = methylation_data.iloc[:, 1:]
assign_data = assign_data.iloc[:, 2:]

# Convertir todas las columnas a tipo float
expression_data = expression_data.apply(pd.to_numeric, errors='coerce')
methylation_data = methylation_data.apply(pd.to_numeric, errors='coerce')
assign_data = assign_data.apply(pd.to_numeric, errors='coerce')
# Lidiar con valores NaN (si los hay). Pone 0(CAMBIAR)
expression_data.fillna(0, inplace=True)
methylation_data.fillna(0, inplace=True)
assign_data.fillna(0, inplace=True)

expression_data = expression_data.values
methylation_data = methylation_data.values
assign_data=assign_data.values
# Asegurar que tienes el mismo número de muestras en ambos conjuntos de datos


assert expression_data.shape[0] == methylation_data.shape[0], "Los datos de expresión y metilación deben tener el mismo número de muestras."
assert assign_data.shape[0] == methylation_data.shape[0], "Los datos de asignación y metilación deben tener el mismo número de muestras."

# Concatenar los datos
#combined_data =torch.FloatTensor(np.hstack((expression_data, methylation_data,assign_data)))
print(torch.cuda.is_available())
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device="cpu"
expression_data = torch.FloatTensor(expression_data).to(device)
methylation_data = torch.FloatTensor(methylation_data).to(device)
assign_data = torch.FloatTensor(assign_data).to(device)
combined_data = torch.cat((expression_data,methylation_data,assign_data), 1).to(device)
# Out:
# True

# %%
# Modelos y optimizadores
gen = Generator(100, methylation_data.shape[1]+assign_data.shape[1]).to(device)
disc = Discriminator(expression_data.shape[1] + methylation_data.shape[1]+assign_data.shape[1]).to(device)
gen_optimizer = optim.Adam(gen.parameters(), lr=0.0002)
disc_optimizer = optim.Adam(disc.parameters(), lr=0.0002)
criterion = nn.BCELoss()

# Entrenamiento
n_samples = combined_data.size(0)
batch_size = 64
n_epochs = 10000
start_time = time.time()
for epoch in range(n_epochs):
    for idx in range(0, n_samples, batch_size):
        real_data = combined_data[idx:idx+batch_size].to(device)
        current_batch_size = real_data.size(0)
        real_labels = torch.ones(current_batch_size, 1).to(device)

        noise = torch.randn(current_batch_size, 100).to(device)
        #noise = expression_data[idx:idx+batch_size]
        
        fake_methyl = gen(noise).to(device)
        #fake_data = torch.cat((expression_data[idx:idx+batch_size],fake_methyl), 1)

        fake_data = torch.cat((expression_data[idx:idx+batch_size],fake_methyl ), 1).to(device)

        fake_labels = torch.zeros(current_batch_size, 1).to(device)
        
        # Entrenar discriminador
        disc_optimizer.zero_grad()

        real_preds = disc(real_data).to(device)
        real_loss = criterion(real_preds, real_labels)
        
        fake_preds = disc(fake_data).to(device)
        fake_loss = criterion(fake_preds, fake_labels)

        disc_loss = real_loss + fake_loss
        disc_loss.backward()
        disc_optimizer.step()

        # Entrenar generador
        gen_optimizer.zero_grad()

        noise = torch.randn(current_batch_size, 100).to(device)
        fake_methyl = gen(noise).to(device)
        fake_data = torch.cat((expression_data[idx:idx+batch_size],fake_methyl ), 1).to(device)
        fake_preds = disc(fake_data).to(device)

        gen_loss = criterion(fake_preds, real_labels)
        gen_loss.backward()
        gen_optimizer.step()

    if (epoch+1) % 100 == 0:
        print(f"Epoch {epoch+1}/{n_epochs} | Disc Loss: {disc_loss.item()} | Gen Loss: {gen_loss.item()}")
        end_time = time.time()

        # Calcular la diferencia de tiempo
        elapsed_time = end_time - start_time

        print(f"El código tardó {elapsed_time:.5f} segundos en ejecutarse.")
        start_time = time.time()

torch.save(gen.state_dict(), 'generator_model2.pth')
# Out:
# Epoch 100/10000 | Disc Loss: 0.01707882434129715 | Gen Loss: 8.565431594848633
# El código tardó 174.23768 segundos en ejecutarse.
# Epoch 200/10000 | Disc Loss: 0.0014769148547202349 | Gen Loss: 13.212295532226562
# El código tardó 149.94316 segundos en ejecutarse.
# Epoch 300/10000 | Disc Loss: 0.00046135979937389493 | Gen Loss: 17.89940643310547
# El código tardó 146.95551 segundos en ejecutarse.
# Epoch 400/10000 | Disc Loss: 0.00048000417882576585 | Gen Loss: 17.815914154052734
# El código tardó 157.47819 segundos en ejecutarse.
# Epoch 500/10000 | Disc Loss: 0.05051526054739952 | Gen Loss: 18.261539459228516
# El código tardó 146.26449 segundos en ejecutarse.
# Epoch 600/10000 | Disc Loss: 4.128748696530238e-05 | Gen Loss: 16.9796142578125
# El código tardó 158.35204 segundos en ejecutarse.
# Epoch 700/10000 | Disc Loss: 0.00010783644393086433 | Gen Loss: 20.309486389160156
# El código tardó 150.55015 segundos en ejecutarse.
# Epoch 800/10000 | Disc Loss: 0.0002093649236485362 | Gen Loss: 22.364234924316406
# El código tardó 157.81714 segundos en ejecutarse.
# Epoch 900/10000 | Disc Loss: 0.0002565310278441757 | Gen Loss: 26.338909149169922
# El código tardó 127.00082 segundos en ejecutarse.
# Epoch 1000/10000 | Disc Loss: 3.518411540426314e-05 | Gen Loss: 28.193113327026367
# El código tardó 179.76325 segundos en ejecutarse.
# Epoch 1100/10000 | Disc Loss: 0.005637845490127802 | Gen Loss: 25.99816131591797
# El código tardó 169.13492 segundos en ejecutarse.
# Epoch 1200/10000 | Disc Loss: 0.0018363625276833773 | Gen Loss: 31.113365173339844
# El código tardó 157.02617 segundos en ejecutarse.
# Epoch 1300/10000 | Disc Loss: 1.0910374840022996e-05 | Gen Loss: 25.930587768554688
# El código tardó 150.22992 segundos en ejecutarse.
# Epoch 1400/10000 | Disc Loss: 3.549018583726138e-05 | Gen Loss: 31.121471405029297
# El código tardó 158.30859 segundos en ejecutarse.
# Epoch 1500/10000 | Disc Loss: 0.0017620987491682172 | Gen Loss: 28.58962059020996
# El código tardó 163.37516 segundos en ejecutarse.
# Epoch 1600/10000 | Disc Loss: 0.14900222420692444 | Gen Loss: 25.57080841064453
# El código tardó 174.16013 segundos en ejecutarse.
# Epoch 1700/10000 | Disc Loss: 2.5049987016245723e-05 | Gen Loss: 33.88591003417969
# El código tardó 174.40682 segundos en ejecutarse.
# Epoch 1800/10000 | Disc Loss: 0.0003117078449577093 | Gen Loss: 26.88612937927246
# El código tardó 158.97824 segundos en ejecutarse.
# Epoch 1900/10000 | Disc Loss: 2.0069115635124035e-05 | Gen Loss: 32.071041107177734
# El código tardó 150.17558 segundos en ejecutarse.
# Epoch 2000/10000 | Disc Loss: 5.0060370995197445e-05 | Gen Loss: 30.537118911743164
# El código tardó 143.20076 segundos en ejecutarse.
# Epoch 2100/10000 | Disc Loss: 0.13774435222148895 | Gen Loss: 33.576271057128906
# El código tardó 144.78786 segundos en ejecutarse.
# Epoch 2200/10000 | Disc Loss: 0.0038079095538705587 | Gen Loss: 35.93015670776367
# El código tardó 173.44110 segundos en ejecutarse.
# Epoch 2300/10000 | Disc Loss: 3.0542983040504623e-06 | Gen Loss: 33.49265670776367
# El código tardó 165.60643 segundos en ejecutarse.
# Epoch 2400/10000 | Disc Loss: 7.61311582664348e-07 | Gen Loss: 32.50773620605469
# El código tardó 155.46652 segundos en ejecutarse.
# Epoch 2500/10000 | Disc Loss: 7.049391570035368e-06 | Gen Loss: 37.50152587890625
# El código tardó 175.90696 segundos en ejecutarse.
# Epoch 2600/10000 | Disc Loss: 1.4714856661157683e-05 | Gen Loss: 28.136859893798828
# El código tardó 156.11852 segundos en ejecutarse.
# Epoch 2700/10000 | Disc Loss: 6.429570203181356e-05 | Gen Loss: 34.601531982421875
# El código tardó 151.87105 segundos en ejecutarse.
# Epoch 2800/10000 | Disc Loss: 3.3065068691939814e-06 | Gen Loss: 37.580894470214844
# El código tardó 155.45211 segundos en ejecutarse.
# Epoch 2900/10000 | Disc Loss: 0.00016657245578244328 | Gen Loss: 39.86559295654297
# El código tardó 165.56602 segundos en ejecutarse.
# Epoch 3000/10000 | Disc Loss: 5.06394098920282e-05 | Gen Loss: 35.39649963378906
# El código tardó 174.41494 segundos en ejecutarse.
# Epoch 3100/10000 | Disc Loss: 2.452033413646859e-06 | Gen Loss: 33.09267044067383
# El código tardó 165.68005 segundos en ejecutarse.
# Epoch 3200/10000 | Disc Loss: 5.3991941967979074e-05 | Gen Loss: 35.06033706665039
# El código tardó 175.92720 segundos en ejecutarse.
# Epoch 3300/10000 | Disc Loss: 2.0712698187708156e-06 | Gen Loss: 36.28709411621094
# El código tardó 162.71386 segundos en ejecutarse.
# Epoch 3400/10000 | Disc Loss: 4.405714207678102e-06 | Gen Loss: 31.544689178466797
# El código tardó 156.34963 segundos en ejecutarse.
# Epoch 3500/10000 | Disc Loss: 5.595518814516254e-06 | Gen Loss: 45.21270751953125
# El código tardó 159.94444 segundos en ejecutarse.
# Epoch 3600/10000 | Disc Loss: 1.3129998478689231e-05 | Gen Loss: 23.984432220458984
# El código tardó 163.41183 segundos en ejecutarse.
# Epoch 3700/10000 | Disc Loss: 8.928620445658453e-06 | Gen Loss: 25.871030807495117
# El código tardó 154.38287 segundos en ejecutarse.
# Epoch 3800/10000 | Disc Loss: 1.253073833140661e-06 | Gen Loss: 26.599590301513672
# El código tardó 179.07542 segundos en ejecutarse.
# Epoch 3900/10000 | Disc Loss: 1.6148831036844058e-06 | Gen Loss: 40.94511413574219
# El código tardó 146.42251 segundos en ejecutarse.
# Epoch 4000/10000 | Disc Loss: 1.493191064128041e-07 | Gen Loss: 36.73186492919922
# El código tardó 173.11425 segundos en ejecutarse.
# Epoch 4100/10000 | Disc Loss: 0.0001474854361731559 | Gen Loss: 38.012779235839844
# El código tardó 150.36754 segundos en ejecutarse.
# Epoch 4200/10000 | Disc Loss: 2.2403979528462514e-05 | Gen Loss: 41.135589599609375
# El código tardó 168.06474 segundos en ejecutarse.
# Epoch 4300/10000 | Disc Loss: 2.1002326775487745e-06 | Gen Loss: 45.704471588134766
# El código tardó 145.18486 segundos en ejecutarse.
# Epoch 4400/10000 | Disc Loss: 2.202700670750346e-06 | Gen Loss: 44.07897186279297
# El código tardó 175.93111 segundos en ejecutarse.
# Epoch 4500/10000 | Disc Loss: 0.00014515680959448218 | Gen Loss: 25.588279724121094
# El código tardó 165.07463 segundos en ejecutarse.
# Epoch 4600/10000 | Disc Loss: 2.769939055724535e-05 | Gen Loss: 26.354705810546875
# El código tardó 175.69163 segundos en ejecutarse.
# Epoch 4700/10000 | Disc Loss: 3.8745821484553744e-07 | Gen Loss: 45.145896911621094
# El código tardó 169.58251 segundos en ejecutarse.
# Epoch 4800/10000 | Disc Loss: 2.4392656996496953e-05 | Gen Loss: 43.50418472290039
# El código tardó 155.90048 segundos en ejecutarse.
# Epoch 4900/10000 | Disc Loss: 3.880369149555918e-06 | Gen Loss: 31.084228515625
# El código tardó 170.20623 segundos en ejecutarse.
# Epoch 5000/10000 | Disc Loss: 1.0504433021196746e-06 | Gen Loss: 29.697816848754883
# El código tardó 177.02327 segundos en ejecutarse.
# Epoch 5100/10000 | Disc Loss: 1.6235128441621782e-06 | Gen Loss: 29.2208194732666
# El código tardó 155.53458 segundos en ejecutarse.
# Epoch 5200/10000 | Disc Loss: 0.00015864623128436506 | Gen Loss: 37.80880355834961
# El código tardó 160.04842 segundos en ejecutarse.
# Epoch 5300/10000 | Disc Loss: 1.5969372952895355e-06 | Gen Loss: 42.81947326660156
# El código tardó 166.55838 segundos en ejecutarse.
# Epoch 5400/10000 | Disc Loss: 7.674135531487991e-07 | Gen Loss: 46.191261291503906
# El código tardó 159.31488 segundos en ejecutarse.
# Epoch 5500/10000 | Disc Loss: 0.006554792169481516 | Gen Loss: 32.3131103515625
# El código tardó 140.07290 segundos en ejecutarse.
# Epoch 5600/10000 | Disc Loss: 1.609345758879499e-06 | Gen Loss: 50.16118621826172
# El código tardó 167.27411 segundos en ejecutarse.
# Epoch 5700/10000 | Disc Loss: 4.6939246090005327e-07 | Gen Loss: 39.1077880859375
# El código tardó 152.26974 segundos en ejecutarse.
# Epoch 5800/10000 | Disc Loss: 1.1775323400797788e-05 | Gen Loss: 45.481170654296875
# El código tardó 149.39448 segundos en ejecutarse.
# Epoch 5900/10000 | Disc Loss: 2.8604999897652306e-06 | Gen Loss: 36.04400634765625
# El código tardó 161.00735 segundos en ejecutarse.
# Epoch 6000/10000 | Disc Loss: 0.00011543452274054289 | Gen Loss: 46.57366180419922
# El código tardó 167.03301 segundos en ejecutarse.
# Epoch 6100/10000 | Disc Loss: 1.2049005817971192e-05 | Gen Loss: 34.37127685546875
# El código tardó 138.38673 segundos en ejecutarse.
# Epoch 6200/10000 | Disc Loss: 9.666527148510795e-06 | Gen Loss: 40.54606628417969
# El código tardó 164.32332 segundos en ejecutarse.
# Epoch 6300/10000 | Disc Loss: 0.006546706426888704 | Gen Loss: 36.018768310546875
# El código tardó 142.75878 segundos en ejecutarse.
# Epoch 6400/10000 | Disc Loss: 2.697528316275566e-06 | Gen Loss: 37.569820404052734
# El código tardó 112.96417 segundos en ejecutarse.
# Epoch 6500/10000 | Disc Loss: 7.384053901660081e-07 | Gen Loss: 41.51969909667969
# El código tardó 172.49465 segundos en ejecutarse.
# Epoch 6600/10000 | Disc Loss: 1.04713599284878e-05 | Gen Loss: 38.796363830566406
# El código tardó 160.94964 segundos en ejecutarse.
# Epoch 6700/10000 | Disc Loss: 0.00013214352657087147 | Gen Loss: 37.511497497558594
# El código tardó 183.49884 segundos en ejecutarse.
# Epoch 6800/10000 | Disc Loss: 3.278290421349084e-07 | Gen Loss: 44.60722351074219
# El código tardó 145.24987 segundos en ejecutarse.
# Epoch 6900/10000 | Disc Loss: 1.488106704528036e-06 | Gen Loss: 56.11589050292969
# El código tardó 141.54337 segundos en ejecutarse.
# Epoch 7000/10000 | Disc Loss: 4.057074818319961e-07 | Gen Loss: 43.90521240234375
# El código tardó 163.95550 segundos en ejecutarse.
# Epoch 7100/10000 | Disc Loss: 3.7876793715363455e-12 | Gen Loss: 35.43133544921875
# El código tardó 161.07742 segundos en ejecutarse.
# Epoch 7200/10000 | Disc Loss: 8.059768333623651e-06 | Gen Loss: 53.18081283569336
# El código tardó 142.74760 segundos en ejecutarse.
# Epoch 7300/10000 | Disc Loss: 8.128710032906383e-05 | Gen Loss: 47.61369323730469
# El código tardó 164.22313 segundos en ejecutarse.
# Epoch 7400/10000 | Disc Loss: 2.1089103938720655e-06 | Gen Loss: 29.821292877197266
# El código tardó 168.38433 segundos en ejecutarse.
# Epoch 7500/10000 | Disc Loss: 8.611455086793285e-07 | Gen Loss: 42.198848724365234
# El código tardó 157.96592 segundos en ejecutarse.
# Epoch 7600/10000 | Disc Loss: 1.8289265426574275e-06 | Gen Loss: 43.84669494628906
# El código tardó 176.16518 segundos en ejecutarse.
# Epoch 7700/10000 | Disc Loss: 0.00035605268203653395 | Gen Loss: 28.84402084350586
# El código tardó 111.54472 segundos en ejecutarse.
# Epoch 7800/10000 | Disc Loss: 5.435104412754299e-06 | Gen Loss: 41.225990295410156
# El código tardó 154.66669 segundos en ejecutarse.
# Epoch 7900/10000 | Disc Loss: 7.732482117717154e-06 | Gen Loss: 55.26622772216797
# El código tardó 152.56563 segundos en ejecutarse.
# Epoch 8000/10000 | Disc Loss: 0.003320917719975114 | Gen Loss: 38.677162170410156
# El código tardó 161.99365 segundos en ejecutarse.
# Epoch 8100/10000 | Disc Loss: 2.980365465532486e-08 | Gen Loss: 47.977787017822266
# El código tardó 157.75034 segundos en ejecutarse.
# Epoch 8200/10000 | Disc Loss: 2.5146732696157414e-06 | Gen Loss: 46.58965301513672
# El código tardó 155.39113 segundos en ejecutarse.
# Epoch 8300/10000 | Disc Loss: 2.2928880127892626e-07 | Gen Loss: 41.51734924316406
# El código tardó 157.33780 segundos en ejecutarse.
# Epoch 8400/10000 | Disc Loss: 1.9851323429520562e-07 | Gen Loss: 34.537784576416016
# El código tardó 161.89208 segundos en ejecutarse.
# Epoch 8500/10000 | Disc Loss: 0.07587685436010361 | Gen Loss: 44.28590393066406
# El código tardó 156.64213 segundos en ejecutarse.
# Epoch 8600/10000 | Disc Loss: 3.9079853308976453e-07 | Gen Loss: 51.80938720703125
# El código tardó 151.59618 segundos en ejecutarse.
# Epoch 8700/10000 | Disc Loss: 5.275204784993548e-06 | Gen Loss: 49.92129135131836
# El código tardó 144.01048 segundos en ejecutarse.
# Epoch 8800/10000 | Disc Loss: 3.9609346913493937e-07 | Gen Loss: 43.00957489013672
# El código tardó 178.89781 segundos en ejecutarse.
# Epoch 8900/10000 | Disc Loss: 2.42770035185913e-08 | Gen Loss: 44.312599182128906
# El código tardó 158.48375 segundos en ejecutarse.
# Epoch 9000/10000 | Disc Loss: 2.473622089382843e-07 | Gen Loss: 42.29586410522461
# El código tardó 153.49247 segundos en ejecutarse.
# Epoch 9100/10000 | Disc Loss: 9.34319075440726e-08 | Gen Loss: 44.61251449584961
# El código tardó 170.51361 segundos en ejecutarse.
# Epoch 9200/10000 | Disc Loss: 1.6710703221178846e-06 | Gen Loss: 44.31761169433594
# El código tardó 157.15195 segundos en ejecutarse.
# Epoch 9300/10000 | Disc Loss: 4.052350777783431e-05 | Gen Loss: 29.403953552246094
# El código tardó 168.22278 segundos en ejecutarse.
# Epoch 9400/10000 | Disc Loss: 1.3060238188700168e-06 | Gen Loss: 39.54438018798828
# El código tardó 179.91647 segundos en ejecutarse.
# Epoch 9500/10000 | Disc Loss: 1.617634325157269e-06 | Gen Loss: 45.7721061706543
# El código tardó 145.22912 segundos en ejecutarse.
# Epoch 9600/10000 | Disc Loss: 2.3627221068522886e-08 | Gen Loss: 42.895591735839844
# El código tardó 172.03108 segundos en ejecutarse.
# Epoch 9700/10000 | Disc Loss: 8.510918547699475e-08 | Gen Loss: 40.31911087036133
# El código tardó 159.75660 segundos en ejecutarse.
# Epoch 9800/10000 | Disc Loss: 0.00038077819044701755 | Gen Loss: 47.77129364013672
# El código tardó 128.92071 segundos en ejecutarse.
# Epoch 9900/10000 | Disc Loss: 2.0221721115376567e-06 | Gen Loss: 52.289127349853516
# El código tardó 152.37585 segundos en ejecutarse.
# Epoch 10000/10000 | Disc Loss: 1.367519416817231e-06 | Gen Loss: 43.86112976074219
# El código tardó 124.31530 segundos en ejecutarse.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns

# Generar datos de expresión sintética
gen2 = Generator(100, methylation_data.shape[1]+assign_data.shape[1]).to(device)
gen2.load_state_dict(torch.load('generator_model2.pth'))
gen2.eval()
expressions_list = []
for i in range(10000):
    noise = torch.randn(1, 100).to(device)
    synthetic_expression = gen2(noise).to(device)
    #print(synthetic_expression)
    expressions_list.append(synthetic_expression.detach().cpu().numpy().squeeze())

X = pd.DataFrame(expressions_list)
#X = X.apply(pd.to_numeric, errors='coerce')
y = X.iloc[:, -1].values.astype(int)  # Suponiendo que la asignación está en la primera columna

X = X.iloc[:, :-1]
# Dividimos los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Entrenamos el modelo SVC
clf = SVC()
clf.fit(X_train, y_train)

# Predicciones
y_pred = clf.predict(X_test)

# Métricas de clasificación
print(classification_report(y_test, y_pred))

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2658
#            1       1.00      1.00      1.00       342
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns

# Cargamos los datos
expr_data = pd.read_csv('exprMID.csv')
meth_data = pd.read_csv('methylMID.csv')
assig_data = pd.read_csv('assignMID.csv')
expr_data = expr_data.iloc[:, 1:]
meth_data = meth_data.iloc[:, 1:]
assig_data = assig_data.iloc[:, 2:]

# Convertir todas las columnas a tipo float
expr_data = expr_data.apply(pd.to_numeric, errors='coerce')
meth_data = meth_data.apply(pd.to_numeric, errors='coerce')
assig_data = assig_data.apply(pd.to_numeric, errors='coerce')
# Lidiar con valores NaN (si los hay). Pone 0(CAMBIAR)
expr_data.fillna(0, inplace=True)
meth_data.fillna(0, inplace=True)
assig_data.fillna(0, inplace=True)
# Aseguramos que las dimensiones coincidan
assert expr_data.shape[0] == meth_data.shape[0] == assig_data.shape[0], "Las dimensiones de los archivos no coinciden"

# Combinamos los datos de expresión génica y metilación
X = pd.concat([expr_data, meth_data], axis=1)
y = assig_data.iloc[:, 0].values  # Suponiendo que la asignación está en la primera columna

# Dividimos los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Entrenamos el modelo SVC
clf = SVC()
clf.fit(X_train, y_train)

# Predicciones
y_pred = clf.predict(X_test)

# Métricas de clasificación
print(classification_report(y_test, y_pred))

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     23934
#            2       1.00      1.00      1.00      6066
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns

# Cargamos los datos
expr_data = pd.read_csv('exprMID.csv')
meth_data = pd.read_csv('methylMID.csv')
assig_data = pd.read_csv('assignMID.csv')
expr_data = expr_data.iloc[:, 1:]
meth_data = meth_data.iloc[:, 1:]
assig_data = assig_data.iloc[:, 2:]

# Convertir todas las columnas a tipo float
expr_data = expr_data.apply(pd.to_numeric, errors='coerce')
meth_data = meth_data.apply(pd.to_numeric, errors='coerce')
assig_data = assig_data.apply(pd.to_numeric, errors='coerce')
# Lidiar con valores NaN (si los hay). Pone 0(CAMBIAR)
expr_data.fillna(0, inplace=True)
meth_data.fillna(0, inplace=True)
assig_data.fillna(0, inplace=True)
# Aseguramos que las dimensiones coincidan
assert expr_data.shape[0] == meth_data.shape[0] == assig_data.shape[0], "Las dimensiones de los archivos no coinciden"

# Combinamos los datos de expresión génica y metilación
X = meth_data
y = assig_data.iloc[:, 0].values  # Suponiendo que la asignación está en la primera columna

# Dividimos los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Entrenamos el modelo SVC
clf = SVC()
clf.fit(X_train, y_train)

# Predicciones
y_pred = clf.predict(X_test)

# Métricas de clasificación
print(classification_report(y_test, y_pred))

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     23934
#            2       1.00      1.00      1.00      6066
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
