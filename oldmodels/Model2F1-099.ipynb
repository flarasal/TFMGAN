# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import time

# Definir el generador y el discriminador
class Generator(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(Generator, self).__init__()
        self.net = nn.Sequential(
            #nn.Linear(input_dim, 128),
            #nn.ReLU(),
            #nn.Linear(128, 256),
            #nn.ReLU(),
            #nn.Linear(256, output_dim),
            #nn.Tanh()
                    
            nn.Linear(input_dim, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            
            nn.Linear(512, 768),
            nn.BatchNorm1d(768),
            nn.ReLU(),
            
            nn.Linear(768, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(),

            #nn.Linear(1024, 768),
            #nn.BatchNorm1d(768),
            #nn.ReLU(),
            
            #nn.Linear(768, 512),
            #nn.BatchNorm1d(512),
            #nn.ReLU(),
            
            nn.Linear(1024, output_dim),
            nn.Tanh()
        )
        
    def forward(self, x):
        return self.net(x)

class Discriminator(nn.Module):
    def __init__(self, input_dim):
        super(Discriminator, self).__init__()
        self.net = nn.Sequential(
            #nn.Linear(input_dim, 256),
            #nn.LeakyReLU(0.2),
            #nn.Linear(256, 256),
            #nn.LeakyReLU(0.2),
            #nn.Linear(256, 128),
            #nn.LeakyReLU(0.2),
            #nn.Linear(128, 1),
            #nn.Sigmoid()
            
            nn.Linear(input_dim, 256),
            #nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.3),
        
            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.3),
            
            #nn.Linear(128, 64),
            #nn.BatchNorm1d(64),
            #nn.ReLU(),
            #nn.Dropout(0.3),
    
            nn.Linear(128, 1),
            nn.Sigmoid(),
        )
        
    def forward(self, x):
        return self.net(x)
        
# Leer datos
expression_data = pd.read_csv('expr.csv')
methylation_data = pd.read_csv('methyl.csv')
assign_data = pd.read_csv('assign.csv')

expression_data = expression_data.iloc[:, 1:]
methylation_data = methylation_data.iloc[:, 1:]
assign_data = assign_data.iloc[:, 2:]

# Convertir todas las columnas a tipo float
expression_data = expression_data.apply(pd.to_numeric, errors='coerce')
methylation_data = methylation_data.apply(pd.to_numeric, errors='coerce')
assign_data = assign_data.apply(pd.to_numeric, errors='coerce')
# Lidiar con valores NaN (si los hay). Pone 0(CAMBIAR)
expression_data.fillna(0, inplace=True)
methylation_data.fillna(0, inplace=True)
assign_data.fillna(0, inplace=True)

expression_data = expression_data.values
methylation_data = methylation_data.values
assign_data=assign_data.values
# Asegurar que tienes el mismo número de muestras en ambos conjuntos de datos


assert expression_data.shape[0] == methylation_data.shape[0], "Los datos de expresión y metilación deben tener el mismo número de muestras."
assert assign_data.shape[0] == methylation_data.shape[0], "Los datos de asignación y metilación deben tener el mismo número de muestras."

# Concatenar los datos
#combined_data =torch.FloatTensor(np.hstack((expression_data, methylation_data,assign_data)))
print(torch.cuda.is_available())
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device="cpu"
expression_data = torch.FloatTensor(expression_data).to(device)
methylation_data = torch.FloatTensor(methylation_data).to(device)
assign_data = torch.FloatTensor(assign_data).to(device)
combined_data = torch.cat((expression_data,methylation_data,assign_data), 1).to(device)
# Out:
# True

# %%
# Modelos y optimizadores
gen = Generator(100, methylation_data.shape[1]+assign_data.shape[1]).to(device)
disc = Discriminator(expression_data.shape[1] + methylation_data.shape[1]+assign_data.shape[1]).to(device)
gen_optimizer = optim.Adam(gen.parameters(), lr=0.0002)
disc_optimizer = optim.Adam(disc.parameters(), lr=0.0002)
criterion = nn.BCELoss()

# Entrenamiento
n_samples = combined_data.size(0)
batch_size = 64
n_epochs = 10000
start_time = time.time()
for epoch in range(n_epochs):
    for idx in range(0, n_samples, batch_size):
        real_data = combined_data[idx:idx+batch_size].to(device)
        current_batch_size = real_data.size(0)
        real_labels = torch.ones(current_batch_size, 1).to(device)

        noise = torch.randn(current_batch_size, 100).to(device)
        #noise = expression_data[idx:idx+batch_size]
        
        fake_methyl = gen(noise).to(device)
        #fake_data = torch.cat((expression_data[idx:idx+batch_size],fake_methyl), 1)

        fake_data = torch.cat((expression_data[idx:idx+batch_size],fake_methyl ), 1).to(device)

        fake_labels = torch.zeros(current_batch_size, 1).to(device)
        
        # Entrenar discriminador
        disc_optimizer.zero_grad()

        real_preds = disc(real_data).to(device)
        real_loss = criterion(real_preds, real_labels)
        
        fake_preds = disc(fake_data).to(device)
        fake_loss = criterion(fake_preds, fake_labels)

        disc_loss = real_loss + fake_loss
        disc_loss.backward()
        disc_optimizer.step()

        # Entrenar generador
        gen_optimizer.zero_grad()

        noise = torch.randn(current_batch_size, 100).to(device)
        fake_methyl = gen(noise).to(device)
        fake_data = torch.cat((expression_data[idx:idx+batch_size],fake_methyl ), 1).to(device)
        fake_preds = disc(fake_data).to(device)

        gen_loss = criterion(fake_preds, real_labels)
        gen_loss.backward()
        gen_optimizer.step()

    if (epoch+1) % 100 == 0:
        print(f"Epoch {epoch+1}/{n_epochs} | Disc Loss: {disc_loss.item()} | Gen Loss: {gen_loss.item()}")
        end_time = time.time()

        # Calcular la diferencia de tiempo
        elapsed_time = end_time - start_time

        print(f"El código tardó {elapsed_time:.5f} segundos en ejecutarse.")
        start_time = time.time()

torch.save(gen.state_dict(), 'generator_model.pth')
# Out:
# Epoch 100/10000 | Disc Loss: 0.000807556149084121 | Gen Loss: 10.889925003051758
# El código tardó 112.72470 segundos en ejecutarse.
# Epoch 200/10000 | Disc Loss: 0.002753788372501731 | Gen Loss: 13.62681770324707
# El código tardó 121.73309 segundos en ejecutarse.
# Epoch 300/10000 | Disc Loss: 0.001795490738004446 | Gen Loss: 16.125633239746094
# El código tardó 105.47391 segundos en ejecutarse.
# Epoch 400/10000 | Disc Loss: 3.386068783584051e-05 | Gen Loss: 17.280067443847656
# El código tardó 104.03243 segundos en ejecutarse.
# Epoch 500/10000 | Disc Loss: 4.6130116970743984e-05 | Gen Loss: 13.773537635803223
# El código tardó 106.32831 segundos en ejecutarse.
# Epoch 600/10000 | Disc Loss: 1.7357740944135003e-05 | Gen Loss: 15.520808219909668
# El código tardó 107.96036 segundos en ejecutarse.
# Epoch 700/10000 | Disc Loss: 0.003645859891548753 | Gen Loss: 18.902584075927734
# El código tardó 94.09130 segundos en ejecutarse.
# Epoch 800/10000 | Disc Loss: 0.0001916400797199458 | Gen Loss: 28.19015121459961
# El código tardó 100.50155 segundos en ejecutarse.
# Epoch 900/10000 | Disc Loss: 6.758453673683107e-05 | Gen Loss: 44.009647369384766
# El código tardó 124.06243 segundos en ejecutarse.
# Epoch 1000/10000 | Disc Loss: 5.079424590803683e-05 | Gen Loss: 40.744956970214844
# El código tardó 103.87728 segundos en ejecutarse.
# Epoch 1100/10000 | Disc Loss: 0.0006313964840956032 | Gen Loss: 56.99422073364258
# El código tardó 113.43625 segundos en ejecutarse.
# Epoch 1200/10000 | Disc Loss: 0.000104085287603084 | Gen Loss: 62.36616516113281
# El código tardó 102.06294 segundos en ejecutarse.
# Epoch 1300/10000 | Disc Loss: 1.3977579328638967e-05 | Gen Loss: 61.81986999511719
# El código tardó 118.01685 segundos en ejecutarse.
# Epoch 1400/10000 | Disc Loss: 0.0001399952598148957 | Gen Loss: 68.59886169433594
# El código tardó 124.60647 segundos en ejecutarse.
# Epoch 1500/10000 | Disc Loss: 2.160726216970943e-05 | Gen Loss: 64.8670654296875
# El código tardó 122.50051 segundos en ejecutarse.
# Epoch 1600/10000 | Disc Loss: 3.3342657843604684e-05 | Gen Loss: 63.77781677246094
# El código tardó 127.54368 segundos en ejecutarse.
# Epoch 1700/10000 | Disc Loss: 2.7162850528839044e-05 | Gen Loss: 73.83275604248047
# El código tardó 110.07357 segundos en ejecutarse.
# Epoch 1800/10000 | Disc Loss: 6.802508323744405e-06 | Gen Loss: 57.777469635009766
# El código tardó 141.84647 segundos en ejecutarse.
# Epoch 1900/10000 | Disc Loss: 3.4427412174409255e-05 | Gen Loss: 65.838134765625
# El código tardó 109.03489 segundos en ejecutarse.
# Epoch 2000/10000 | Disc Loss: 4.565320341498591e-05 | Gen Loss: 67.99097442626953
# El código tardó 91.28487 segundos en ejecutarse.
# Epoch 2100/10000 | Disc Loss: 1.5952056855894625e-05 | Gen Loss: 78.61245727539062
# El código tardó 96.97775 segundos en ejecutarse.
# Epoch 2200/10000 | Disc Loss: 1.6637990484014153e-05 | Gen Loss: 71.95756530761719
# El código tardó 110.72580 segundos en ejecutarse.
# Epoch 2300/10000 | Disc Loss: 3.4900251193903387e-05 | Gen Loss: 84.0821762084961
# El código tardó 102.42656 segundos en ejecutarse.
# Epoch 2400/10000 | Disc Loss: 1.7889307855512016e-05 | Gen Loss: 87.46019744873047
# El código tardó 118.17830 segundos en ejecutarse.
# Epoch 2500/10000 | Disc Loss: 3.0310164220281877e-05 | Gen Loss: 85.18101501464844
# El código tardó 95.86770 segundos en ejecutarse.
# Epoch 2600/10000 | Disc Loss: 3.2031362934503704e-05 | Gen Loss: 76.95585632324219
# El código tardó 123.08476 segundos en ejecutarse.
# Epoch 2700/10000 | Disc Loss: 6.841763388365507e-05 | Gen Loss: 73.8846435546875
# El código tardó 108.32083 segundos en ejecutarse.
# Epoch 2800/10000 | Disc Loss: 6.511950232379604e-06 | Gen Loss: 89.92727661132812
# El código tardó 120.50731 segundos en ejecutarse.
# Epoch 2900/10000 | Disc Loss: 2.6598720523907105e-06 | Gen Loss: 73.01506042480469
# El código tardó 99.47707 segundos en ejecutarse.
# Epoch 3000/10000 | Disc Loss: 4.321341293689329e-07 | Gen Loss: 87.32461547851562
# El código tardó 114.72982 segundos en ejecutarse.
# Epoch 3100/10000 | Disc Loss: 9.462268053539447e-07 | Gen Loss: 91.71204376220703
# El código tardó 110.68138 segundos en ejecutarse.
# Epoch 3200/10000 | Disc Loss: 1.9595108824432828e-06 | Gen Loss: 65.09443664550781
# El código tardó 114.10878 segundos en ejecutarse.
# Epoch 3300/10000 | Disc Loss: 1.683836558186158e-06 | Gen Loss: 78.45713806152344
# El código tardó 102.51833 segundos en ejecutarse.
# Epoch 3400/10000 | Disc Loss: 7.748611210445233e-07 | Gen Loss: 86.57769775390625
# El código tardó 112.33159 segundos en ejecutarse.
# Epoch 3500/10000 | Disc Loss: 1.862649241957115e-06 | Gen Loss: 77.50519561767578
# El código tardó 109.46576 segundos en ejecutarse.
# Epoch 3600/10000 | Disc Loss: 1.3783600252281758e-06 | Gen Loss: 75.79672241210938
# El código tardó 112.58309 segundos en ejecutarse.
# Epoch 3700/10000 | Disc Loss: 3.4645668165467214e-06 | Gen Loss: 76.9879150390625
# El código tardó 116.82812 segundos en ejecutarse.
# Epoch 3800/10000 | Disc Loss: 1.1400305993447546e-05 | Gen Loss: 73.00141906738281
# El código tardó 121.85463 segundos en ejecutarse.
# Epoch 3900/10000 | Disc Loss: 1.4528667406921159e-06 | Gen Loss: 87.50944519042969
# El código tardó 97.40516 segundos en ejecutarse.
# Epoch 4000/10000 | Disc Loss: 4.142557827435667e-06 | Gen Loss: 79.10527038574219
# El código tardó 108.64505 segundos en ejecutarse.
# Epoch 4100/10000 | Disc Loss: 5.289917339723615e-07 | Gen Loss: 75.72023010253906
# El código tardó 100.27807 segundos en ejecutarse.
# Epoch 4200/10000 | Disc Loss: 5.170773874851875e-06 | Gen Loss: 83.81645202636719
# El código tardó 111.56056 segundos en ejecutarse.
# Epoch 4300/10000 | Disc Loss: 5.394335857999977e-06 | Gen Loss: 77.42362976074219
# El código tardó 127.24821 segundos en ejecutarse.
# Epoch 4400/10000 | Disc Loss: 4.768376129504759e-07 | Gen Loss: 85.58761596679688
# El código tardó 95.52009 segundos en ejecutarse.
# Epoch 4500/10000 | Disc Loss: 1.139947244155337e-06 | Gen Loss: 79.7182388305664
# El código tardó 97.93650 segundos en ejecutarse.
# Epoch 4600/10000 | Disc Loss: 1.6391291524087137e-07 | Gen Loss: 73.88919067382812
# El código tardó 99.35843 segundos en ejecutarse.
# Epoch 4700/10000 | Disc Loss: 4.6624389643105415e-29 | Gen Loss: 86.85784149169922
# El código tardó 106.48244 segundos en ejecutarse.
# Epoch 4800/10000 | Disc Loss: 2.002729269045365e-21 | Gen Loss: 82.45042419433594
# El código tardó 101.23856 segundos en ejecutarse.
# Epoch 4900/10000 | Disc Loss: 3.725291364276018e-08 | Gen Loss: 83.37777709960938
# El código tardó 93.65858 segundos en ejecutarse.
# Epoch 5000/10000 | Disc Loss: 8.307649037650004e-28 | Gen Loss: 75.03019714355469
# El código tardó 109.04312 segundos en ejecutarse.
# Epoch 5100/10000 | Disc Loss: 3.471146311804043e-17 | Gen Loss: 87.21165466308594
# El código tardó 107.93677 segundos en ejecutarse.
# Epoch 5200/10000 | Disc Loss: 1.4901162970204496e-08 | Gen Loss: 86.38250732421875
# El código tardó 114.22479 segundos en ejecutarse.
# Epoch 5300/10000 | Disc Loss: 1.8626465703164286e-07 | Gen Loss: 84.39256286621094
# El código tardó 117.10738 segundos en ejecutarse.
# Epoch 5400/10000 | Disc Loss: 5.97596348703096e-32 | Gen Loss: 93.49724578857422
# El código tardó 134.57564 segundos en ejecutarse.
# Epoch 5500/10000 | Disc Loss: 7.411448952968972e-17 | Gen Loss: 82.09344482421875
# El código tardó 106.43301 segundos en ejecutarse.
# Epoch 5600/10000 | Disc Loss: 1.1351742129904387e-27 | Gen Loss: 82.17630004882812
# El código tardó 117.04269 segundos en ejecutarse.
# Epoch 5700/10000 | Disc Loss: 1.7935826341004716e-30 | Gen Loss: 84.55852508544922
# El código tardó 118.48407 segundos en ejecutarse.
# Epoch 5800/10000 | Disc Loss: 8.315514349097579e-17 | Gen Loss: 90.24397277832031
# El código tardó 118.36840 segundos en ejecutarse.
# Epoch 5900/10000 | Disc Loss: 7.450581485102248e-09 | Gen Loss: 92.27175903320312
# El código tardó 122.83741 segundos en ejecutarse.
# Epoch 6000/10000 | Disc Loss: 1.4901162970204496e-08 | Gen Loss: 80.89109802246094
# El código tardó 132.43780 segundos en ejecutarse.
# Epoch 6100/10000 | Disc Loss: 1.9371539394796855e-07 | Gen Loss: 90.0654296875
# El código tardó 106.64435 segundos en ejecutarse.
# Epoch 6200/10000 | Disc Loss: 2.4785257979469623e-33 | Gen Loss: 85.67081451416016
# El código tardó 102.56971 segundos en ejecutarse.
# Epoch 6300/10000 | Disc Loss: 7.45152295422713e-09 | Gen Loss: 92.7039566040039
# El código tardó 115.62830 segundos en ejecutarse.
# Epoch 6400/10000 | Disc Loss: 1.5576615367519219e-18 | Gen Loss: 84.9103012084961
# El código tardó 109.78551 segundos en ejecutarse.
# Epoch 6500/10000 | Disc Loss: 7.450581485102248e-09 | Gen Loss: 86.20401000976562
# El código tardó 120.02727 segundos en ejecutarse.
# Epoch 6600/10000 | Disc Loss: 7.22624586079631e-17 | Gen Loss: 71.59866333007812
# El código tardó 110.63486 segundos en ejecutarse.
# Epoch 6700/10000 | Disc Loss: 7.450581485102248e-09 | Gen Loss: 96.13211059570312
# El código tardó 92.74679 segundos en ejecutarse.
# Epoch 6800/10000 | Disc Loss: 1.6289721313019697e-24 | Gen Loss: 97.15750122070312
# El código tardó 97.88478 segundos en ejecutarse.
# Epoch 6900/10000 | Disc Loss: 1.6391298629514495e-07 | Gen Loss: 88.54939270019531
# El código tardó 113.56174 segundos en ejecutarse.
# Epoch 7000/10000 | Disc Loss: 1.0628424954033247e-30 | Gen Loss: 86.773193359375
# El código tardó 124.77201 segundos en ejecutarse.
# Epoch 7100/10000 | Disc Loss: 1.3631541058011186e-29 | Gen Loss: 89.78816223144531
# El código tardó 116.32219 segundos en ejecutarse.
# Epoch 7200/10000 | Disc Loss: 7.450581485102248e-09 | Gen Loss: 92.27444458007812
# El código tardó 116.74336 segundos en ejecutarse.
# Epoch 7300/10000 | Disc Loss: 9.400685239571149e-30 | Gen Loss: 91.126220703125
# El código tardó 134.15896 segundos en ejecutarse.
# Epoch 7400/10000 | Disc Loss: 1.6908401255292797e-31 | Gen Loss: 94.29252624511719
# El código tardó 99.08488 segundos en ejecutarse.
# Epoch 7500/10000 | Disc Loss: 1.2712668596798268e-30 | Gen Loss: 89.71501159667969
# El código tardó 107.01776 segundos en ejecutarse.
# Epoch 7600/10000 | Disc Loss: 5.0858344252733316e-30 | Gen Loss: 88.00401306152344
# El código tardó 110.33432 segundos en ejecutarse.
# Epoch 7700/10000 | Disc Loss: 3.708454836966607e-26 | Gen Loss: 94.57328033447266
# El código tardó 128.58563 segundos en ejecutarse.
# Epoch 7800/10000 | Disc Loss: 1.4901162970204496e-08 | Gen Loss: 88.58848571777344
# El código tardó 124.95464 segundos en ejecutarse.
# Epoch 7900/10000 | Disc Loss: 1.5529912148600455e-29 | Gen Loss: 86.13883972167969
# El código tardó 121.73196 segundos en ejecutarse.
# Epoch 8000/10000 | Disc Loss: 2.927844646388862e-34 | Gen Loss: 88.55464172363281
# El código tardó 106.97219 segundos en ejecutarse.
# Epoch 8100/10000 | Disc Loss: 6.002801988119755e-12 | Gen Loss: 93.6788330078125
# El código tardó 97.27850 segundos en ejecutarse.
# Epoch 8200/10000 | Disc Loss: 8.940699558479537e-08 | Gen Loss: 76.26179504394531
# El código tardó 119.84345 segundos en ejecutarse.
# Epoch 8300/10000 | Disc Loss: 8.195644340958097e-08 | Gen Loss: 91.76510620117188
# El código tardó 110.92646 segundos en ejecutarse.
# Epoch 8400/10000 | Disc Loss: 3.799801504555944e-07 | Gen Loss: 94.14794158935547
# El código tardó 134.83712 segundos en ejecutarse.
# Epoch 8500/10000 | Disc Loss: 2.4106057400022916e-16 | Gen Loss: 94.2957534790039
# El código tardó 122.80121 segundos en ejecutarse.
# Epoch 8600/10000 | Disc Loss: 7.450584149637507e-09 | Gen Loss: 93.99838256835938
# El código tardó 126.80110 segundos en ejecutarse.
# Epoch 8700/10000 | Disc Loss: 1.4901162970204496e-08 | Gen Loss: 91.54376983642578
# El código tardó 119.19346 segundos en ejecutarse.
# Epoch 8800/10000 | Disc Loss: 1.4901162970204496e-08 | Gen Loss: 87.30653381347656
# El código tardó 97.40929 segundos en ejecutarse.
# Epoch 8900/10000 | Disc Loss: 8.458821613488916e-31 | Gen Loss: 98.00381469726562
# El código tardó 112.62929 segundos en ejecutarse.
# Epoch 9000/10000 | Disc Loss: 7.450581485102248e-09 | Gen Loss: 93.47564697265625
# El código tardó 135.22867 segundos en ejecutarse.
# Epoch 9100/10000 | Disc Loss: 3.8992282646110604e-36 | Gen Loss: 98.0404281616211
# El código tardó 111.16495 segundos en ejecutarse.
# Epoch 9200/10000 | Disc Loss: 7.450581485102248e-09 | Gen Loss: 86.60291290283203
# El código tardó 92.12709 segundos en ejecutarse.
# Epoch 9300/10000 | Disc Loss: 1.4901162970204496e-08 | Gen Loss: 75.92367553710938
# El código tardó 120.94972 segundos en ejecutarse.
# Epoch 9400/10000 | Disc Loss: 1.1739837747537972e-29 | Gen Loss: 96.50611877441406
# El código tardó 121.41480 segundos en ejecutarse.
# Epoch 9500/10000 | Disc Loss: 2.980232949312267e-08 | Gen Loss: 96.09513854980469
# El código tardó 136.26416 segundos en ejecutarse.
# Epoch 9600/10000 | Disc Loss: 1.4901162970204496e-08 | Gen Loss: 82.84783935546875
# El código tardó 103.72148 segundos en ejecutarse.
# Epoch 9700/10000 | Disc Loss: 4.470350134511136e-08 | Gen Loss: 96.92273712158203
# El código tardó 97.90738 segundos en ejecutarse.
# Epoch 9800/10000 | Disc Loss: 7.450581485102248e-09 | Gen Loss: 92.22335815429688
# El código tardó 98.98480 segundos en ejecutarse.
# Epoch 9900/10000 | Disc Loss: 1.3701582356993738e-33 | Gen Loss: 93.43916320800781
# El código tardó 114.37542 segundos en ejecutarse.
# Epoch 10000/10000 | Disc Loss: 8.94070240065048e-08 | Gen Loss: 93.59642028808594
# El código tardó 121.60441 segundos en ejecutarse.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns

# Generar datos de expresión sintética
gen2 = Generator(100, methylation_data.shape[1]+assign_data.shape[1]).to(device)
gen2.load_state_dict(torch.load('generator_model.pth'))
gen2.eval()
expressions_list = []
for i in range(10000):
    noise = torch.randn(1, 100).to(device)
    synthetic_expression = gen2(noise).to(device)
    #print(synthetic_expression)
    expressions_list.append(synthetic_expression.detach().cpu().numpy().squeeze())

X = pd.DataFrame(expressions_list)
#X = X.apply(pd.to_numeric, errors='coerce')
y = X.iloc[:, -1].values.astype(int)  # Suponiendo que la asignación está en la primera columna

X = X.iloc[:, :-1]
# Dividimos los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Entrenamos el modelo SVC
clf = SVC()
clf.fit(X_train, y_train)

# Predicciones
y_pred = clf.predict(X_test)

# Métricas de clasificación
print(classification_report(y_test, y_pred))

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 30
#      28 # Entrenamos el modelo SVC
#      29 clf = SVC()
# ---> 30 clf.fit(X_train, y_train)
#      32 # Predicciones
#      33 y_pred = clf.predict(X_test)
#
# File ~/PyEnv/PB/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/PyEnv/PB/lib/python3.11/site-packages/sklearn/svm/_base.py:199, in BaseLibSVM.fit(self, X, y, sample_weight)
#     189 else:
#     190     X, y = self._validate_data(
#     191         X,
#     192         y,
#    (...)
#     196         accept_large_sparse=False,
#     197     )
# --> 199 y = self._validate_targets(y)
#     201 sample_weight = np.asarray(
#     202     [] if sample_weight is None else sample_weight, dtype=np.float64
#     203 )
#     204 solver_type = LIBSVM_IMPL.index(self._impl)
#
# File ~/PyEnv/PB/lib/python3.11/site-packages/sklearn/svm/_base.py:747, in BaseSVC._validate_targets(self, y)
#     745 self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#     746 if len(cls) < 2:
# --> 747     raise ValueError(
#     748         "The number of classes has to be greater than one; got %d class"
#     749         % len(cls)
#     750     )
#     752 self.classes_ = cls
#     754 return np.asarray(y, dtype=np.float64, order="C")
#
# ValueError: The number of classes has to be greater than one; got 1 class

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns

# Cargamos los datos
expr_data = pd.read_csv('exprMID.csv')
meth_data = pd.read_csv('methylMID.csv')
assig_data = pd.read_csv('assignMID.csv')
expr_data = expr_data.iloc[:, 1:]
meth_data = meth_data.iloc[:, 1:]
assig_data = assig_data.iloc[:, 2:]

# Convertir todas las columnas a tipo float
expr_data = expr_data.apply(pd.to_numeric, errors='coerce')
meth_data = meth_data.apply(pd.to_numeric, errors='coerce')
assig_data = assig_data.apply(pd.to_numeric, errors='coerce')
# Lidiar con valores NaN (si los hay). Pone 0(CAMBIAR)
expr_data.fillna(0, inplace=True)
meth_data.fillna(0, inplace=True)
assig_data.fillna(0, inplace=True)
# Aseguramos que las dimensiones coincidan
assert expr_data.shape[0] == meth_data.shape[0] == assig_data.shape[0], "Las dimensiones de los archivos no coinciden"

# Combinamos los datos de expresión génica y metilación
X = pd.concat([expr_data, meth_data], axis=1)
y = assig_data.iloc[:, 0].values  # Suponiendo que la asignación está en la primera columna

# Dividimos los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Entrenamos el modelo SVC
clf = SVC()
clf.fit(X_train, y_train)

# Predicciones
y_pred = clf.predict(X_test)

# Métricas de clasificación
print(classification_report(y_test, y_pred))

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     23934
#            2       1.00      1.00      1.00      6066
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns

# Cargamos los datos
expr_data = pd.read_csv('exprMID.csv')
meth_data = pd.read_csv('methylMID.csv')
assig_data = pd.read_csv('assignMID.csv')
expr_data = expr_data.iloc[:, 1:]
meth_data = meth_data.iloc[:, 1:]
assig_data = assig_data.iloc[:, 2:]

# Convertir todas las columnas a tipo float
expr_data = expr_data.apply(pd.to_numeric, errors='coerce')
meth_data = meth_data.apply(pd.to_numeric, errors='coerce')
assig_data = assig_data.apply(pd.to_numeric, errors='coerce')
# Lidiar con valores NaN (si los hay). Pone 0(CAMBIAR)
expr_data.fillna(0, inplace=True)
meth_data.fillna(0, inplace=True)
assig_data.fillna(0, inplace=True)
# Aseguramos que las dimensiones coincidan
assert expr_data.shape[0] == meth_data.shape[0] == assig_data.shape[0], "Las dimensiones de los archivos no coinciden"

# Combinamos los datos de expresión génica y metilación
X = meth_data
y = assig_data.iloc[:, 0].values  # Suponiendo que la asignación está en la primera columna

# Dividimos los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Entrenamos el modelo SVC
clf = SVC()
clf.fit(X_train, y_train)

# Predicciones
y_pred = clf.predict(X_test)

# Métricas de clasificación
print(classification_report(y_test, y_pred))

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     23934
#            2       1.00      1.00      1.00      6066
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
