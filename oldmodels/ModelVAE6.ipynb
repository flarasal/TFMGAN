# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import time

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
    
class VAE(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim):
        super(VAE, self).__init__()

        # Encoder
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 2 * latent_dim)  # 2 for mean and variance
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim)
        )

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mu + eps*std

    def forward(self, x):
        h = self.encoder(x)
        mu, logvar = torch.chunk(h, 2, dim=1)
        z = self.reparameterize(mu, logvar)
        recon = self.decoder(z)
        recon = torch.tanh(recon) * 10  # scale output to range -10 to 10
        return recon, mu, logvar

        
# Leer datos
expression_data = pd.read_csv('expr.csv')
methylation_data = pd.read_csv('methyl.csv')
assign_data = pd.read_csv('assign.csv')

expression_data = expression_data.iloc[:, 1:]
methylation_data = methylation_data.iloc[:, 1:]
assign_data = assign_data.iloc[:, 2:]

# Convertir todas las columnas a tipo float
expression_data = expression_data.apply(pd.to_numeric, errors='coerce')
methylation_data = methylation_data.apply(pd.to_numeric, errors='coerce')
assign_data = assign_data.apply(pd.to_numeric, errors='coerce')
# Lidiar con valores NaN (si los hay). Pone 0(CAMBIAR)
expression_data.fillna(0, inplace=True)
methylation_data.fillna(0, inplace=True)
assign_data.fillna(0, inplace=True)

expression_data = expression_data.values
methylation_data = methylation_data.values
assign_data=assign_data.values
# Asegurar que tienes el mismo número de muestras en ambos conjuntos de datos


assert expression_data.shape[0] == methylation_data.shape[0], "Los datos de expresión y metilación deben tener el mismo número de muestras."
assert assign_data.shape[0] == methylation_data.shape[0], "Los datos de asignación y metilación deben tener el mismo número de muestras."

# Concatenar los datos
#combined_data =torch.FloatTensor(np.hstack((expression_data, methylation_data,assign_data)))
print(torch.cuda.is_available())
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device="cpu"
expression_data = torch.FloatTensor(expression_data).to(device)
methylation_data = torch.FloatTensor(methylation_data).to(device)
assign_data = torch.FloatTensor(assign_data).to(device)
combined_data = torch.cat((expression_data,methylation_data,assign_data), 1).to(device)
# Out:
# True

# %%
# Modelos y optimizadores
vae = VAE(combined_data.shape[1], 512, 100000).to(device)
print(f'El modelo VAE tiene {count_parameters(vae)} parámetros entrenables.')
vae_optimizer = optim.Adam(vae.parameters(), lr=0.0002)

# Función de pérdida para VAE
def loss_vae(recon_x, x, mu, logvar):
    recon_loss = nn.MSELoss(reduction='sum')(recon_x, x)
    kl_divergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return recon_loss + kl_divergence

# Entrenamiento
n_samples = combined_data.size(0)
batch_size = 64
n_epochs = 10000
start_time = time.time()
for epoch in range(n_epochs):
    for idx in range(0, n_samples, batch_size):
        real_data = combined_data[idx:idx+batch_size].to(device)

        vae_optimizer.zero_grad()
        
        recon_data, mu, logvar = vae(real_data)
        loss = loss_vae(recon_data, real_data, mu, logvar)
        loss.backward()
        vae_optimizer.step()

    if (epoch+1) % 100 == 0:
        print(f"Epoch {epoch+1}/{n_epochs} | Loss: {loss.item()}")
        end_time = time.time()

        # Calcular la diferencia de tiempo
        elapsed_time = end_time - start_time

        print(f"El código tardó {elapsed_time:.5f} segundos en ejecutarse.")
        start_time = time.time()

torch.save(vae.state_dict(), 'vae_model.pth')
# Out:
# El modelo VAE tiene 154312499 parámetros entrenables.
# Epoch 100/10000 | Loss: 9117.5419921875
# El código tardó 35.15352 segundos en ejecutarse.
# Epoch 200/10000 | Loss: 7930.0947265625
# El código tardó 35.41659 segundos en ejecutarse.
# Epoch 300/10000 | Loss: 8360.7802734375
# El código tardó 35.48747 segundos en ejecutarse.
# Epoch 400/10000 | Loss: 7550.51904296875
# El código tardó 35.48128 segundos en ejecutarse.
# Epoch 500/10000 | Loss: 7839.181640625
# El código tardó 35.50303 segundos en ejecutarse.
# Epoch 600/10000 | Loss: 6787.9814453125
# El código tardó 35.51539 segundos en ejecutarse.
# Epoch 700/10000 | Loss: 6797.2646484375
# El código tardó 35.54914 segundos en ejecutarse.
# Epoch 800/10000 | Loss: 6461.25390625
# El código tardó 35.56588 segundos en ejecutarse.
# Epoch 900/10000 | Loss: 6348.841796875
# El código tardó 35.58943 segundos en ejecutarse.
# Epoch 1000/10000 | Loss: 5909.1796875
# El código tardó 35.62864 segundos en ejecutarse.
# Epoch 1100/10000 | Loss: 5631.4736328125
# El código tardó 35.65010 segundos en ejecutarse.
# Epoch 1200/10000 | Loss: 5820.46875
# El código tardó 35.65947 segundos en ejecutarse.
# Epoch 1300/10000 | Loss: 5604.97021484375
# El código tardó 35.65750 segundos en ejecutarse.
# Epoch 1400/10000 | Loss: 5699.4462890625
# El código tardó 35.66884 segundos en ejecutarse.
# Epoch 1500/10000 | Loss: 5816.2109375
# El código tardó 35.68319 segundos en ejecutarse.
# Epoch 1600/10000 | Loss: 5490.470703125
# El código tardó 35.66825 segundos en ejecutarse.
# Epoch 1700/10000 | Loss: 5494.48046875
# El código tardó 35.66373 segundos en ejecutarse.
# Epoch 1800/10000 | Loss: 5479.14306640625
# El código tardó 35.66911 segundos en ejecutarse.
# Epoch 1900/10000 | Loss: 5515.591796875
# El código tardó 35.66607 segundos en ejecutarse.
# Epoch 2000/10000 | Loss: 5512.232421875
# El código tardó 35.64842 segundos en ejecutarse.
# Epoch 2100/10000 | Loss: 5428.984375
# El código tardó 35.65450 segundos en ejecutarse.
# Epoch 2200/10000 | Loss: 5440.2529296875
# El código tardó 35.65118 segundos en ejecutarse.
# Epoch 2300/10000 | Loss: 5320.3388671875
# El código tardó 35.65475 segundos en ejecutarse.
# Epoch 2400/10000 | Loss: 5400.96337890625
# El código tardó 35.65136 segundos en ejecutarse.
# Epoch 2500/10000 | Loss: 5473.99072265625
# El código tardó 35.64622 segundos en ejecutarse.
# Epoch 2600/10000 | Loss: 5437.265625
# El código tardó 35.64043 segundos en ejecutarse.
# Epoch 2700/10000 | Loss: 5352.548828125
# El código tardó 35.63426 segundos en ejecutarse.
# Epoch 2800/10000 | Loss: 5427.91162109375
# El código tardó 35.62341 segundos en ejecutarse.
# Epoch 2900/10000 | Loss: 5461.78076171875
# El código tardó 35.60738 segundos en ejecutarse.
# Epoch 3000/10000 | Loss: 5620.8935546875
# El código tardó 35.60714 segundos en ejecutarse.
# Epoch 3100/10000 | Loss: 5451.642578125
# El código tardó 35.60944 segundos en ejecutarse.
# Epoch 3200/10000 | Loss: 5447.80908203125
# El código tardó 35.61408 segundos en ejecutarse.
# Epoch 3300/10000 | Loss: 5614.01953125
# El código tardó 35.61016 segundos en ejecutarse.
# Epoch 3400/10000 | Loss: 5553.55078125
# El código tardó 35.59666 segundos en ejecutarse.
# Epoch 3500/10000 | Loss: 5567.939453125
# El código tardó 35.59635 segundos en ejecutarse.
# Epoch 3600/10000 | Loss: 5469.5849609375
# El código tardó 35.59203 segundos en ejecutarse.
# Epoch 3700/10000 | Loss: 5278.36474609375
# El código tardó 35.58438 segundos en ejecutarse.
# Epoch 3800/10000 | Loss: 5503.03955078125
# El código tardó 35.57047 segundos en ejecutarse.
# Epoch 3900/10000 | Loss: 5670.47705078125
# El código tardó 35.55274 segundos en ejecutarse.
# Epoch 4000/10000 | Loss: 5651.6240234375
# El código tardó 35.55991 segundos en ejecutarse.
# Epoch 4100/10000 | Loss: 5643.6591796875
# El código tardó 35.54681 segundos en ejecutarse.
# Epoch 4200/10000 | Loss: 5491.4619140625
# El código tardó 35.52750 segundos en ejecutarse.
# Epoch 4300/10000 | Loss: 5763.390625
# El código tardó 35.52406 segundos en ejecutarse.
# Epoch 4400/10000 | Loss: 5630.455078125
# El código tardó 35.51639 segundos en ejecutarse.
# Epoch 4500/10000 | Loss: 5650.4462890625
# El código tardó 35.52183 segundos en ejecutarse.
# Epoch 4600/10000 | Loss: 5401.69775390625
# El código tardó 35.52757 segundos en ejecutarse.
# Epoch 4700/10000 | Loss: 5641.89404296875
# El código tardó 35.51203 segundos en ejecutarse.
# Epoch 4800/10000 | Loss: 5628.06005859375
# El código tardó 35.49845 segundos en ejecutarse.
# Epoch 4900/10000 | Loss: 5557.77978515625
# El código tardó 35.50252 segundos en ejecutarse.
# Epoch 5000/10000 | Loss: 5777.1708984375
# El código tardó 35.48934 segundos en ejecutarse.
# Epoch 5100/10000 | Loss: 5893.453125
# El código tardó 35.47905 segundos en ejecutarse.
# Epoch 5200/10000 | Loss: 5623.83203125
# El código tardó 35.48436 segundos en ejecutarse.
# Epoch 5300/10000 | Loss: 5573.45654296875
# El código tardó 35.47817 segundos en ejecutarse.
# Epoch 5400/10000 | Loss: 5484.92333984375
# El código tardó 35.48544 segundos en ejecutarse.
# Epoch 5500/10000 | Loss: 5677.27734375
# El código tardó 35.49440 segundos en ejecutarse.
# Epoch 5600/10000 | Loss: 5520.0390625
# El código tardó 35.50938 segundos en ejecutarse.
# Epoch 5700/10000 | Loss: 5612.9765625
# El código tardó 35.50157 segundos en ejecutarse.
# Epoch 5800/10000 | Loss: 5593.64990234375
# El código tardó 35.49715 segundos en ejecutarse.
# Epoch 5900/10000 | Loss: 5463.302734375
# El código tardó 35.48619 segundos en ejecutarse.
# Epoch 6000/10000 | Loss: 5722.0439453125
# El código tardó 35.48662 segundos en ejecutarse.
# Epoch 6100/10000 | Loss: 5518.35009765625
# El código tardó 35.49018 segundos en ejecutarse.
# Epoch 6200/10000 | Loss: 5643.5908203125
# El código tardó 35.48796 segundos en ejecutarse.
# Epoch 6300/10000 | Loss: 5683.7138671875
# El código tardó 35.48464 segundos en ejecutarse.
# Epoch 6400/10000 | Loss: 5548.49462890625
# El código tardó 35.49415 segundos en ejecutarse.
# Epoch 6500/10000 | Loss: 5462.9443359375
# El código tardó 35.50276 segundos en ejecutarse.
# Epoch 6600/10000 | Loss: 5737.337890625
# El código tardó 35.49771 segundos en ejecutarse.
# Epoch 6700/10000 | Loss: 7922.615234375
# El código tardó 35.49713 segundos en ejecutarse.
# Epoch 6800/10000 | Loss: 5529.64599609375
# El código tardó 35.50242 segundos en ejecutarse.
# Epoch 6900/10000 | Loss: 5943.0732421875
# El código tardó 35.51003 segundos en ejecutarse.
# Epoch 7000/10000 | Loss: 5693.228515625
# El código tardó 35.52408 segundos en ejecutarse.
# Epoch 7100/10000 | Loss: 5667.10595703125
# El código tardó 35.54576 segundos en ejecutarse.
# Epoch 7200/10000 | Loss: 5637.8876953125
# El código tardó 35.54374 segundos en ejecutarse.
# Epoch 7300/10000 | Loss: 5747.9765625
# El código tardó 35.53806 segundos en ejecutarse.
# Epoch 7400/10000 | Loss: 5556.978515625
# El código tardó 35.54057 segundos en ejecutarse.
# Epoch 7500/10000 | Loss: 5738.5234375
# El código tardó 35.53837 segundos en ejecutarse.
# Epoch 7600/10000 | Loss: 5866.7900390625
# El código tardó 35.53757 segundos en ejecutarse.
# Epoch 7700/10000 | Loss: 5747.810546875
# El código tardó 35.53745 segundos en ejecutarse.
# Epoch 7800/10000 | Loss: 5475.67138671875
# El código tardó 35.53749 segundos en ejecutarse.
# Epoch 7900/10000 | Loss: 5624.92626953125
# El código tardó 35.54051 segundos en ejecutarse.
# Epoch 8000/10000 | Loss: 5643.22900390625
# El código tardó 35.54119 segundos en ejecutarse.
# Epoch 8100/10000 | Loss: 5460.5078125
# El código tardó 35.53297 segundos en ejecutarse.
# Epoch 8200/10000 | Loss: 5712.54833984375
# El código tardó 35.50661 segundos en ejecutarse.
# Epoch 8300/10000 | Loss: 5932.74462890625
# El código tardó 35.49682 segundos en ejecutarse.
# Epoch 8400/10000 | Loss: 5693.06884765625
# El código tardó 35.49880 segundos en ejecutarse.
# Epoch 8500/10000 | Loss: 5714.4228515625
# El código tardó 35.48546 segundos en ejecutarse.
# Epoch 8600/10000 | Loss: 5653.01806640625
# El código tardó 35.47642 segundos en ejecutarse.
# Epoch 8700/10000 | Loss: 6023.1826171875
# El código tardó 35.47047 segundos en ejecutarse.
# Epoch 8800/10000 | Loss: 5445.81298828125
# El código tardó 35.47209 segundos en ejecutarse.
# Epoch 8900/10000 | Loss: 5706.142578125
# El código tardó 35.46995 segundos en ejecutarse.
# Epoch 9000/10000 | Loss: 5632.93359375
# El código tardó 35.46612 segundos en ejecutarse.
# Epoch 9100/10000 | Loss: 5851.337890625
# El código tardó 35.45562 segundos en ejecutarse.
# Epoch 9200/10000 | Loss: 6041.6025390625
# El código tardó 35.45912 segundos en ejecutarse.
# Epoch 9300/10000 | Loss: 5781.2646484375
# El código tardó 35.45456 segundos en ejecutarse.
# Epoch 9400/10000 | Loss: 5649.0244140625
# El código tardó 35.45336 segundos en ejecutarse.
# Epoch 9500/10000 | Loss: 5596.5107421875
# El código tardó 35.46733 segundos en ejecutarse.
# Epoch 9600/10000 | Loss: 5673.8837890625
# El código tardó 35.46179 segundos en ejecutarse.
# Epoch 9700/10000 | Loss: 5750.69140625
# El código tardó 35.46509 segundos en ejecutarse.
# Epoch 9800/10000 | Loss: 5612.173828125
# El código tardó 35.44175 segundos en ejecutarse.
# Epoch 9900/10000 | Loss: 5743.19140625
# El código tardó 35.43888 segundos en ejecutarse.
# Epoch 10000/10000 | Loss: 5762.77783203125
# El código tardó 35.44432 segundos en ejecutarse.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns

vae = VAE(combined_data.shape[1], 512, 100000).to(device)
vae.load_state_dict(torch.load('vae_model.pth'))
vae.eval()

# Función para reparametrización (para generar muestras del espacio latente)

# Generar datos de expresión sintética
expressions_list = []
for i in range(10000):
    with torch.no_grad():
        # Puedes elegir mu y logvar como quieras, pero una opción común es usar 0 y 1
        mu = torch.zeros(1, 100000).to(device)
        logvar = torch.ones(1, 100000).to(device)
        
        z = vae.reparameterize(mu, logvar).to(device)
        synthetic_expression = vae.decoder(z).to(device)
        #print(synthetic_expression)
        expressions_list.append(synthetic_expression.detach().cpu().numpy().squeeze())

X = pd.DataFrame(expressions_list)
#X = X.apply(pd.to_numeric, errors='coerce')
y = X.iloc[:, -1].values.astype(int)  # Suponiendo que la asignación está en la primera columna

X = X.iloc[:, :-1]
# Dividimos los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Entrenamos el modelo SVC
clf = SVC()
clf.fit(X_train, y_train)

# Predicciones
y_pred = clf.predict(X_test)

# Métricas de clasificación
print(classification_report(y_test, y_pred))

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#           -2       0.00      0.00      0.00        10
#           -1       0.74      0.54      0.63       199
#            0       0.96      0.99      0.98      2773
#            1       0.00      0.00      0.00        18
#
#     accuracy                           0.95      3000
#    macro avg       0.43      0.38      0.40      3000
# weighted avg       0.94      0.95      0.94      3000
# /home/fede/PyEnv/PB/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fede/PyEnv/PB/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fede/PyEnv/PB/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns

# Cargamos los datos
expr_data = pd.read_csv('exprLOW.csv')
meth_data = pd.read_csv('methylLOW.csv')
assig_data = pd.read_csv('assignLOW.csv')
expr_data = expr_data.iloc[:, 1:]
meth_data = meth_data.iloc[:, 1:]
assig_data = assig_data.iloc[:, 2:]

# Convertir todas las columnas a tipo float
expr_data = expr_data.apply(pd.to_numeric, errors='coerce')
meth_data = meth_data.apply(pd.to_numeric, errors='coerce')
assig_data = assig_data.apply(pd.to_numeric, errors='coerce')
# Lidiar con valores NaN (si los hay). Pone 0(CAMBIAR)
expr_data.fillna(0, inplace=True)
meth_data.fillna(0, inplace=True)
assig_data.fillna(0, inplace=True)
# Aseguramos que las dimensiones coincidan
assert expr_data.shape[0] == meth_data.shape[0] == assig_data.shape[0], "Las dimensiones de los archivos no coinciden"

# Combinamos los datos de expresión génica y metilación
X = pd.concat([expr_data, meth_data], axis=1)
y = assig_data.iloc[:, 0].values  # Suponiendo que la asignación está en la primera columna

# Dividimos los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Entrenamos el modelo SVC
clf = SVC()
clf.fit(X_train, y_train)

# Predicciones
y_pred = clf.predict(X_test)

# Métricas de clasificación
print(classification_report(y_test, y_pred))

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      2370
#            2       1.00      1.00      1.00       630
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns

# Cargamos los datos
expr_data = pd.read_csv('exprMID.csv')
meth_data = pd.read_csv('methylMID.csv')
assig_data = pd.read_csv('assignMID.csv')
expr_data = expr_data.iloc[:, 1:]
meth_data = meth_data.iloc[:, 1:]
assig_data = assig_data.iloc[:, 2:]

# Convertir todas las columnas a tipo float
expr_data = expr_data.apply(pd.to_numeric, errors='coerce')
meth_data = meth_data.apply(pd.to_numeric, errors='coerce')
assig_data = assig_data.apply(pd.to_numeric, errors='coerce')
# Lidiar con valores NaN (si los hay). Pone 0(CAMBIAR)
expr_data.fillna(0, inplace=True)
meth_data.fillna(0, inplace=True)
assig_data.fillna(0, inplace=True)
# Aseguramos que las dimensiones coincidan
assert expr_data.shape[0] == meth_data.shape[0] == assig_data.shape[0], "Las dimensiones de los archivos no coinciden"

# Combinamos los datos de expresión génica y metilación
X = meth_data
y = assig_data.iloc[:, 0].values  # Suponiendo que la asignación está en la primera columna

# Dividimos los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Entrenamos el modelo SVC
clf = SVC()
clf.fit(X_train, y_train)

# Predicciones
y_pred = clf.predict(X_test)

# Métricas de clasificación
print(classification_report(y_test, y_pred))

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     23934
#            2       1.00      1.00      1.00      6066
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
