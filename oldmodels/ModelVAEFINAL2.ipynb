# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import time
from sklearn.preprocessing import MinMaxScaler,StandardScaler

fnexpr='exprLOW.csv'
fnmet='methylLOW.csv'
fnassig='assignLOW.csv'
nsamp=10000
fnmodel='generator_modelVAE10-10k.pth'
filename = "modelvae10-"
save= False
ldim=100
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
    
class VAE(nn.Module):
    def __init__(self, input_dim_exp, input_dim_meth,input_dim_assig, latent_dim):
        super(VAE, self).__init__()

        # Capas específicas para datos de expresión
        self.exp_encoder = nn.Sequential(
            nn.Linear(input_dim_exp, 1024),
            nn.LeakyReLU(0.2)
        )

        # Capas específicas para datos de metilación
        self.meth_encoder = nn.Sequential(
            nn.Linear(input_dim_meth, 1024),
            nn.LeakyReLU(0.2)
        )

        # Capas específicas para datos de asignación
        self.assig_encoder = nn.Sequential(
            nn.Linear(input_dim_assig, 16),
            nn.LeakyReLU(0.2)
        )

        # Capa combinada después de procesar ambos tipos de datos
        self.combined_encoder = nn.Sequential(
            nn.Linear(2064, 1024),
            nn.LeakyReLU(0.2),
            nn.Linear(1024, 2 * latent_dim)  # 2 for mean and variance
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 2048),
            nn.ReLU(),
            nn.Linear(2048, 4096),
            nn.ReLU(),
            nn.Linear(4096, input_dim_exp + input_dim_meth+ input_dim_assig)
        )

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mu + eps*std

    def forward(self, x_exp, x_meth,x_assig):
        h_exp = self.exp_encoder(x_exp)
        h_meth = self.meth_encoder(x_meth)
        h_assig = self.assig_encoder(x_assig)
        # Combina las representaciones codificadas de expresión y metilación
        h_combined = torch.cat((h_exp, h_meth,h_assig), dim=1)
        h = self.combined_encoder(h_combined)

        mu, logvar = torch.chunk(h, 2, dim=1)
        z = self.reparameterize(mu, logvar)
        recon = self.decoder(z)
        return recon, mu, logvar
        
# Leer datos
expression_data = pd.read_csv(fnexpr)
methylation_data = pd.read_csv(fnmet)
assign_data = pd.read_csv(fnassig)

expression_data = expression_data.iloc[:, 1:]
methylation_data = methylation_data.iloc[:, 1:]
assign_data = assign_data.iloc[:, 2:]

# Convertir todas las columnas a tipo float
expression_data = expression_data.apply(pd.to_numeric, errors='coerce')
methylation_data = methylation_data.apply(pd.to_numeric, errors='coerce')
assign_data = assign_data.apply(pd.to_numeric, errors='coerce')
# Lidiar con valores NaN (si los hay). 
#expression_data.fillna(0, inplace=True)
#methylation_data.fillna(0, inplace=True)
#assign_data.fillna(0, inplace=True)



# Normalizacion
scaler = StandardScaler()


expression_data_scaled = scaler.fit_transform(expression_data)
methylation_data_scaled = scaler.fit_transform(methylation_data)
assign_data_scaled =assign_data

# Convertir de vuelta a DataFrames
expression_data = pd.DataFrame(expression_data_scaled, index=expression_data.index, columns=expression_data.columns)
methylation_data = pd.DataFrame(methylation_data_scaled, index=methylation_data.index, columns=methylation_data.columns)
assign_data = pd.DataFrame(assign_data_scaled, index=assign_data.index, columns=assign_data.columns)

print(torch.cuda.is_available())
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device="cpu"

# Convertirlos a tensores y pasarlos a la GPU
expression_data = torch.FloatTensor(expression_data.values).to(device)
methylation_data = torch.FloatTensor(methylation_data.values).to(device)
assign_data = torch.FloatTensor(assign_data.values).to(device)

combined_data = torch.cat((expression_data,methylation_data,assign_data), 1).to(device)
# Out:
# True

# %%
# Modelos y optimizadores
vae = VAE(expression_data.shape[1],methylation_data.shape[1],assign_data.shape[1],ldim).to(device)
print(f'El modelo VAE tiene {count_parameters(vae)} parámetros entrenables.')
vae_optimizer = optim.RMSprop(vae.parameters(), lr=0.0002)

# Función de pérdida para VAE
def loss_vae(recon_x, x, mu, logvar):
    recon_loss = nn.MSELoss(reduction='sum')(recon_x, x)  # pérdida de reconstrucción
    #recon_loss = nn.BCELoss(reduction='sum')(recon_x, x)
    kl_divergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())  # divergencia KL
    total_loss = recon_loss + kl_divergence
    return total_loss, recon_loss, kl_divergence

# Entrenamiento
n_samples = combined_data.size(0)
batch_size = 64
n_epochs = 10000
start_time = time.time()
for epoch in range(n_epochs):
    epoch_recon_loss = 0.0
    epoch_kl_divergence = 0.0
    for idx in range(0, n_samples, batch_size):
        real_data = combined_data[idx:idx+batch_size].to(device)
        real_data_expr = expression_data[idx:idx+batch_size].to(device)
        real_data_meth = methylation_data[idx:idx+batch_size].to(device)
        real_data_assig = assign_data[idx:idx+batch_size].to(device)
        
        vae_optimizer.zero_grad()
        
        recon_data, mu, logvar = vae(real_data_expr,real_data_meth,real_data_assig)
        if ((epoch+1) % 100 == 0) and (idx ==0):
                print(recon_data)
        loss, recon_loss, kl_div = loss_vae(recon_data, real_data, mu, logvar)
        epoch_recon_loss += recon_loss.item()
        epoch_kl_divergence += kl_div.item()
        loss.backward()
              # Verificar si la pérdida es NaN
        if torch.isnan(loss):
            print("NaN detected!")
            break
        torch.nn.utils.clip_grad_norm_(vae.parameters(), max_norm=1.0)
        vae_optimizer.step()

    if (epoch+1) % 100 == 0:
        print(f"Epoch {epoch+1}/{n_epochs} | Total Loss: {loss.item()} | Recon Loss: {epoch_recon_loss/n_samples} | KL Div: {epoch_kl_divergence/n_samples}")
        end_time = time.time()

        # Calcular la diferencia de tiempo
        elapsed_time = end_time - start_time

        print(f"El código tardó {elapsed_time:.5f} segundos en ejecutarse.")
        start_time = time.time()

torch.save(vae.state_dict(), fnmodel)
# Out:
# El modelo VAE tiene 13475547 parámetros entrenables.
# tensor([[-0.5840,  0.0183,  0.3175,  ...,  0.7195,  1.5728,  0.9982],
#         [-0.3608, -0.3881,  0.4216,  ..., -0.0832,  0.5791,  1.0373],
#         [-0.3508, -0.0219, -0.1119,  ...,  0.4011,  0.6749,  0.9972],
#         ...,
#         [-0.0735, -1.9790,  0.3452,  ...,  0.5722,  6.2860,  1.0479],
#         [-0.4474,  0.0148,  0.3997,  ...,  0.4247,  1.0089,  1.0296],
#         [-0.5741,  0.9037,  0.3041,  ...,  0.7378, -0.2451,  1.0529]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 100/10000 | Total Loss: 1574.9776611328125 | Recon Loss: 96.08312286376953 | KL Div: 42.807141821289065
# El código tardó 91.05857 segundos en ejecutarse.
# tensor([[-0.5349,  0.9949,  0.3057,  ...,  0.5370,  1.6910,  0.9569],
#         [-0.3372, -0.7960,  0.3890,  ..., -0.3551,  0.6581,  0.9924],
#         [-0.3202,  0.0528, -0.1226,  ...,  1.4084,  0.5130,  0.9628],
#         ...,
#         [-0.2664, -1.1620,  0.3749,  ...,  2.8033,  6.6350,  1.0262],
#         [-0.6273, -0.3784,  0.4827,  ...,  0.1974,  1.2586,  0.9647],
#         [-0.4845,  0.5962,  0.3528,  ...,  1.0625, -0.0551,  0.9833]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 200/10000 | Total Loss: 1258.749755859375 | Recon Loss: 67.94457840576172 | KL Div: 47.422732360839845
# El código tardó 89.81963 segundos en ejecutarse.
# tensor([[-0.5635,  1.1973,  0.3506,  ...,  0.6949,  1.9512,  0.9961],
#         [-0.2732,  0.0576,  0.3148,  ..., -1.6112,  0.5028,  0.9525],
#         [-0.3485,  0.1048, -0.1955,  ...,  0.7622,  0.5339,  0.9730],
#         ...,
#         [-0.0616, -1.6402,  0.0966,  ...,  2.9912,  6.9615,  1.0312],
#         [-0.5836, -0.9610,  0.3297,  ...,  0.1411,  1.2235,  1.0086],
#         [-0.5666,  0.5044,  0.2850,  ...,  0.7992, -0.3836,  0.9765]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 300/10000 | Total Loss: 1145.6339111328125 | Recon Loss: 54.50163380737305 | KL Div: 49.02632606811523
# El código tardó 91.01836 segundos en ejecutarse.
# tensor([[-0.6385,  0.7787,  0.4028,  ...,  0.3039,  2.0502,  1.0061],
#         [-0.4457, -0.5770,  0.6003,  ..., -1.1985,  0.6096,  1.0005],
#         [-0.2702, -0.2743, -0.1291,  ...,  0.6112,  0.4652,  0.9894],
#         ...,
#         [-0.2379, -2.1422,  0.3353,  ...,  1.4810,  6.9081,  1.0348],
#         [-0.5050, -0.5065,  0.3241,  ...,  0.5539,  1.2495,  1.0280],
#         [-0.6815,  0.7422,  0.4458,  ...,  0.9179, -0.0888,  0.9977]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 400/10000 | Total Loss: 1157.18603515625 | Recon Loss: 47.425071856689456 | KL Div: 49.50179294433594
# El código tardó 91.01722 segundos en ejecutarse.
# tensor([[-0.5798,  0.8663,  0.2882,  ...,  0.5153,  1.9345,  1.0078],
#         [-0.3756,  0.2562,  0.3124,  ..., -1.4612,  0.7337,  0.9926],
#         [-0.2432,  0.0647, -0.0208,  ..., -0.0552,  0.8151,  1.0027],
#         ...,
#         [-0.1701, -2.0023,  0.1088,  ...,  1.9780,  6.9928,  1.0593],
#         [-0.4615, -0.2961,  0.3235,  ..., -0.0385,  0.6345,  0.9887],
#         [-0.7303,  0.7231,  0.2683,  ...,  1.2458,  0.0681,  0.9904]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 500/10000 | Total Loss: 1124.84228515625 | Recon Loss: 43.02771019897461 | KL Div: 49.476402734375
# El código tardó 91.23133 segundos en ejecutarse.
# tensor([[-0.6219,  0.6495,  0.2637,  ...,  0.2160,  2.0748,  1.0166],
#         [-0.4167,  0.2236,  0.4800,  ..., -1.1320,  0.6979,  0.9974],
#         [-0.2476, -0.3394,  0.0813,  ...,  0.2735,  0.4625,  0.9930],
#         ...,
#         [-0.1364, -2.3988, -0.0118,  ...,  0.9877,  6.2321,  1.0269],
#         [-0.5775, -0.2768,  0.2818,  ..., -0.6239,  0.8095,  0.9913],
#         [-0.8356,  0.6049,  0.3591,  ...,  1.1547, -0.1636,  0.9953]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 600/10000 | Total Loss: 1067.7999267578125 | Recon Loss: 40.10815116882324 | KL Div: 48.9574385925293
# El código tardó 90.78728 segundos en ejecutarse.
# tensor([[-0.5845,  0.9017,  0.5330,  ...,  0.3407,  1.7424,  1.0033],
#         [-0.2837, -0.4692,  0.5115,  ..., -1.6028,  0.6369,  0.9862],
#         [-0.2343, -0.2679, -0.3171,  ...,  0.7304,  0.4159,  1.0036],
#         ...,
#         [-0.1501, -2.0907,  0.2076,  ...,  1.6283,  6.6106,  1.0487],
#         [-0.5429, -0.2320,  0.2384,  ..., -0.6955,  0.7755,  0.9982],
#         [-0.7670,  0.5985,  0.3448,  ...,  1.5484, -0.0112,  1.0047]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 700/10000 | Total Loss: 1050.806640625 | Recon Loss: 37.7854158203125 | KL Div: 48.63510590209961
# El código tardó 91.55432 segundos en ejecutarse.
# tensor([[-0.5009,  0.5189,  0.4947,  ...,  0.4667,  1.6364,  1.0062],
#         [-0.3439,  0.7791,  0.5318,  ..., -0.8685,  0.9813,  1.0053],
#         [-0.1921, -0.3870, -0.1672,  ...,  1.1643,  0.5073,  1.0308],
#         ...,
#         [-0.2314, -2.0913,  0.1617,  ...,  2.1715,  6.1176,  0.9980],
#         [-0.6138, -0.2615,  0.2004,  ..., -0.1801,  0.8968,  1.0176],
#         [-0.6746,  0.8904,  0.2641,  ...,  0.9138, -0.1039,  1.0265]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 800/10000 | Total Loss: 1026.5098876953125 | Recon Loss: 36.06645987854004 | KL Div: 48.13394033203125
# El código tardó 90.68794 segundos en ejecutarse.
# tensor([[-0.5871,  0.6018,  0.4065,  ...,  0.3449,  1.3414,  1.0241],
#         [-0.2599, -0.4415,  0.5200,  ..., -1.1215,  0.9291,  1.0042],
#         [-0.3948, -0.2248, -0.2004,  ...,  1.0958,  0.6019,  1.0109],
#         ...,
#         [-0.2012, -2.3996,  0.1047,  ...,  1.1665,  6.6021,  1.0077],
#         [-0.6371, -0.4767,  0.1523,  ..., -0.2625,  1.2546,  1.0110],
#         [-0.7351,  0.2981,  0.3419,  ...,  1.3409, -0.0547,  1.0120]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 900/10000 | Total Loss: 993.3218383789062 | Recon Loss: 34.735469946289065 | KL Div: 47.889947918701175
# El código tardó 91.40875 segundos en ejecutarse.
# tensor([[-0.5995,  1.0185,  0.3851,  ...,  0.9302,  1.7699,  1.0119],
#         [-0.2977, -0.2519,  0.4089,  ..., -1.1466,  0.7360,  1.0026],
#         [-0.3740,  0.1371, -0.2406,  ...,  0.7574,  1.1178,  1.0188],
#         ...,
#         [-0.1149, -2.1370,  0.1108,  ...,  2.0710,  7.1423,  1.0248],
#         [-0.6981, -0.6859,  0.1812,  ..., -0.0751,  1.1346,  1.0017],
#         [-0.6951,  0.0148,  0.2597,  ...,  0.6769,  0.0998,  1.0093]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 1000/10000 | Total Loss: 1010.2435302734375 | Recon Loss: 33.69282971496582 | KL Div: 47.587235693359375
# El código tardó 91.48903 segundos en ejecutarse.
# tensor([[-0.3429,  0.8306,  0.2782,  ...,  0.0165,  1.4921,  1.0214],
#         [-0.3034, -0.5424,  0.5938,  ..., -1.4123,  0.7115,  1.0322],
#         [-0.2076, -0.1533, -0.3400,  ...,  0.7953,  0.9984,  1.0275],
#         ...,
#         [-0.3092, -1.6527, -0.0111,  ...,  2.8998,  6.9269,  0.9885],
#         [-0.6185, -0.6347,  0.2499,  ..., -0.4957,  1.0490,  1.0166],
#         [-0.6842,  0.7177,  0.2181,  ...,  0.8825,  0.1707,  1.0221]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 1100/10000 | Total Loss: 948.2737426757812 | Recon Loss: 32.7372733215332 | KL Div: 47.21873303222656
# El código tardó 91.81332 segundos en ejecutarse.
# tensor([[-0.6198,  1.2278,  0.4215,  ..., -0.0442,  1.7156,  1.0086],
#         [-0.2619, -0.4976,  0.6295,  ..., -1.5597,  0.8783,  0.9825],
#         [-0.1858,  0.1826, -0.3402,  ...,  1.6726,  0.9707,  1.0061],
#         ...,
#         [-0.2937, -1.6445,  0.0717,  ...,  1.2985,  7.2624,  1.0100],
#         [-0.7077, -0.4162,  0.4412,  ..., -0.3961,  0.7761,  0.9861],
#         [-0.7386,  0.2075,  0.4669,  ...,  0.5654, -0.1161,  0.9968]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 1200/10000 | Total Loss: 944.7364501953125 | Recon Loss: 31.907756552124024 | KL Div: 46.8173391418457
# El código tardó 92.69289 segundos en ejecutarse.
# tensor([[-0.5308,  0.9426,  0.3238,  ...,  0.2616,  1.5554,  0.9984],
#         [-0.3099, -0.0470,  0.6500,  ..., -0.8066,  0.9139,  1.0026],
#         [-0.2314, -0.3706, -0.1444,  ...,  0.5705,  0.7500,  1.0110],
#         ...,
#         [-0.2398, -2.0991, -0.0544,  ...,  1.6005,  6.5208,  0.9992],
#         [-0.5494, -0.4543,  0.2230,  ...,  0.2806,  1.0534,  1.0050],
#         [-0.7207,  0.1644,  0.3313,  ...,  0.7381, -0.1161,  1.0062]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 1300/10000 | Total Loss: 956.329833984375 | Recon Loss: 31.261542755126953 | KL Div: 46.61473695678711
# El código tardó 92.35120 segundos en ejecutarse.
# tensor([[-0.4459,  0.4302,  0.3362,  ...,  0.1793,  1.8649,  0.9981],
#         [-0.2683, -0.3974,  0.4617,  ..., -0.8261,  0.6929,  0.9950],
#         [-0.3288, -0.2918, -0.1355,  ...,  0.8708,  0.6426,  0.9918],
#         ...,
#         [-0.0989, -2.0598, -0.0724,  ...,  2.0430,  6.9146,  1.0336],
#         [-0.5612, -0.6780,  0.2839,  ..., -0.4290,  0.6042,  0.9921],
#         [-0.7591,  0.2251,  0.3760,  ...,  1.0648,  0.0315,  0.9828]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 1400/10000 | Total Loss: 971.936279296875 | Recon Loss: 30.664824365234374 | KL Div: 46.316791687011715
# El código tardó 91.75781 segundos en ejecutarse.
# tensor([[-0.5353,  0.7286,  0.3964,  ...,  0.6084,  1.8876,  0.9970],
#         [-0.2257, -0.2941,  0.4773,  ..., -1.1584,  1.0446,  1.0016],
#         [-0.3068,  0.2860, -0.1324,  ...,  0.8895,  0.5554,  1.0130],
#         ...,
#         [-0.2991, -2.2041,  0.0368,  ...,  2.1890,  7.6440,  0.9898],
#         [-0.6759, -0.6070,  0.3952,  ...,  0.0256,  0.8150,  0.9845],
#         [-0.6386,  0.4784,  0.5417,  ...,  1.0657, -0.0502,  1.0014]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 1500/10000 | Total Loss: 927.2412109375 | Recon Loss: 30.207933557128907 | KL Div: 46.0437083984375
# El código tardó 91.81020 segundos en ejecutarse.
# tensor([[-0.5318,  0.4133,  0.4861,  ...,  0.4739,  1.8786,  1.0049],
#         [-0.2617, -0.2623,  0.5605,  ..., -0.8252,  0.9635,  1.0009],
#         [-0.3923,  0.5913, -0.1098,  ...,  1.1522,  0.8156,  1.0018],
#         ...,
#         [-0.2787, -1.7545, -0.0088,  ...,  1.9695,  6.6666,  0.9751],
#         [-0.5935, -0.9263,  0.4347,  ...,  0.0424,  0.8444,  0.9845],
#         [-0.7623,  0.1868,  0.2501,  ...,  1.1309, -0.0169,  0.9932]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 1600/10000 | Total Loss: 904.9404296875 | Recon Loss: 29.64297945251465 | KL Div: 45.73263486328125
# El código tardó 91.11768 segundos en ejecutarse.
# tensor([[-0.3981,  0.9139,  0.2881,  ...,  0.2623,  1.8023,  1.0004],
#         [-0.2452,  0.5388,  0.4166,  ..., -1.1643,  1.1615,  0.9851],
#         [-0.3400, -0.1646, -0.2063,  ...,  0.5407,  0.4636,  1.0066],
#         ...,
#         [-0.1937, -1.9918, -0.1120,  ...,  2.7007,  6.5535,  0.9985],
#         [-0.4865, -0.9728,  0.3223,  ...,  0.1848,  1.0102,  0.9886],
#         [-0.7295,  0.1890,  0.2947,  ...,  0.5936, -0.0737,  0.9939]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 1700/10000 | Total Loss: 907.0591430664062 | Recon Loss: 29.132113671875 | KL Div: 45.56989844360351
# El código tardó 91.34190 segundos en ejecutarse.
# tensor([[-0.4296,  1.1503,  0.2304,  ...,  0.1247,  1.5076,  0.9861],
#         [-0.2350, -0.2367,  0.6508,  ..., -1.0852,  1.2148,  0.9937],
#         [-0.2575, -0.1825, -0.0859,  ...,  0.8120,  1.1482,  0.9860],
#         ...,
#         [-0.1442, -2.1187,  0.1632,  ...,  1.6750,  6.5691,  0.9965],
#         [-0.5716, -0.1121,  0.5008,  ..., -0.0086,  0.5282,  0.9735],
#         [-0.6610,  0.0344,  0.3982,  ...,  1.2639, -0.1312,  0.9884]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 1800/10000 | Total Loss: 947.020751953125 | Recon Loss: 28.751159155273438 | KL Div: 45.35575872802735
# El código tardó 92.32130 segundos en ejecutarse.
# tensor([[-0.4274,  0.8744,  0.4572,  ...,  0.1776,  1.3725,  1.0105],
#         [-0.3040, -0.0597,  0.6488,  ..., -1.1110,  1.3476,  1.0060],
#         [-0.2398, -0.0997, -0.0438,  ...,  0.9258,  0.9198,  1.0079],
#         ...,
#         [-0.1969, -1.5002, -0.0817,  ...,  1.3547,  6.5599,  1.0172],
#         [-0.5705, -0.4705,  0.4301,  ..., -0.1106,  0.8563,  0.9973],
#         [-0.6711,  0.4315,  0.1621,  ...,  1.4488, -0.0273,  1.0019]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 1900/10000 | Total Loss: 913.0589599609375 | Recon Loss: 28.342630883789063 | KL Div: 45.07006455078125
# El código tardó 91.30506 segundos en ejecutarse.
# tensor([[-0.5031,  0.7940,  0.3484,  ...,  0.2111,  1.5096,  1.0071],
#         [-0.2836,  0.3383,  0.6205,  ..., -0.4261,  1.2847,  1.0086],
#         [-0.2220, -0.4455, -0.1931,  ...,  0.9543,  0.9060,  0.9843],
#         ...,
#         [-0.3467, -1.9117,  0.1026,  ...,  1.4013,  7.2078,  1.0196],
#         [-0.5737, -0.6257,  0.3355,  ..., -0.0883,  1.1707,  0.9874],
#         [-0.7406,  0.0116,  0.2247,  ...,  1.2560,  0.1174,  0.9952]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 2000/10000 | Total Loss: 855.5516357421875 | Recon Loss: 27.98062536315918 | KL Div: 44.79102204589844
# El código tardó 91.05742 segundos en ejecutarse.
# tensor([[-0.5336,  1.3443,  0.2618,  ...,  0.2519,  1.6981,  0.9925],
#         [-0.3498, -0.4967,  0.6147,  ..., -1.1370,  1.2687,  0.9871],
#         [-0.3155, -0.5879, -0.0116,  ...,  1.0571,  0.9668,  1.0093],
#         ...,
#         [-0.2390, -1.8563,  0.0717,  ...,  1.2612,  7.4314,  0.9901],
#         [-0.5914, -1.0673,  0.3546,  ..., -0.4283,  0.8470,  1.0064],
#         [-0.6801,  0.3198,  0.3165,  ...,  1.5524,  0.1452,  0.9961]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 2100/10000 | Total Loss: 905.8919677734375 | Recon Loss: 27.643640887451173 | KL Div: 44.586220074462894
# El código tardó 91.76154 segundos en ejecutarse.
# tensor([[-0.5550,  1.1263,  0.1915,  ...,  0.3950,  1.9786,  1.0087],
#         [-0.2631, -0.1311,  0.5236,  ..., -1.2073,  0.8248,  0.9912],
#         [-0.2108, -0.0646, -0.1046,  ...,  1.0540,  1.2015,  1.0051],
#         ...,
#         [-0.2092, -2.0552,  0.1647,  ...,  1.5890,  7.5019,  0.9829],
#         [-0.5431, -0.3481,  0.2098,  ..., -0.2671,  0.6522,  1.0103],
#         [-0.6129,  0.9322,  0.2372,  ...,  0.9017,  0.1397,  1.0071]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 2200/10000 | Total Loss: 871.5477294921875 | Recon Loss: 27.148243844604494 | KL Div: 44.345730920410155
# El código tardó 91.54284 segundos en ejecutarse.
# tensor([[-0.4572,  0.3266,  0.2541,  ...,  0.6577,  1.3374,  1.0051],
#         [-0.3128,  0.1631,  0.6285,  ..., -0.9856,  1.1737,  0.9879],
#         [-0.1861, -0.0955, -0.0158,  ...,  0.8347,  0.8467,  1.0007],
#         ...,
#         [-0.1683, -1.5546,  0.1474,  ...,  2.1377,  6.9411,  0.9996],
#         [-0.5348, -0.3930,  0.3817,  ...,  0.3091,  0.8560,  0.9971],
#         [-0.7491,  0.0507,  0.1335,  ...,  1.7793,  0.2873,  0.9979]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 2300/10000 | Total Loss: 856.82861328125 | Recon Loss: 26.84635898132324 | KL Div: 44.32202752075195
# El código tardó 91.65016 segundos en ejecutarse.
# tensor([[-0.4951,  0.7375,  0.2547,  ...,  1.0066,  1.6230,  0.9964],
#         [-0.3351,  0.0761,  0.6118,  ..., -1.0685,  0.7564,  1.0030],
#         [-0.2748, -0.2842, -0.0601,  ...,  1.2460,  0.9752,  1.0068],
#         ...,
#         [-0.2050, -1.7593,  0.0449,  ...,  1.6939,  6.7752,  0.9957],
#         [-0.5121, -0.4010,  0.1992,  ..., -0.0702,  0.7142,  1.0072],
#         [-0.7968, -0.1776,  0.3033,  ...,  1.2662,  0.0517,  0.9995]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 2400/10000 | Total Loss: 1580.634521484375 | Recon Loss: 26.619568560791016 | KL Div: 44.01222940673828
# El código tardó 91.93707 segundos en ejecutarse.
# tensor([[-0.4707,  1.1808,  0.2488,  ...,  0.1500,  1.5957,  0.9966],
#         [-0.3686, -0.2992,  0.6735,  ..., -0.7445,  0.8557,  1.0064],
#         [-0.3630, -0.3918, -0.0525,  ...,  0.8550,  0.6713,  1.0022],
#         ...,
#         [-0.2553, -2.1678,  0.1337,  ...,  1.2657,  6.8300,  0.9998],
#         [-0.5517, -0.7823,  0.2908,  ..., -0.3947,  0.7137,  0.9933],
#         [-0.7343,  0.4266,  0.2536,  ...,  0.9920, -0.1516,  1.0065]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 2500/10000 | Total Loss: 885.7791748046875 | Recon Loss: 26.421143151855468 | KL Div: 43.88440395507813
# El código tardó 93.16419 segundos en ejecutarse.
# tensor([[-0.5785,  1.3532,  0.3706,  ...,  0.3028,  1.2570,  1.0053],
#         [-0.4001, -0.2172,  0.5891,  ..., -0.5522,  1.0573,  0.9938],
#         [-0.4200, -0.1500,  0.0206,  ...,  0.4261,  0.8942,  0.9972],
#         ...,
#         [-0.3209, -2.1239,  0.2120,  ...,  1.5317,  7.6957,  1.0075],
#         [-0.4972, -0.5078,  0.2807,  ...,  0.1078,  0.7118,  1.0005],
#         [-0.7848,  0.8290,  0.3082,  ...,  0.3039,  0.1079,  1.0018]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 2600/10000 | Total Loss: 898.8321533203125 | Recon Loss: 26.02431399536133 | KL Div: 43.732572576904296
# El código tardó 91.00165 segundos en ejecutarse.
# tensor([[-0.3793,  1.2073,  0.3420,  ...,  0.2551,  1.0512,  0.9886],
#         [-0.3646, -0.1871,  0.5638,  ..., -1.1564,  0.9494,  1.0067],
#         [-0.2585, -0.3989, -0.1779,  ...,  0.4833,  0.5861,  1.0139],
#         ...,
#         [-0.1139, -2.1838,  0.0441,  ...,  1.6940,  7.0622,  0.9872],
#         [-0.5237, -0.7896,  0.3604,  ..., -0.4200,  0.4408,  1.0069],
#         [-0.7415,  0.2502,  0.2703,  ...,  1.0604, -0.2222,  1.0011]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 2700/10000 | Total Loss: 862.37890625 | Recon Loss: 25.855705337524412 | KL Div: 43.53975893554688
# El código tardó 91.54342 segundos en ejecutarse.
# tensor([[-0.4678,  1.1387,  0.5605,  ...,  0.4021,  1.5775,  1.0232],
#         [-0.2588,  0.0295,  0.6477,  ..., -1.1018,  0.9268,  1.0281],
#         [-0.3024, -0.2107,  0.0151,  ...,  0.7629,  0.9380,  1.0277],
#         ...,
#         [-0.3150, -2.1046,  0.1850,  ...,  1.6384,  6.9303,  1.0055],
#         [-0.5258, -0.6572,  0.4465,  ...,  0.3406,  0.8245,  1.0127],
#         [-0.5423,  0.6899,  0.2647,  ...,  0.7951, -0.0789,  1.0205]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 2800/10000 | Total Loss: 864.8065795898438 | Recon Loss: 25.638426837158203 | KL Div: 43.38283294677734
# El código tardó 90.75520 segundos en ejecutarse.
# tensor([[-0.5234,  1.4460,  0.3173,  ...,  0.0159,  1.2950,  1.0182],
#         [-0.3196, -0.3797,  0.5198,  ..., -1.1358,  1.1810,  1.0082],
#         [-0.2806, -0.2964, -0.1601,  ...,  0.7025,  0.6475,  0.9996],
#         ...,
#         [-0.1690, -1.8709,  0.0858,  ...,  1.7514,  6.8855,  0.9839],
#         [-0.4677, -0.1942,  0.1738,  ...,  0.0760,  0.3881,  0.9998],
#         [-0.7713,  0.1587,  0.3037,  ...,  1.5397, -0.4167,  1.0098]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 2900/10000 | Total Loss: 880.0711669921875 | Recon Loss: 25.374911279296875 | KL Div: 43.09539102783203
# El código tardó 91.30097 segundos en ejecutarse.
# tensor([[-0.5728,  1.1113,  0.3186,  ...,  0.3204,  1.7772,  0.9933],
#         [-0.2570, -0.2206,  0.4678,  ..., -0.9630,  1.1873,  0.9805],
#         [-0.2471, -0.2818, -0.1537,  ...,  1.0341,  0.9827,  0.9713],
#         ...,
#         [-0.2929, -1.9101,  0.1172,  ...,  1.4797,  6.8947,  0.9999],
#         [-0.6157, -0.3460,  0.4322,  ...,  0.1910,  0.8379,  0.9830],
#         [-0.6831, -0.0334,  0.3612,  ...,  1.0306, -0.1372,  0.9933]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 3000/10000 | Total Loss: 845.250732421875 | Recon Loss: 25.11803031921387 | KL Div: 43.07555820922852
# El código tardó 91.50075 segundos en ejecutarse.
# tensor([[-0.4585,  1.1264,  0.3549,  ...,  0.1113,  1.7784,  0.9954],
#         [-0.3374,  0.0441,  0.6901,  ..., -0.8622,  0.8332,  1.0130],
#         [-0.3383, -0.4096, -0.1094,  ...,  1.1329,  0.8970,  1.0025],
#         ...,
#         [-0.1082, -1.7132, -0.0426,  ...,  1.9374,  7.2342,  0.9932],
#         [-0.6156, -0.5159,  0.4137,  ...,  0.1988,  0.8984,  0.9903],
#         [-0.7574,  0.1265,  0.2127,  ...,  0.8737, -0.3508,  0.9956]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 3100/10000 | Total Loss: 847.9224243164062 | Recon Loss: 24.89480393066406 | KL Div: 42.93394323120117
# El código tardó 91.60752 segundos en ejecutarse.
# tensor([[-0.6155,  0.9233,  0.4535,  ...,  0.2978,  1.6002,  1.0142],
#         [-0.3692, -0.0110,  0.5608,  ..., -0.7144,  0.5832,  0.9963],
#         [-0.2622, -0.0620, -0.1258,  ...,  0.2194,  0.7604,  0.9990],
#         ...,
#         [-0.2068, -1.3573,  0.0070,  ...,  2.7358,  6.8675,  0.9589],
#         [-0.5609, -0.8482,  0.3381,  ..., -0.4416,  1.0701,  0.9948],
#         [-0.7122,  0.8629,  0.2256,  ...,  1.1965, -0.0838,  1.0035]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 3200/10000 | Total Loss: 834.8067626953125 | Recon Loss: 24.734054162597655 | KL Div: 42.750634716796874
# El código tardó 91.74157 segundos en ejecutarse.
# tensor([[-0.5292,  1.0790,  0.3181,  ...,  0.7451,  1.7284,  1.0124],
#         [-0.3180, -0.1425,  0.6805,  ..., -1.0320,  1.0710,  0.9916],
#         [-0.3161, -0.1653, -0.1022,  ...,  0.8613,  0.8793,  1.0024],
#         ...,
#         [-0.2164, -1.6054,  0.0905,  ...,  1.3190,  6.7575,  0.9778],
#         [-0.5517, -0.6740,  0.4160,  ...,  0.0812,  0.7805,  0.9865],
#         [-0.7077,  0.2158,  0.2712,  ...,  0.9034, -0.1796,  0.9906]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 3300/10000 | Total Loss: 821.296875 | Recon Loss: 24.565032345581056 | KL Div: 42.66461290283203
# El código tardó 91.16060 segundos en ejecutarse.
# tensor([[-0.5690,  1.0454,  0.2503,  ...,  0.3963,  1.5158,  1.0289],
#         [-0.4236, -0.1747,  0.5978,  ..., -0.8551,  0.8168,  0.9926],
#         [-0.3178, -0.5913, -0.0959,  ...,  0.7621,  0.6948,  1.0028],
#         ...,
#         [-0.2218, -1.9269,  0.1666,  ...,  1.4400,  7.5019,  1.0250],
#         [-0.6232, -0.7345,  0.3858,  ..., -0.0743,  0.7731,  0.9783],
#         [-0.8428,  0.6693,  0.2657,  ...,  1.0678, -0.0545,  0.9986]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 3400/10000 | Total Loss: 859.6494140625 | Recon Loss: 24.37121546936035 | KL Div: 42.46777969360352
# El código tardó 91.72748 segundos en ejecutarse.
# tensor([[-0.4221,  0.8978,  0.3888,  ...,  0.1426,  1.6936,  1.0164],
#         [-0.3537, -0.2358,  0.5573,  ..., -1.1460,  1.1609,  1.0063],
#         [-0.3660, -0.4753, -0.2787,  ...,  0.4894,  1.0458,  1.0138],
#         ...,
#         [-0.2254, -1.5223,  0.1905,  ...,  1.8420,  6.6181,  1.0152],
#         [-0.4900, -0.6522,  0.3576,  ..., -0.2413,  0.6310,  1.0002],
#         [-0.7662,  0.3063,  0.3123,  ...,  0.7905, -0.1141,  1.0095]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 3500/10000 | Total Loss: 821.7819213867188 | Recon Loss: 24.08184087524414 | KL Div: 42.35447658691406
# El código tardó 92.33262 segundos en ejecutarse.
# tensor([[-0.5911,  1.0824,  0.2999,  ...,  0.1103,  1.6419,  1.0138],
#         [-0.4373, -0.3576,  0.6906,  ..., -0.9984,  0.8867,  1.0169],
#         [-0.3275, -0.1794, -0.0668,  ...,  0.9829,  0.6899,  1.0118],
#         ...,
#         [-0.2118, -1.9835,  0.1862,  ...,  2.2657,  6.7691,  0.9923],
#         [-0.6814, -0.9025,  0.2847,  ...,  0.0349,  0.8493,  1.0139],
#         [-0.7109,  0.4894,  0.1880,  ...,  0.5511, -0.2278,  1.0019]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 3600/10000 | Total Loss: 835.8265380859375 | Recon Loss: 23.93959895324707 | KL Div: 42.16687420654297
# El código tardó 91.74584 segundos en ejecutarse.
# tensor([[-0.5395,  1.3936,  0.2802,  ...,  0.0329,  1.3487,  1.0159],
#         [-0.3884, -0.3602,  0.6102,  ..., -1.1389,  1.1082,  1.0094],
#         [-0.3624, -0.0371, -0.1076,  ...,  0.5475,  1.1439,  1.0171],
#         ...,
#         [-0.2945, -2.0886,  0.0897,  ...,  1.4243,  6.5185,  1.0004],
#         [-0.5285, -0.6327,  0.3938,  ..., -0.0457,  0.5601,  1.0166],
#         [-0.7137, -0.1279,  0.1272,  ...,  1.1278, -0.1350,  1.0174]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 3700/10000 | Total Loss: 804.4432373046875 | Recon Loss: 23.68985511627197 | KL Div: 41.9826548828125
# El código tardó 92.89544 segundos en ejecutarse.
# tensor([[-0.6369,  1.2930,  0.5442,  ..., -0.1355,  1.4624,  1.0094],
#         [-0.3531,  0.0717,  0.5959,  ..., -0.8305,  1.1488,  0.9945],
#         [-0.3129, -0.0824, -0.1219,  ...,  0.9140,  0.7979,  1.0032],
#         ...,
#         [-0.1428, -1.8893, -0.0693,  ...,  2.0857,  7.2698,  1.0226],
#         [-0.5003, -0.7608,  0.4071,  ..., -0.1131,  0.5591,  1.0007],
#         [-0.7679,  0.3032,  0.0447,  ...,  1.0570, -0.0734,  1.0063]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 3800/10000 | Total Loss: 813.8251342773438 | Recon Loss: 23.511637620544434 | KL Div: 41.94451342163086
# El código tardó 92.70299 segundos en ejecutarse.
# tensor([[-0.5317,  1.1393,  0.4407,  ...,  0.2668,  1.2033,  1.0022],
#         [-0.3330, -0.2030,  0.6376,  ..., -1.2501,  1.3512,  0.9807],
#         [-0.3526, -0.5755, -0.2565,  ...,  0.5375,  0.6877,  0.9787],
#         ...,
#         [-0.2257, -2.0035,  0.1996,  ...,  1.9731,  6.6769,  1.0234],
#         [-0.5716, -0.5455,  0.4001,  ...,  0.0416,  0.9677,  0.9910],
#         [-0.7783,  0.6190,  0.2302,  ...,  1.1124, -0.1419,  0.9958]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 3900/10000 | Total Loss: 809.406494140625 | Recon Loss: 23.371373068237304 | KL Div: 41.84133778686523
# El código tardó 91.73702 segundos en ejecutarse.
# tensor([[-5.8685e-01,  1.2175e+00,  3.1971e-01,  ...,  2.9316e-01,
#           1.6510e+00,  1.0061e+00],
#         [-3.2409e-01,  2.1800e-01,  5.6780e-01,  ..., -5.7862e-01,
#           1.3650e+00,  1.0024e+00],
#         [-3.3489e-01, -4.2877e-01, -1.9427e-01,  ...,  1.3728e+00,
#           8.9525e-01,  9.9546e-01],
#         ...,
#         [-2.2629e-01, -1.6335e+00, -2.0756e-01,  ...,  1.8174e+00,
#           6.4855e+00,  9.9137e-01],
#         [-5.1934e-01, -5.8248e-01,  5.1202e-01,  ..., -1.5020e-03,
#           7.8636e-01,  9.9919e-01],
#         [-7.4171e-01,  7.0141e-01,  3.8802e-01,  ...,  1.7688e+00,
#          -2.1813e-02,  9.9818e-01]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 4000/10000 | Total Loss: 812.652099609375 | Recon Loss: 23.2509791015625 | KL Div: 41.803742053222656
# El código tardó 91.69261 segundos en ejecutarse.
# tensor([[-4.7211e-01,  1.1860e+00,  3.1073e-01,  ...,  2.4565e-01,
#           1.8432e+00,  1.0127e+00],
#         [-2.6064e-01,  5.9436e-03,  5.1273e-01,  ..., -8.3326e-01,
#           1.3384e+00,  9.8473e-01],
#         [-2.9976e-01,  3.9784e-02, -3.4044e-01,  ...,  1.1363e+00,
#           1.0546e+00,  9.8027e-01],
#         ...,
#         [-2.5772e-01, -1.7579e+00,  1.6780e-01,  ...,  1.7072e+00,
#           6.7024e+00,  9.9673e-01],
#         [-6.1042e-01, -8.1082e-01,  3.3651e-01,  ..., -6.2636e-01,
#           7.7618e-01,  9.7856e-01],
#         [-7.6502e-01,  8.5494e-01,  4.6346e-01,  ...,  9.8839e-01,
#          -6.5602e-02,  1.0035e+00]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 4100/10000 | Total Loss: 838.1181030273438 | Recon Loss: 23.10953438720703 | KL Div: 41.768358795166016
# El código tardó 91.62737 segundos en ejecutarse.
# tensor([[-0.4837,  1.3262,  0.3187,  ...,  0.0122,  1.5444,  0.9954],
#         [-0.2996,  0.0617,  0.6538,  ..., -1.2280,  1.0803,  0.9967],
#         [-0.3513, -0.3570, -0.2097,  ...,  1.0029,  1.0145,  0.9880],
#         ...,
#         [-0.3001, -2.1519,  0.2450,  ...,  1.9037,  6.8035,  1.0029],
#         [-0.5437, -0.4826,  0.3167,  ..., -0.5732,  0.5509,  0.9967],
#         [-0.7639,  0.8578,  0.1436,  ...,  1.0556, -0.1015,  0.9881]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 4200/10000 | Total Loss: 832.3225708007812 | Recon Loss: 23.078802276611327 | KL Div: 41.646799450683595
# El código tardó 93.93080 segundos en ejecutarse.
# tensor([[-4.9111e-01,  1.0373e+00,  3.7434e-01,  ..., -1.2408e-01,
#           1.3923e+00,  9.9193e-01],
#         [-4.0327e-01, -1.8820e-02,  6.4492e-01,  ..., -1.2645e+00,
#           1.1298e+00,  1.0214e+00],
#         [-2.9671e-01, -1.8361e-01, -2.4664e-01,  ...,  1.1467e+00,
#           9.7835e-01,  1.0151e+00],
#         ...,
#         [-1.7466e-01, -1.8981e+00,  3.7741e-03,  ...,  1.1143e+00,
#           6.8508e+00,  9.9903e-01],
#         [-5.4292e-01, -6.3394e-02,  3.6609e-01,  ...,  1.5707e-01,
#           4.5045e-01,  9.9529e-01],
#         [-7.2444e-01,  9.0621e-01,  2.9760e-01,  ...,  1.3210e+00,
#          -1.4440e-01,  1.0150e+00]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 4300/10000 | Total Loss: 824.69091796875 | Recon Loss: 22.89651191101074 | KL Div: 41.618414978027346
# El código tardó 92.53273 segundos en ejecutarse.
# tensor([[-0.6461,  1.5146,  0.3824,  ...,  0.2829,  1.9151,  0.9993],
#         [-0.3921, -0.2938,  0.4469,  ..., -1.0882,  1.1011,  1.0049],
#         [-0.3586, -0.4067, -0.1590,  ...,  0.8099,  0.7586,  0.9890],
#         ...,
#         [-0.3362, -1.6717, -0.0601,  ...,  1.6162,  7.0459,  0.9809],
#         [-0.6379, -0.2737,  0.4615,  ..., -0.2186,  0.8924,  1.0086],
#         [-0.7413,  0.2510,  0.1835,  ...,  0.7185,  0.0651,  0.9917]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 4400/10000 | Total Loss: 824.45703125 | Recon Loss: 22.81299674987793 | KL Div: 41.48425386352539
# El código tardó 93.69440 segundos en ejecutarse.
# tensor([[-0.5352,  1.6277,  0.3263,  ...,  0.3780,  1.8218,  1.0246],
#         [-0.3235, -0.2016,  0.7067,  ..., -1.1172,  1.3354,  0.9821],
#         [-0.3495, -0.3222, -0.2747,  ...,  0.8905,  0.5432,  1.0010],
#         ...,
#         [-0.4032, -1.7351,  0.2314,  ...,  1.7773,  7.1731,  1.0097],
#         [-0.5340, -0.5352,  0.3054,  ...,  0.1439,  0.6571,  0.9861],
#         [-0.7039,  0.8070,  0.1928,  ...,  0.9139, -0.1290,  0.9869]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 4500/10000 | Total Loss: 800.2136840820312 | Recon Loss: 22.689961755371094 | KL Div: 41.41558278198242
# El código tardó 92.73990 segundos en ejecutarse.
# tensor([[-0.5818,  1.1545,  0.5087,  ..., -0.0433,  1.5360,  0.9928],
#         [-0.2644, -0.4246,  0.5580,  ..., -1.1798,  1.1654,  1.0046],
#         [-0.4393, -0.5704, -0.2331,  ...,  0.4622,  0.7053,  0.9994],
#         ...,
#         [-0.2487, -1.8369,  0.1459,  ...,  2.2497,  7.3878,  0.9965],
#         [-0.5868, -0.4718,  0.3674,  ...,  0.1591,  0.7386,  0.9878],
#         [-0.8378,  0.7161,  0.1581,  ...,  1.5166, -0.0752,  0.9962]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 4600/10000 | Total Loss: 778.680419921875 | Recon Loss: 22.554906721496582 | KL Div: 41.39584193725586
# El código tardó 91.61395 segundos en ejecutarse.
# tensor([[-0.6191,  1.3212,  0.2798,  ...,  0.5309,  1.3759,  0.9934],
#         [-0.3807, -0.5091,  0.8193,  ..., -1.0104,  1.1118,  0.9788],
#         [-0.3058,  0.1540, -0.1171,  ...,  1.5845,  1.0290,  0.9825],
#         ...,
#         [-0.2899, -2.0370, -0.0075,  ...,  2.0595,  7.0233,  0.9892],
#         [-0.6173, -0.6077,  0.4462,  ...,  0.4401,  1.1700,  0.9915],
#         [-0.8297,  0.4787,  0.1917,  ...,  1.1076, -0.1745,  0.9864]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 4700/10000 | Total Loss: 793.3548583984375 | Recon Loss: 22.514051818847655 | KL Div: 41.34056589355469
# El código tardó 92.82295 segundos en ejecutarse.
# tensor([[-0.5566,  0.8480,  0.4716,  ...,  0.2177,  1.6424,  1.0044],
#         [-0.3513, -0.0546,  0.7500,  ..., -0.8059,  0.9431,  1.0000],
#         [-0.3361,  0.0964, -0.1715,  ...,  0.9086,  0.7984,  0.9856],
#         ...,
#         [-0.3503, -1.6798,  0.2663,  ...,  1.5716,  6.7694,  1.0021],
#         [-0.5345, -0.5793,  0.3941,  ..., -0.2967,  1.0133,  1.0084],
#         [-0.7380,  0.5773,  0.2116,  ...,  1.1756, -0.1726,  1.0037]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 4800/10000 | Total Loss: 818.3389892578125 | Recon Loss: 22.427542153930663 | KL Div: 41.36857965087891
# El código tardó 92.22674 segundos en ejecutarse.
# tensor([[-0.4742,  1.5660,  0.3364,  ...,  0.2788,  1.7130,  1.0030],
#         [-0.3454, -0.8642,  0.7102,  ..., -0.8424,  1.0077,  1.0061],
#         [-0.3133, -0.3953, -0.2300,  ...,  0.5734,  0.6847,  0.9833],
#         ...,
#         [-0.3593, -1.7151,  0.2647,  ...,  1.0664,  6.9972,  0.9754],
#         [-0.6427, -0.5850,  0.4902,  ...,  0.1274,  0.6482,  1.0040],
#         [-0.7377,  0.2915,  0.1996,  ...,  0.7107, -0.3220,  1.0046]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 4900/10000 | Total Loss: 781.3541259765625 | Recon Loss: 22.28325238342285 | KL Div: 41.206103698730466
# El código tardó 96.05247 segundos en ejecutarse.
# tensor([[-4.2704e-01,  1.1874e+00,  3.3062e-01,  ...,  8.6446e-01,
#           1.7433e+00,  1.0208e+00],
#         [-4.0543e-01,  9.5478e-04,  6.0473e-01,  ..., -7.2707e-01,
#           1.1473e+00,  9.8974e-01],
#         [-2.4981e-01, -2.4908e-01, -2.9425e-01,  ...,  5.2337e-01,
#           9.6487e-01,  9.9861e-01],
#         ...,
#         [-3.1195e-01, -2.0512e+00,  1.6773e-01,  ...,  2.3975e+00,
#           7.0750e+00,  1.0155e+00],
#         [-5.7888e-01, -2.2383e-01,  4.4752e-01,  ...,  4.8352e-02,
#           9.6402e-01,  9.7657e-01],
#         [-7.7956e-01,  7.1667e-01,  2.6499e-01,  ...,  9.6724e-01,
#          -2.2371e-02,  9.8452e-01]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 5000/10000 | Total Loss: 792.4920043945312 | Recon Loss: 22.225834434509277 | KL Div: 41.24622592163086
# El código tardó 92.34781 segundos en ejecutarse.
# tensor([[-0.4878,  1.0547,  0.4132,  ...,  0.0512,  1.7577,  1.0264],
#         [-0.3262, -0.5752,  0.5793,  ..., -0.9496,  1.1891,  1.0014],
#         [-0.3187, -0.4554, -0.3863,  ...,  0.7527,  0.7649,  1.0042],
#         ...,
#         [-0.3397, -1.7198,  0.1986,  ...,  1.6343,  7.4900,  1.0136],
#         [-0.5999, -0.3163,  0.3024,  ..., -0.3284,  0.5704,  0.9920],
#         [-0.7313,  0.7045,  0.1412,  ...,  1.3964, -0.3885,  0.9930]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 5100/10000 | Total Loss: 798.5545654296875 | Recon Loss: 22.13636555480957 | KL Div: 41.09360368652344
# El código tardó 91.20393 segundos en ejecutarse.
# tensor([[-0.5291,  0.8082,  0.3796,  ...,  0.5315,  1.4953,  1.0088],
#         [-0.3323, -0.5103,  0.7346,  ..., -1.1425,  1.1293,  0.9869],
#         [-0.3344, -0.1356, -0.1652,  ...,  1.0528,  0.9393,  0.9976],
#         ...,
#         [-0.1731, -2.2035, -0.0191,  ...,  1.6002,  6.9829,  1.0030],
#         [-0.5638, -0.6418,  0.3497,  ..., -0.3517,  0.6585,  0.9816],
#         [-0.7368,  0.4159,  0.3019,  ...,  0.9613, -0.3220,  0.9959]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 5200/10000 | Total Loss: 801.8218994140625 | Recon Loss: 22.12807972869873 | KL Div: 41.05181411743164
# El código tardó 92.02377 segundos en ejecutarse.
# tensor([[-0.5015,  1.0451,  0.4764,  ...,  0.5511,  1.6025,  0.9952],
#         [-0.3481,  0.2461,  0.6759,  ..., -0.8869,  1.2960,  1.0052],
#         [-0.3094, -0.1319, -0.2122,  ...,  0.5552,  0.6213,  0.9944],
#         ...,
#         [-0.1670, -1.9809,  0.2752,  ...,  1.6155,  7.0278,  0.9647],
#         [-0.5165, -0.1099,  0.4425,  ...,  0.1431,  0.3401,  1.0027],
#         [-0.7427,  0.3823,  0.3070,  ...,  0.8546, -0.3989,  1.0001]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 5300/10000 | Total Loss: 842.1734008789062 | Recon Loss: 22.058560662841796 | KL Div: 41.00639884033203
# El código tardó 92.08995 segundos en ejecutarse.
# tensor([[-0.4986,  1.3873,  0.3704,  ...,  0.7776,  1.4262,  1.0028],
#         [-0.2721, -0.4443,  0.4748,  ..., -1.1458,  1.1130,  1.0118],
#         [-0.3636,  0.2177, -0.0391,  ...,  0.8304,  0.8910,  1.0064],
#         ...,
#         [-0.2595, -1.9797,  0.1493,  ...,  1.6146,  6.7458,  0.9984],
#         [-0.5147, -0.4775,  0.4087,  ...,  0.2825,  0.9822,  1.0267],
#         [-0.7734,  0.4698,  0.3760,  ...,  0.8773, -0.3650,  1.0188]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 5400/10000 | Total Loss: 798.48095703125 | Recon Loss: 22.058158474731446 | KL Div: 41.048439123535154
# El código tardó 91.90671 segundos en ejecutarse.
# tensor([[-0.5296,  1.2207,  0.3406,  ...,  0.0370,  1.7404,  1.0195],
#         [-0.4028, -0.0980,  0.5643,  ..., -0.8434,  1.0343,  1.0179],
#         [-0.4676, -0.0812, -0.3463,  ...,  0.7267,  0.7907,  1.0219],
#         ...,
#         [-0.2016, -1.8737,  0.0162,  ...,  1.6286,  6.7586,  1.0042],
#         [-0.5551, -0.5502,  0.4269,  ...,  0.2338,  0.3226,  1.0116],
#         [-0.7389,  0.3498,  0.2190,  ...,  1.0575, -0.1853,  1.0058]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 5500/10000 | Total Loss: 778.5493774414062 | Recon Loss: 21.93360349884033 | KL Div: 40.953504943847655
# El código tardó 91.98803 segundos en ejecutarse.
# tensor([[-6.5213e-01,  1.8813e+00,  3.4483e-01,  ...,  1.8391e-02,
#           1.3470e+00,  9.9124e-01],
#         [-3.0500e-01, -2.4178e-01,  5.9485e-01,  ..., -7.2029e-01,
#           1.0927e+00,  9.9821e-01],
#         [-3.6236e-01, -3.5922e-03, -3.2329e-01,  ...,  7.3774e-01,
#           8.4176e-01,  1.0037e+00],
#         ...,
#         [-2.7953e-01, -1.8615e+00,  2.4590e-01,  ...,  1.4700e+00,
#           6.6192e+00,  9.8128e-01],
#         [-5.1735e-01, -6.8153e-01,  4.1356e-01,  ..., -1.1112e-01,
#           4.3995e-01,  9.9267e-01],
#         [-8.0675e-01,  4.9435e-01,  2.6305e-01,  ...,  1.4663e+00,
#          -3.6281e-01,  9.9190e-01]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 5600/10000 | Total Loss: 806.7222290039062 | Recon Loss: 21.819923822021483 | KL Div: 40.844267907714844
# El código tardó 91.61832 segundos en ejecutarse.
# tensor([[-0.5981,  0.7384,  0.2616,  ...,  0.3916,  1.7576,  1.0167],
#         [-0.3986, -0.3196,  0.5865,  ..., -0.9442,  1.1994,  0.9923],
#         [-0.3624, -0.3708, -0.1988,  ...,  0.9397,  0.6985,  1.0037],
#         ...,
#         [-0.3376, -2.0896,  0.1680,  ...,  1.7650,  6.9742,  0.9731],
#         [-0.5881, -0.6937,  0.3440,  ..., -0.0190,  0.6932,  0.9824],
#         [-0.7831,  0.4390,  0.2491,  ...,  0.7030, -0.3366,  1.0017]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 5700/10000 | Total Loss: 779.62353515625 | Recon Loss: 21.98123445739746 | KL Div: 40.90556243286133
# El código tardó 91.18132 segundos en ejecutarse.
# tensor([[-0.5094,  0.7459,  0.3387,  ...,  0.5550,  1.5971,  1.0152],
#         [-0.4671, -0.6218,  0.5893,  ..., -1.1318,  0.9041,  1.0111],
#         [-0.2678,  0.2585, -0.1587,  ...,  0.9371,  0.7074,  1.0163],
#         ...,
#         [-0.3115, -1.8492,  0.1591,  ...,  1.4354,  6.7288,  0.9886],
#         [-0.5714, -0.6004,  0.4998,  ..., -0.3180,  0.7188,  1.0099],
#         [-0.7276,  0.1787,  0.2191,  ...,  1.0438, -0.2070,  0.9936]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 5800/10000 | Total Loss: 766.8668212890625 | Recon Loss: 21.75528656921387 | KL Div: 40.66058247680664
# El código tardó 91.80125 segundos en ejecutarse.
# tensor([[-0.5199,  1.2934,  0.3399,  ...,  1.4023,  1.2741,  1.0306],
#         [-0.3666, -0.3900,  0.5342,  ..., -1.1028,  1.0164,  1.0053],
#         [-0.3864, -0.3920, -0.1935,  ...,  0.9430,  0.6287,  1.0196],
#         ...,
#         [-0.1794, -1.9632, -0.1334,  ...,  2.0993,  7.1896,  1.0272],
#         [-0.5466, -0.6812,  0.4504,  ..., -0.1501,  0.7507,  0.9938],
#         [-0.7774,  0.3754,  0.1953,  ...,  1.2268, -0.1347,  1.0045]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 5900/10000 | Total Loss: 769.6103515625 | Recon Loss: 21.611975186157228 | KL Div: 40.6937274597168
# El código tardó 91.51311 segundos en ejecutarse.
# tensor([[-0.6335,  1.0391,  0.3584,  ...,  0.3811,  1.8588,  0.9973],
#         [-0.3956, -0.2735,  0.7402,  ..., -0.9911,  1.3297,  0.9759],
#         [-0.3164, -0.5623, -0.3102,  ...,  0.8884,  0.7239,  0.9763],
#         ...,
#         [-0.2908, -2.2081,  0.0970,  ...,  2.5581,  7.0722,  0.9984],
#         [-0.5223, -0.7800,  0.4082,  ...,  0.0691,  0.7030,  0.9893],
#         [-0.6153, -0.1677,  0.2138,  ...,  0.6135, -0.2161,  0.9925]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 6000/10000 | Total Loss: 794.6754150390625 | Recon Loss: 21.525678749084474 | KL Div: 40.61476094970703
# El código tardó 92.02045 segundos en ejecutarse.
# tensor([[-0.4584,  0.8782,  0.3498,  ...,  0.4639,  1.5438,  1.0308],
#         [-0.3633, -0.1004,  0.7642,  ..., -0.9094,  1.2416,  1.0046],
#         [-0.3241, -0.3717, -0.1593,  ...,  1.0099,  0.7953,  1.0097],
#         ...,
#         [-0.3492, -1.9010,  0.0938,  ...,  1.4537,  7.0558,  0.9966],
#         [-0.4971, -0.3114,  0.2711,  ...,  0.1170,  0.7013,  0.9924],
#         [-0.7025,  0.3447,  0.2080,  ...,  1.1928, -0.1791,  0.9983]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 6100/10000 | Total Loss: 741.9619750976562 | Recon Loss: 21.47104450073242 | KL Div: 40.52457984619141
# El código tardó 93.03214 segundos en ejecutarse.
# tensor([[-6.0790e-01,  4.2143e-01,  2.9597e-01,  ...,  4.6685e-01,
#           1.7798e+00,  9.8816e-01],
#         [-4.0998e-01, -5.1358e-03,  5.5679e-01,  ..., -8.8215e-01,
#           1.4416e+00,  9.8185e-01],
#         [-3.7030e-01, -3.7416e-01, -2.7309e-01,  ...,  1.0393e+00,
#           7.2658e-01,  9.8577e-01],
#         ...,
#         [-2.7043e-01, -2.1344e+00, -1.2002e-01,  ...,  2.4193e+00,
#           7.1534e+00,  9.9559e-01],
#         [-5.6422e-01, -6.6443e-01,  4.5814e-01,  ...,  3.4597e-01,
#           3.9223e-01,  1.0046e+00],
#         [-8.2761e-01,  2.3013e-01,  2.6360e-01,  ...,  1.3158e+00,
#          -3.2972e-01,  1.0074e+00]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 6200/10000 | Total Loss: 770.2109375 | Recon Loss: 21.3754100189209 | KL Div: 40.46278575439453
# El código tardó 93.14568 segundos en ejecutarse.
# tensor([[-5.9897e-01,  1.5293e+00,  3.4075e-01,  ...,  6.2108e-01,
#           1.5524e+00,  1.0148e+00],
#         [-3.7915e-01, -3.9518e-01,  6.6555e-01,  ..., -9.4442e-01,
#           1.2553e+00,  1.0002e+00],
#         [-3.5338e-01,  4.5516e-02, -2.1795e-01,  ...,  8.5589e-01,
#           6.2267e-01,  1.0012e+00],
#         ...,
#         [-3.4928e-01, -2.0071e+00,  1.8401e-01,  ...,  1.8748e+00,
#           6.4425e+00,  1.0105e+00],
#         [-5.4380e-01, -5.7075e-01,  5.4200e-01,  ..., -3.5311e-03,
#           5.3320e-01,  1.0023e+00],
#         [-9.0297e-01, -4.7481e-02,  1.7912e-01,  ...,  1.1899e+00,
#          -1.8497e-01,  9.9874e-01]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 6300/10000 | Total Loss: 771.4473266601562 | Recon Loss: 21.284155975341797 | KL Div: 40.48591748046875
# El código tardó 92.60028 segundos en ejecutarse.
# tensor([[-5.1920e-01,  3.6160e-01,  2.6762e-01,  ...,  4.5042e-01,
#           1.7656e+00,  1.0186e+00],
#         [-4.1709e-01, -3.3034e-01,  5.7476e-01,  ..., -1.2793e+00,
#           1.3132e+00,  1.0102e+00],
#         [-3.3224e-01,  2.6688e-02, -3.5206e-01,  ...,  1.0621e+00,
#           6.6860e-01,  1.0066e+00],
#         ...,
#         [-2.2980e-01, -1.9297e+00, -2.5160e-02,  ...,  1.4367e+00,
#           7.4248e+00,  1.0133e+00],
#         [-7.0041e-01, -4.3105e-01,  3.7447e-01,  ...,  7.9662e-02,
#           6.8741e-01,  9.9509e-01],
#         [-7.5247e-01,  2.4839e-03,  1.2894e-01,  ...,  1.0213e+00,
#           9.0083e-02,  9.9210e-01]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 6400/10000 | Total Loss: 770.0455322265625 | Recon Loss: 21.321039503479003 | KL Div: 40.35559761962891
# El código tardó 91.64731 segundos en ejecutarse.
# tensor([[-0.5611,  0.8732,  0.2933,  ...,  0.2196,  1.5976,  1.0080],
#         [-0.3337, -0.1815,  0.5602,  ..., -0.8630,  1.5343,  1.0115],
#         [-0.3406, -0.0160, -0.3103,  ...,  1.0480,  0.8157,  1.0290],
#         ...,
#         [-0.0568, -1.7175, -0.1258,  ...,  1.3488,  7.3649,  0.9855],
#         [-0.5319, -1.2554,  0.3901,  ..., -0.2145,  0.7325,  0.9985],
#         [-0.7637,  0.4052,  0.2621,  ...,  1.0762, -0.2227,  1.0092]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 6500/10000 | Total Loss: 773.8607177734375 | Recon Loss: 21.388186715698243 | KL Div: 40.390422723388674
# El código tardó 91.58694 segundos en ejecutarse.
# tensor([[-0.6306,  1.5257,  0.3056,  ...,  0.3668,  1.8669,  1.0030],
#         [-0.4429, -0.1212,  0.7112,  ..., -1.2689,  1.1181,  0.9936],
#         [-0.3954, -0.5250, -0.2224,  ...,  0.9468,  0.6309,  1.0217],
#         ...,
#         [-0.2527, -1.9532, -0.1385,  ...,  2.2162,  7.6100,  1.0040],
#         [-0.6234, -0.7109,  0.4257,  ...,  0.1736,  0.7579,  0.9984],
#         [-0.8220,  0.5290,  0.1735,  ...,  1.1060, -0.3502,  1.0041]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 6600/10000 | Total Loss: 782.1367797851562 | Recon Loss: 21.15888226928711 | KL Div: 40.33085881347656
# El código tardó 91.67873 segundos en ejecutarse.
# tensor([[-0.5843,  1.0255,  0.3796,  ...,  0.0194,  1.6975,  1.0003],
#         [-0.4564, -0.8864,  0.5725,  ..., -0.7018,  1.1278,  1.0267],
#         [-0.4062, -0.5184, -0.2278,  ...,  1.0356,  0.7956,  1.0126],
#         ...,
#         [-0.3261, -1.7594,  0.1919,  ...,  2.6678,  7.1206,  1.0083],
#         [-0.5597, -0.4558,  0.4175,  ..., -0.1843,  0.9878,  1.0062],
#         [-0.8478,  0.5222,  0.2379,  ...,  1.2518, -0.3614,  0.9892]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 6700/10000 | Total Loss: 791.0195922851562 | Recon Loss: 21.164467364501952 | KL Div: 40.22800565185547
# El código tardó 91.08852 segundos en ejecutarse.
# tensor([[-0.5406,  0.8232,  0.4672,  ...,  0.4556,  1.7132,  0.9877],
#         [-0.4330, -0.6059,  0.6057,  ..., -1.0300,  1.1988,  0.9865],
#         [-0.3379,  0.1437, -0.2888,  ...,  0.5968,  0.5405,  0.9729],
#         ...,
#         [-0.1730, -2.3607, -0.0616,  ...,  1.6602,  7.3731,  1.0025],
#         [-0.5734, -0.5255,  0.3166,  ...,  0.0406,  0.6258,  0.9905],
#         [-0.7040,  0.6724,  0.0504,  ...,  1.3813, -0.3826,  1.0042]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 6800/10000 | Total Loss: 757.4679565429688 | Recon Loss: 21.042923510742188 | KL Div: 40.22863980102539
# El código tardó 91.43954 segundos en ejecutarse.
# tensor([[-0.5599,  1.1626,  0.3752,  ...,  0.3273,  1.6987,  0.9889],
#         [-0.4394, -0.2872,  0.5342,  ..., -1.0718,  1.2268,  0.9902],
#         [-0.3375, -0.1566, -0.2280,  ...,  1.2760,  0.7885,  0.9861],
#         ...,
#         [-0.2956, -2.1664,  0.2157,  ...,  2.1483,  7.4153,  1.0423],
#         [-0.6048, -0.5360,  0.4309,  ...,  0.0710,  0.9338,  1.0001],
#         [-0.7399,  0.6847,  0.3237,  ...,  1.3905, -0.3058,  0.9947]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 6900/10000 | Total Loss: 790.8846435546875 | Recon Loss: 20.961639932250975 | KL Div: 40.1746352722168
# El código tardó 92.32831 segundos en ejecutarse.
# tensor([[-0.5744,  0.9709,  0.3106,  ...,  0.0092,  1.7225,  1.0190],
#         [-0.4378, -0.1022,  0.7453,  ..., -0.7479,  1.1379,  0.9961],
#         [-0.2584, -0.6774, -0.2193,  ...,  0.9295,  0.8347,  1.0140],
#         ...,
#         [-0.3731, -2.0661,  0.1629,  ...,  2.0620,  7.1205,  1.0154],
#         [-0.4623, -0.5161,  0.4071,  ..., -0.1626,  0.6268,  0.9974],
#         [-0.7705,  0.3384,  0.3446,  ...,  1.0734,  0.0283,  0.9999]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 7000/10000 | Total Loss: 774.3518676757812 | Recon Loss: 20.999146771240234 | KL Div: 40.20324676513672
# El código tardó 91.19771 segundos en ejecutarse.
# tensor([[-0.5973,  1.1315,  0.4562,  ...,  0.8171,  1.4797,  1.0123],
#         [-0.3623, -0.4117,  0.7236,  ..., -1.4166,  1.1424,  0.9796],
#         [-0.2830, -0.5594, -0.3279,  ...,  0.8001,  0.6085,  1.0050],
#         ...,
#         [-0.4482, -1.8671,  0.1114,  ...,  1.9936,  6.7763,  0.9886],
#         [-0.5789, -0.9746,  0.4011,  ...,  0.1053,  0.7925,  0.9934],
#         [-0.6906,  0.1804,  0.1365,  ...,  1.3604, -0.0381,  0.9944]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 7100/10000 | Total Loss: 765.4849243164062 | Recon Loss: 20.84698422088623 | KL Div: 40.173341711425785
# El código tardó 91.07875 segundos en ejecutarse.
# tensor([[-0.4934,  0.7681,  0.0956,  ...,  0.2222,  1.3294,  1.0128],
#         [-0.4058, -0.1250,  0.6598,  ..., -1.0728,  0.9156,  1.0164],
#         [-0.2917, -0.0252, -0.2069,  ...,  1.3018,  0.8423,  1.0115],
#         ...,
#         [-0.3794, -1.5321,  0.0891,  ...,  1.8482,  6.7699,  0.9921],
#         [-0.5549, -0.1483,  0.3714,  ...,  0.1135,  0.7116,  0.9848],
#         [-0.7045,  0.4118,  0.2050,  ...,  1.3806, -0.4535,  0.9938]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 7200/10000 | Total Loss: 747.0970458984375 | Recon Loss: 20.81669345703125 | KL Div: 40.10332263183594
# El código tardó 92.71559 segundos en ejecutarse.
# tensor([[-0.5332,  0.6177,  0.2883,  ...,  0.6140,  1.5961,  0.9988],
#         [-0.3761, -0.3259,  0.5821,  ..., -1.0941,  1.1386,  0.9989],
#         [-0.3496, -0.6210, -0.2142,  ...,  0.8742,  0.7020,  0.9945],
# ...
# tensor([[-0.7741,  1.1297,  0.5332,  ...,  0.6380,  1.6636,  1.0090],
#         [-0.3442, -0.0584,  0.5890,  ..., -1.1632,  1.3198,  0.9908],
#         [-0.3384,  0.1428, -0.2838,  ...,  0.4397,  0.6777,  0.9845],
#         ...,
#         [-0.2679, -2.1511, -0.2576,  ...,  1.9092,  7.1945,  1.0173],
#         [-0.5338, -0.1841,  0.3648,  ...,  0.1694,  0.7255,  1.0016],
#         [-0.7981,  0.3351,  0.1252,  ...,  1.4004, -0.3094,  0.9981]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 7700/10000 | Total Loss: 794.5704345703125 | Recon Loss: 20.667832125854492 | KL Div: 40.01906735839844
# El código tardó 91.23395 segundos en ejecutarse.
# tensor([[-0.6367,  1.4907,  0.3695,  ...,  0.3861,  1.8063,  1.0242],
#         [-0.3190, -0.1739,  0.6349,  ..., -0.8665,  1.2388,  1.0228],
#         [-0.2386, -0.5541, -0.2668,  ...,  0.9509,  1.1613,  1.0284],
#         ...,
#         [-0.3373, -2.0329,  0.1653,  ...,  2.1820,  6.8081,  1.0130],
#         [-0.5800, -1.0313,  0.5771,  ..., -0.2501,  0.9318,  1.0038],
#         [-0.7756,  0.4894,  0.1153,  ...,  1.2367, -0.3926,  0.9885]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 7800/10000 | Total Loss: 856.22802734375 | Recon Loss: 20.618937689208984 | KL Div: 39.90693414916992
# El código tardó 92.24538 segundos en ejecutarse.
# tensor([[-0.4535,  1.2199,  0.3245,  ...,  0.6757,  1.9047,  0.9839],
#         [-0.3872, -0.0444,  0.5814,  ..., -1.0730,  1.1583,  0.9950],
#         [-0.3664, -0.9863, -0.1912,  ...,  0.4182,  0.6842,  0.9941],
#         ...,
#         [-0.3166, -1.9183, -0.0287,  ...,  1.9965,  7.0927,  1.0059],
#         [-0.5754, -0.2457,  0.3062,  ..., -0.1981,  0.8801,  1.0000],
#         [-0.8091,  0.3335,  0.1637,  ...,  1.4174, -0.3968,  0.9982]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 7900/10000 | Total Loss: 738.5344848632812 | Recon Loss: 20.586108506774902 | KL Div: 39.888725555419924
# El código tardó 91.96341 segundos en ejecutarse.
# tensor([[-0.5058,  0.9140,  0.3677,  ...,  0.6120,  1.8240,  0.9862],
#         [-0.3476, -0.5684,  0.6065,  ..., -1.0445,  1.0851,  0.9919],
#         [-0.2944, -0.1740, -0.1960,  ...,  0.5901,  0.5903,  0.9976],
#         ...,
#         [-0.3418, -2.0467,  0.0961,  ...,  1.2982,  6.9296,  0.9829],
#         [-0.4893, -0.7871,  0.3212,  ...,  0.0199,  0.7678,  0.9999],
#         [-0.7801,  0.2652,  0.1831,  ...,  1.3610, -0.3028,  0.9963]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 8000/10000 | Total Loss: 742.2658081054688 | Recon Loss: 20.515171952819824 | KL Div: 39.84544556884766
# El código tardó 91.21413 segundos en ejecutarse.
# tensor([[-0.5178,  0.9337,  0.3014,  ...,  0.6424,  1.3467,  1.0079],
#         [-0.3114, -0.2898,  0.5360,  ..., -1.0056,  1.2205,  0.9987],
#         [-0.3578, -0.1332, -0.2988,  ...,  0.9830,  0.8744,  0.9942],
#         ...,
#         [-0.2383, -2.0005, -0.0111,  ...,  1.5606,  6.8170,  0.9995],
#         [-0.5552, -0.2824,  0.5031,  ..., -0.1059,  0.7051,  0.9997],
#         [-0.7685,  0.2136,  0.1495,  ...,  0.9161, -0.1839,  1.0069]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 8100/10000 | Total Loss: 767.367919921875 | Recon Loss: 20.568137698364257 | KL Div: 39.864377844238284
# El código tardó 89.98064 segundos en ejecutarse.
# tensor([[-5.3903e-01,  1.2013e+00,  2.8417e-01,  ..., -1.7019e-03,
#           1.6315e+00,  1.0027e+00],
#         [-4.7973e-01, -5.1332e-01,  6.5872e-01,  ..., -1.1852e+00,
#           1.1841e+00,  9.7365e-01],
#         [-3.5633e-01, -2.5147e-01, -2.0274e-01,  ...,  1.1052e+00,
#           7.9797e-01,  9.9630e-01],
#         ...,
#         [-3.6230e-01, -1.7529e+00,  2.3841e-01,  ...,  1.8586e+00,
#           6.8008e+00,  1.0165e+00],
#         [-5.3179e-01, -7.2873e-01,  3.8123e-01,  ..., -2.5848e-01,
#           6.4211e-01,  1.0104e+00],
#         [-7.0641e-01,  4.0871e-01,  1.8768e-01,  ...,  1.2780e+00,
#           3.9222e-02,  9.9778e-01]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 8200/10000 | Total Loss: 783.401611328125 | Recon Loss: 20.53575855255127 | KL Div: 39.89267455444336
# El código tardó 90.76224 segundos en ejecutarse.
# tensor([[-0.6169,  0.8925,  0.3110,  ..., -0.0289,  1.5064,  0.9999],
#         [-0.3562,  0.0634,  0.4675,  ..., -0.8553,  1.3611,  0.9779],
#         [-0.3562, -0.0669, -0.1992,  ...,  0.9392,  0.7132,  0.9728],
#         ...,
#         [-0.1612, -2.3662, -0.0275,  ...,  2.5191,  7.4435,  1.0378],
#         [-0.6656, -0.8716,  0.2850,  ..., -0.2384,  0.6664,  0.9918],
#         [-0.7341,  0.1223,  0.2121,  ...,  1.6768,  0.1064,  1.0038]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 8300/10000 | Total Loss: 745.2139282226562 | Recon Loss: 20.506930145263674 | KL Div: 39.82315018310547
# El código tardó 90.99957 segundos en ejecutarse.
# tensor([[-4.8000e-01,  8.3644e-01,  3.2945e-01,  ...,  3.8975e-01,
#           1.2693e+00,  9.9071e-01],
#         [-3.6476e-01, -1.8357e-01,  4.8216e-01,  ..., -8.0155e-01,
#           1.0631e+00,  9.8714e-01],
#         [-3.8483e-01, -3.8956e-01, -1.9106e-01,  ...,  1.1214e+00,
#           6.9770e-01,  9.9850e-01],
#         ...,
#         [-1.4590e-01, -1.6910e+00,  1.7178e-02,  ...,  1.9628e+00,
#           7.2848e+00,  1.0035e+00],
#         [-4.5053e-01, -2.8527e-01,  4.3734e-01,  ...,  2.9664e-03,
#           7.3735e-01,  1.0042e+00],
#         [-7.0450e-01,  1.6583e-01,  2.9273e-01,  ...,  7.8651e-01,
#          -3.7415e-01,  1.0008e+00]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 8400/10000 | Total Loss: 753.5220947265625 | Recon Loss: 20.531416549682618 | KL Div: 39.80158114624023
# El código tardó 91.68717 segundos en ejecutarse.
# tensor([[-0.6697,  1.0561,  0.3750,  ...,  0.4693,  1.5565,  1.0087],
#         [-0.4182, -0.8232,  0.6425,  ..., -0.8947,  0.9762,  1.0262],
#         [-0.3461, -0.5736, -0.1494,  ...,  0.8342,  0.6922,  0.9858],
#         ...,
#         [-0.3723, -1.9433,  0.1288,  ...,  1.8717,  6.9323,  0.9972],
#         [-0.5584, -0.8050,  0.3334,  ...,  0.1935,  1.0644,  0.9997],
#         [-0.8350,  0.6225,  0.2575,  ...,  0.8319, -0.2501,  0.9942]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 8500/10000 | Total Loss: 720.416748046875 | Recon Loss: 20.424908084106445 | KL Div: 39.80199598999023
# El código tardó 90.57617 segundos en ejecutarse.
# tensor([[-0.5272,  0.9601,  0.3639,  ...,  0.4728,  1.8947,  0.9891],
#         [-0.3835, -0.2091,  0.8262,  ..., -0.8831,  1.2089,  0.9997],
#         [-0.3482, -0.2320, -0.2675,  ...,  0.9417,  0.7228,  1.0053],
#         ...,
#         [-0.2035, -2.0756,  0.1965,  ...,  2.3429,  7.8581,  1.0052],
#         [-0.5859, -0.5023,  0.4195,  ..., -0.0613,  0.5827,  1.0052],
#         [-0.7727, -0.1106,  0.2559,  ...,  1.3963,  0.0178,  1.0044]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 8600/10000 | Total Loss: 757.7122802734375 | Recon Loss: 20.451582411193847 | KL Div: 39.73449112548828
# El código tardó 91.01139 segundos en ejecutarse.
# tensor([[-0.5924,  1.1262,  0.3086,  ...,  0.8175,  1.6883,  1.0120],
#         [-0.4194, -0.2186,  0.5868,  ..., -1.1047,  1.2627,  1.0002],
#         [-0.2990,  0.0200, -0.2416,  ...,  1.1508,  0.8207,  1.0085],
#         ...,
#         [-0.3346, -1.8000,  0.0879,  ...,  1.8207,  6.8893,  1.0048],
#         [-0.4719, -0.5293,  0.2994,  ...,  0.1451,  0.5793,  0.9975],
#         [-0.8893,  0.0910,  0.1930,  ...,  1.1888, -0.2117,  0.9903]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 8700/10000 | Total Loss: 744.6214599609375 | Recon Loss: 20.417267852783205 | KL Div: 39.62938650512695
# El código tardó 92.51647 segundos en ejecutarse.
# tensor([[-0.6079,  1.3987,  0.3956,  ...,  0.3368,  1.7889,  1.0055],
#         [-0.5052, -0.5997,  0.7099,  ..., -1.0818,  1.4182,  0.9949],
#         [-0.3560,  0.1086, -0.2621,  ...,  1.1272,  0.7274,  1.0046],
#         ...,
#         [-0.2056, -1.8489, -0.0916,  ...,  1.3894,  7.0024,  0.9994],
#         [-0.5232, -0.5769,  0.4596,  ..., -0.1066,  0.8682,  1.0008],
#         [-0.7447,  0.3713,  0.2083,  ...,  1.1825, -0.0921,  0.9963]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 8800/10000 | Total Loss: 740.5896606445312 | Recon Loss: 20.278973945617675 | KL Div: 39.73901700439453
# El código tardó 90.85370 segundos en ejecutarse.
# tensor([[-0.5021,  1.0480,  0.2471,  ...,  0.3238,  1.6764,  0.9966],
#         [-0.3270, -0.2120,  0.6758,  ..., -1.1186,  1.2614,  1.0135],
#         [-0.1647, -0.4331, -0.2654,  ...,  1.1970,  1.0010,  0.9905],
#         ...,
#         [-0.2851, -2.1593,  0.2150,  ...,  2.2770,  7.7947,  1.0018],
#         [-0.5123, -0.3645,  0.4811,  ..., -0.2190,  0.4009,  1.0077],
#         [-0.7695,  0.8390,  0.2585,  ...,  1.4822,  0.0811,  1.0000]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 8900/10000 | Total Loss: 769.3624267578125 | Recon Loss: 20.412908587646484 | KL Div: 39.65041406860352
# El código tardó 92.10425 segundos en ejecutarse.
# tensor([[-4.7984e-01,  9.4298e-01,  3.2574e-01,  ...,  5.7161e-01,
#           1.3753e+00,  9.9411e-01],
#         [-3.1870e-01, -4.9722e-02,  8.3680e-01,  ..., -5.9112e-01,
#           1.4787e+00,  9.9712e-01],
#         [-2.5482e-01, -1.5281e-01, -3.3579e-01,  ...,  7.5722e-01,
#           7.5406e-01,  9.8986e-01],
#         ...,
#         [-3.1283e-01, -2.0976e+00,  1.1487e-01,  ...,  1.9785e+00,
#           6.9983e+00,  9.8978e-01],
#         [-4.6299e-01, -4.5878e-01,  3.3720e-01,  ..., -9.0091e-03,
#           1.0208e+00,  1.0077e+00],
#         [-8.3946e-01,  6.1555e-01,  1.5803e-01,  ...,  1.0449e+00,
#          -3.3163e-03,  9.9494e-01]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 9000/10000 | Total Loss: 795.8297119140625 | Recon Loss: 20.301432760620116 | KL Div: 39.52445979003906
# El código tardó 91.21255 segundos en ejecutarse.
# tensor([[-0.4979,  1.6150,  0.5342,  ...,  0.5265,  1.7960,  0.9952],
#         [-0.3542, -0.2431,  0.6732,  ..., -0.9294,  0.9931,  1.0173],
#         [-0.4136, -0.3140, -0.1761,  ...,  1.0301,  0.7036,  0.9982],
#         ...,
#         [-0.0876, -2.2223,  0.0744,  ...,  2.4549,  7.5704,  0.9842],
#         [-0.4947, -0.7227,  0.4109,  ...,  0.0762,  0.7714,  1.0051],
#         [-0.8228,  0.5301,  0.1872,  ...,  0.9802, -0.1410,  0.9998]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 9100/10000 | Total Loss: 763.548583984375 | Recon Loss: 20.26855212097168 | KL Div: 39.56714704589844
# El código tardó 91.31389 segundos en ejecutarse.
# tensor([[-0.5714,  0.7780,  0.3810,  ...,  0.1357,  1.6773,  0.9940],
#         [-0.3243, -0.0878,  0.7408,  ..., -1.1041,  1.5019,  1.0031],
#         [-0.2516, -0.2763, -0.3400,  ...,  1.2066,  0.9510,  0.9801],
#         ...,
#         [-0.1688, -2.1161, -0.0420,  ...,  1.9232,  7.7958,  1.0330],
#         [-0.4814, -0.3332,  0.3689,  ..., -0.1054,  0.4864,  0.9894],
#         [-0.8150,  0.3776,  0.2844,  ...,  0.9198, -0.1388,  1.0027]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 9200/10000 | Total Loss: 778.58544921875 | Recon Loss: 20.22248762512207 | KL Div: 39.43145400390625
# El código tardó 92.37806 segundos en ejecutarse.
# tensor([[-0.5498,  0.6221,  0.4141,  ...,  0.4133,  1.4404,  1.0086],
#         [-0.3059, -0.4728,  0.7013,  ..., -0.9411,  1.4600,  1.0162],
#         [-0.3479, -0.1777, -0.2137,  ...,  0.8754,  0.6786,  1.0165],
#         ...,
#         [-0.2572, -1.8810,  0.2061,  ...,  2.1337,  7.2312,  0.9948],
#         [-0.5430, -0.5108,  0.4255,  ...,  0.0284,  0.8112,  0.9795],
#         [-0.7829,  0.3472,  0.1745,  ...,  1.2004, -0.1469,  1.0073]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 9300/10000 | Total Loss: 716.883056640625 | Recon Loss: 20.237542636108397 | KL Div: 39.47137569580078
# El código tardó 91.57750 segundos en ejecutarse.
# tensor([[-0.5734,  1.3226,  0.3361,  ...,  0.3163,  1.6957,  0.9764],
#         [-0.3302, -0.4864,  0.6534,  ..., -0.7271,  1.2668,  0.9994],
#         [-0.2784, -0.4011, -0.2439,  ...,  0.9866,  0.8593,  0.9951],
#         ...,
#         [-0.2472, -1.9829,  0.0390,  ...,  1.5635,  7.4615,  0.9903],
#         [-0.5314, -0.2540,  0.5632,  ..., -0.1659,  0.7788,  0.9917],
#         [-0.8718,  0.4774,  0.2503,  ...,  0.5002, -0.1063,  0.9930]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 9400/10000 | Total Loss: 734.7131958007812 | Recon Loss: 20.26410415649414 | KL Div: 39.5033299194336
# El código tardó 91.28380 segundos en ejecutarse.
# tensor([[-0.6206,  0.8714,  0.4158,  ...,  0.2974,  1.7028,  0.9673],
#         [-0.3992, -0.6418,  0.5663,  ..., -1.0659,  1.2676,  0.9880],
#         [-0.3862, -0.0615, -0.1398,  ...,  1.4488,  0.7739,  0.9799],
#         ...,
#         [-0.1800, -2.5214,  0.1244,  ...,  1.9289,  7.5465,  1.0177],
#         [-0.5879, -0.8271,  0.4636,  ...,  0.0657,  0.8154,  1.0028],
#         [-0.8355,  0.3890,  0.0644,  ...,  1.0687, -0.3103,  1.0080]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 9500/10000 | Total Loss: 760.001220703125 | Recon Loss: 20.233110804748534 | KL Div: 39.402969384765626
# El código tardó 90.85035 segundos en ejecutarse.
# tensor([[-0.6323,  1.5853,  0.3740,  ...,  0.3524,  1.7578,  1.0425],
#         [-0.3489, -0.1626,  0.4992,  ..., -0.9362,  1.2510,  0.9932],
#         [-0.3170, -0.7093, -0.2480,  ...,  0.5963,  0.3902,  1.0028],
#         ...,
#         [-0.2207, -1.5577,  0.0532,  ...,  2.3533,  7.0951,  1.0020],
#         [-0.5139, -0.7678,  0.4329,  ..., -0.1963,  0.8471,  1.0009],
#         [-0.7347,  0.0781,  0.2594,  ...,  0.8425, -0.0550,  1.0057]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 9600/10000 | Total Loss: 742.370849609375 | Recon Loss: 20.07698379058838 | KL Div: 39.22551899414062
# El código tardó 91.54067 segundos en ejecutarse.
# tensor([[-0.5284,  1.4975,  0.4266,  ...,  0.2286,  1.5933,  0.9989],
#         [-0.3389, -0.1859,  0.4922,  ..., -1.0440,  1.2685,  0.9953],
#         [-0.4653, -0.2826, -0.1457,  ...,  1.0624,  0.7972,  0.9806],
#         ...,
#         [-0.1299, -2.1722,  0.0808,  ...,  2.4244,  7.7101,  0.9635],
#         [-0.5025, -0.6589,  0.3801,  ...,  0.0731,  0.7778,  1.0182],
#         [-0.9269,  0.0182,  0.1997,  ...,  0.9502,  0.0809,  1.0032]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 9700/10000 | Total Loss: 742.4208984375 | Recon Loss: 20.001572508239747 | KL Div: 39.24254411621094
# El código tardó 91.97811 segundos en ejecutarse.
# tensor([[-0.6331,  1.1270,  0.2526,  ...,  0.5995,  1.7091,  0.9690],
#         [-0.2756, -0.4259,  0.6046,  ..., -0.9174,  1.1152,  0.9659],
#         [-0.3147, -0.7780, -0.1512,  ...,  0.6190,  0.6102,  0.9762],
#         ...,
#         [-0.1674, -1.7803,  0.1665,  ...,  1.8733,  6.9297,  0.9939],
#         [-0.6271, -0.5951,  0.3587,  ...,  0.0819,  0.7200,  0.9988],
#         [-0.7905,  0.6524,  0.1263,  ...,  0.7463, -0.1119,  0.9960]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 9800/10000 | Total Loss: 732.8421020507812 | Recon Loss: 19.967699206542967 | KL Div: 39.22110521850586
# El código tardó 91.14784 segundos en ejecutarse.
# tensor([[-0.5188,  0.8249,  0.2803,  ...,  0.1966,  1.6461,  0.9799],
#         [-0.3455, -0.0851,  0.5551,  ..., -0.8496,  1.2135,  0.9991],
#         [-0.3455, -0.4100, -0.2211,  ...,  0.6420,  0.7827,  0.9962],
#         ...,
#         [-0.3685, -1.5548,  0.1675,  ...,  2.4445,  6.8080,  0.9876],
#         [-0.4918, -0.2373,  0.3380,  ...,  0.1274,  0.7184,  1.0005],
#         [-0.7284, -0.3987,  0.2218,  ...,  0.4477, -0.3081,  1.0044]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 9900/10000 | Total Loss: 725.57373046875 | Recon Loss: 20.006189559936523 | KL Div: 39.14934406738281
# El código tardó 93.17600 segundos en ejecutarse.
# tensor([[-0.6805,  1.0431,  0.4223,  ...,  0.5498,  1.7523,  1.0051],
#         [-0.3641, -0.2318,  0.6236,  ..., -0.9422,  1.4778,  0.9939],
#         [-0.2309, -0.9996, -0.3052,  ...,  0.9534,  0.6038,  0.9928],
#         ...,
#         [-0.2056, -2.2855, -0.0109,  ...,  1.9391,  7.6652,  1.0194],
#         [-0.5998, -0.9034,  0.4279,  ..., -0.0948,  0.8695,  1.0133],
#         [-0.8232,  0.2767,  0.1648,  ...,  1.1735, -0.1782,  1.0064]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# Epoch 10000/10000 | Total Loss: 716.3187255859375 | Recon Loss: 19.997579122924805 | KL Div: 39.096192864990236
# El código tardó 91.31416 segundos en ejecutarse.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from sklearn.svm import SVC
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from scipy.spatial.distance import cdist
from scipy.stats import wasserstein_distance, ks_2samp
import sys
sys.setrecursionlimit(20000)
# Cargamos los datos
expr_data = pd.read_csv(fnexpr)
meth_data = pd.read_csv(fnmet)
assig_data = pd.read_csv(fnassig)
expr_data = expr_data.iloc[:, 1:]
meth_data = meth_data.iloc[:, 1:]
assig_data = assig_data.iloc[:, 2:]

# Convertir todas las columnas a tipo float
expr_data = expr_data.apply(pd.to_numeric, errors='coerce')
meth_data = meth_data.apply(pd.to_numeric, errors='coerce')
assig_data = assig_data.apply(pd.to_numeric, errors='coerce')

# Lidiar con valores NaN (si los hay). Pone 0 (CAMBIAR)
#expr_data.fillna(0, inplace=True)
#meth_data.fillna(0, inplace=True)
#assig_data.fillna(0, inplace=True)

expr_data = scaler.fit_transform(expr_data)
meth_data = scaler.fit_transform(meth_data)
expr_data = pd.DataFrame(expr_data)
meth_data = pd.DataFrame(meth_data)
assig_data = pd.DataFrame(assig_data)

# Combinamos los datos de expresión génica y metilación
X_real = pd.concat([expr_data, meth_data], axis=1)

# Generar datos de expresión sintética
vae = VAE(expression_data.shape[1],methylation_data.shape[1],assign_data.shape[1],ldim).to(device)
vae.load_state_dict(torch.load(fnmodel))
vae.eval()

# Función para reparametrización (para generar muestras del espacio latente)

# Generar datos de expresión sintética

with torch.no_grad():
    z = torch.randn(nsamp, ldim).to(device)
    synthetic_expression = vae.decoder(z).to(device)
    synthetic_expression = torch.sigmoid(synthetic_expression)
    #print(synthetic_expression)
    expressions_list=synthetic_expression.detach().cpu().numpy().squeeze()

X_gan = pd.DataFrame(expressions_list)
#X = X.apply(pd.to_numeric, errors='coerce')
y = X_gan.iloc[:, -1].values.astype(int)  

X = X_gan.iloc[:, :-1]

last_column = X_gan.columns[-1]
X_gan = X_gan.drop(columns=[last_column])
X_gan.columns = X_real.columns
# Concatena los datos reales con los generados
X_combined = np.vstack([X_real, X_gan])



# Aplanar los datos para cálculos estadísticos
real_data_flattened = X_real.values.flatten()
generated_data_flattened = X_gan.values.flatten()

# Wasserstein Distance
w_distance = wasserstein_distance(real_data_flattened, generated_data_flattened)

# KS Test
ks_statistic, ks_pvalue = ks_2samp(real_data_flattened, generated_data_flattened)

print(f"Wasserstein Distance: {w_distance}")
print(f"KS Statistic: {ks_statistic}, P-Value: {ks_pvalue}")

# Suponiendo que X_real y X_gan son tus dos grupos de datos
distancias_euclidianas = cdist(X_real, X_gan, metric='euclidean')

# Calcular la distancia promedio
distancia_promedio_euclidiana = np.mean(distancias_euclidianas)
print("Distancia Euclidiana Promedio:", distancia_promedio_euclidiana)

# Calcula las matrices de correlación
corr_real = X_real.corr()
corr_gan = X_gan.corr()

# Dibuja las matrices de correlación
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.heatmap(corr_real, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix (Real Data)')

plt.subplot(1, 2, 2)
sns.heatmap(corr_gan, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix (Generated Data)')

plt.show()

# Etiquetas: 1 para real, 0 para generado
y_real = [1] * X_real.shape[0]
y_gan = [0] * X_gan.shape[0]

# Combina los datos y las etiquetas
#X_combined = pd.concat([X_real, X_gan], axis=0)
y_combined = y_real + y_gan

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_combined, y_combined, test_size=0.3, random_state=42)

# Inicializa y entrena el clasificador SVC
svc = SVC()
svc.fit(X_train, y_train)

# Realiza predicciones en el conjunto de prueba
y_pred = svc.predict(X_test)
# Evalúa el rendimiento del clasificador
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Truth')
if (save): plt.savefig(filename+"SVC1.jpg")
plt.show()


# Dividimos los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Entrenamos el modelo SVC
clf = SVC()
unique_classes = np.unique(y_train)
if len(unique_classes) > 1:
    clf.fit(X_train, y_train)
    # Predicciones
    y_pred = clf.predict(X_test)
    
    # Métricas de clasificación
    print(classification_report(y_test, y_pred))
    
    # Matriz de confusión
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt='g')
    plt.xlabel('Predicted')
    plt.ylabel('Truth')
    if (save):plt.savefig(filename+"SVC2.jpg")
    plt.show()
else:
    print("SVC: Solo una clase")



# Clustering jerárquico
linked1 = linkage(X_real, method='ward')
linked2 = linkage(X_gan, method='ward')

plt.figure(figsize=(10, 7))
dendrogram(linked1, orientation='top', no_labels=True)
plt.title("Dendrograma jerárquico Real")
if (save):plt.savefig(filename+"DJR.jpg")
plt.show()

plt.figure(figsize=(10, 7))
dendrogram(linked2, orientation='top', no_labels=True)
plt.title("Dendrograma jerárquico Generado")
if (save):plt.savefig(filename+"DJG.jpg")
plt.show()


# K-Means
k = 2
kmeans = KMeans(n_clusters=k)
kmeans.fit(X_real)
labels = kmeans.predict(X_real)
centroids = kmeans.cluster_centers_
X_array = X_real.values
generated_data=X_gan.values
plt.scatter(X_array[:, 0], X_array[:, 1], c=labels, s=50, cmap='viridis')
plt.scatter(generated_data[:, 0], generated_data[:, 1], s=50, color='pink', label='Datos Generados')
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=200, alpha=0.75)
if (save):plt.savefig(filename+"KNN.jpg")
plt.show()

# t-SNE
# Crea etiquetas para los datos (1 para reales, 0 para GAN)
labels = np.concatenate([np.ones(X_real.shape[0]), np.zeros(X_gan.shape[0])])
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X_combined)

plt.scatter(X_tsne[labels==1, 0], X_tsne[labels==1, 1], c='blue', label='Real', s=3)
plt.scatter(X_tsne[labels==0, 0], X_tsne[labels==0, 1], c='red', label='Generated', s=3)
plt.legend()
plt.title('t-SNE visualization')
if (save):plt.savefig(filename+"tsne.jpg")
plt.show()



#PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_combined)

# Dibujar el resultado
plt.scatter(X_pca[labels==1, 0], X_pca[labels==1, 1], c='blue', label='Real', s=3)
plt.scatter(X_pca[labels==0, 0], X_pca[labels==0, 1], c='red', label='Generated', s=3)
plt.legend()
plt.title('PCA visualization')
if (save):plt.savefig(filename+"pca.jpg")
plt.show()


#KDE
column_names = X_real.columns.tolist()
random_columns = random.sample(column_names, 20)
for column_name in random_columns:
    sns.kdeplot(X_real[column_name], label='Real',color='blue')
    sns.kdeplot(X_gan[column_name], label='Generated',color='red')
    plt.legend()
    plt.title(f'Distribution for "{column_name}"')
    if (save):plt.savefig(f"{filename}kde-{column_name}.jpg")
    plt.show()
# Out:
# Wasserstein Distance: 0.7807878790943809
# KS Statistic: 0.5646333333333334, P-Value: 0.0
# Distancia Euclidiana Promedio: 24.471504056191815
# Accuracy: 1.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2983
#            1       1.00      1.00      1.00      3017
#
#     accuracy                           1.00      6000
#    macro avg       1.00      1.00      1.00      6000
# weighted avg       1.00      1.00      1.00      6000
# SVC: Solo una clase
# /home/fede/PyEnv/PB/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
