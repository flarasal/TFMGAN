# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import time
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
# Definir el generador y el discriminador
class Generator(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(Generator, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, 1024),
            nn.ReLU(),
            nn.Linear(1024, 2048),
            nn.ReLU(),
            nn.Linear(2048, 4096),
            nn.ReLU(),
            nn.Linear(4096, 8192),
            nn.ReLU(),
            nn.Linear(8192, output_dim),
            nn.Tanh()
                    
            
        )
        
    def forward(self, x):
        return self.net(x) *10

class Discriminator(nn.Module):
    def __init__(self, input_dim):
        super(Discriminator, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.LeakyReLU(0.2),
            nn.Linear(128, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 1),
            nn.Sigmoid()
            
            
        )
        
    def forward(self, x):
        return self.net(x)
        
# Leer datos
expression_data = pd.read_csv('expr.csv')
methylation_data = pd.read_csv('methyl.csv')
assign_data = pd.read_csv('assign.csv')

expression_data = expression_data.iloc[:, 1:]
methylation_data = methylation_data.iloc[:, 1:]
assign_data = assign_data.iloc[:, 2:]

# Convertir todas las columnas a tipo float
expression_data = expression_data.apply(pd.to_numeric, errors='coerce')
methylation_data = methylation_data.apply(pd.to_numeric, errors='coerce')
assign_data = assign_data.apply(pd.to_numeric, errors='coerce')
# Lidiar con valores NaN (si los hay). Pone 0(CAMBIAR)
expression_data.fillna(0, inplace=True)
methylation_data.fillna(0, inplace=True)
assign_data.fillna(0, inplace=True)

expression_data = expression_data.values
methylation_data = methylation_data.values
assign_data=assign_data.values
# Asegurar que tienes el mismo número de muestras en ambos conjuntos de datos


assert expression_data.shape[0] == methylation_data.shape[0], "Los datos de expresión y metilación deben tener el mismo número de muestras."
assert assign_data.shape[0] == methylation_data.shape[0], "Los datos de asignación y metilación deben tener el mismo número de muestras."

# Concatenar los datos
#combined_data =torch.FloatTensor(np.hstack((expression_data, methylation_data,assign_data)))
print(torch.cuda.is_available())
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device="cpu"
expression_data = torch.FloatTensor(expression_data).to(device)
methylation_data = torch.FloatTensor(methylation_data).to(device)
assign_data = torch.FloatTensor(assign_data).to(device)
combined_data = torch.cat((expression_data,methylation_data,assign_data), 1).to(device)
# Out:
# True

# %%
# Modelos y optimizadores
gen = Generator(100, expression_data.shape[1] + methylation_data.shape[1]+assign_data.shape[1]).to(device)
disc = Discriminator(expression_data.shape[1] + methylation_data.shape[1]+assign_data.shape[1]).to(device)
print(f'El modelo Generator tiene {count_parameters(gen)} parámetros entrenables.')
print(f'El modelo Discriminator tiene {count_parameters(disc)} parámetros entrenables.')
gen_optimizer = optim.Adam(gen.parameters(), lr=0.0002)
disc_optimizer = optim.Adam(disc.parameters(), lr=0.0002)
criterion = nn.BCELoss()

# Entrenamiento
n_samples = combined_data.size(0)
batch_size = 64
n_epochs = 10000
start_time = time.time()
for epoch in range(n_epochs):
    for idx in range(0, n_samples, batch_size):
        real_data = combined_data[idx:idx+batch_size].to(device)
        current_batch_size = real_data.size(0)
        real_labels = torch.ones(current_batch_size, 1).to(device)

        noise = torch.randn(current_batch_size, 100).to(device)
        #noise = expression_data[idx:idx+batch_size]
        
        fake_data = gen(noise).to(device)
        if ((epoch+1) % 100 == 0) and (idx ==0):
            print(fake_data)
        #fake_data = torch.cat((expression_data[idx:idx+batch_size],fake_methyl), 1)

        #fake_data = torch.cat((expression_data[idx:idx+batch_size],fake_methyl ), 1).to(device)

        fake_labels = torch.zeros(current_batch_size, 1).to(device)
        
        # Entrenar discriminador
        disc_optimizer.zero_grad()

        real_preds = disc(real_data).to(device)
        real_loss = criterion(real_preds, real_labels)
        
        fake_preds = disc(fake_data).to(device)
        fake_loss = criterion(fake_preds, fake_labels)

        disc_loss = real_loss + fake_loss
        disc_loss.backward()
        disc_optimizer.step()

        # Entrenar generador
        gen_optimizer.zero_grad()

        noise = torch.randn(current_batch_size, 100).to(device)
        fake_data = gen(noise).to(device)
        #fake_data = torch.cat((expression_data[idx:idx+batch_size],fake_methyl ), 1).to(device)
        fake_preds = disc(fake_data).to(device)

        gen_loss = criterion(fake_preds, real_labels)
        gen_loss.backward()
        gen_optimizer.step()

    if (epoch+1) % 100 == 0:
        print(f"Epoch {epoch+1}/{n_epochs} | Disc Loss: {disc_loss.item()} | Gen Loss: {gen_loss.item()}")
        end_time = time.time()

        # Calcular la diferencia de tiempo
        elapsed_time = end_time - start_time

        print(f"El código tardó {elapsed_time:.5f} segundos en ejecutarse.")
        start_time = time.time()

torch.save(gen.state_dict(), 'generator_model.pth')
# Out:
# El modelo Generator tiene 48845683 parámetros entrenables.
# El modelo Discriminator tiene 229121 parámetros entrenables.
# tensor([[ 1.1562,  6.8383, -1.1249,  ...,  1.6217, -0.3404,  1.3955],
#         [ 1.1706,  6.8724, -1.1347,  ...,  1.6396, -0.3468,  1.4099],
#         [ 1.0929,  6.6729, -1.0730,  ...,  1.5520, -0.3117,  1.3417],
#         ...,
#         [ 1.1647,  6.8578, -1.1295,  ...,  1.6307, -0.3416,  1.4020],
#         [ 1.1572,  6.8411, -1.1227,  ...,  1.6266, -0.3395,  1.3991],
#         [ 1.1604,  6.8502, -1.1288,  ...,  1.6308, -0.3465,  1.4035]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 100/10000 | Disc Loss: 1.4542443752288818 | Gen Loss: 0.6447799801826477
# El código tardó 15.83268 segundos en ejecutarse.
# tensor([[-0.2670,  5.6177, -0.5346,  ...,  0.3652,  0.6384,  1.2656],
#         [-0.2595,  5.5943, -0.5118,  ...,  0.3958,  0.6559,  1.2512],
#         [-0.2712,  5.6171, -0.5297,  ...,  0.3657,  0.6432,  1.2673],
#         ...,
#         [-0.2626,  5.6098, -0.5281,  ...,  0.3745,  0.6415,  1.2584],
#         [-0.2603,  5.6054, -0.5257,  ...,  0.3793,  0.6432,  1.2552],
#         [-0.2580,  5.6168, -0.5420,  ...,  0.3596,  0.6265,  1.2567]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 200/10000 | Disc Loss: 1.3865151405334473 | Gen Loss: 0.6713319420814514
# El código tardó 15.66663 segundos en ejecutarse.
# tensor([[-1.1072,  9.2926,  0.7497,  ...,  2.0454,  1.1621,  2.7185],
#         [-1.2164,  9.4306,  0.8233,  ...,  2.2327,  1.2511,  2.8725],
#         [-1.2358,  9.4528,  0.8371,  ...,  2.2669,  1.2674,  2.9002],
#         ...,
#         [-1.2176,  9.4347,  0.8206,  ...,  2.2374,  1.2518,  2.8777],
#         [-1.0747,  9.2531,  0.7208,  ...,  1.9920,  1.1366,  2.6813],
#         [-1.2786,  9.4961,  0.8633,  ...,  2.3372,  1.3008,  2.9571]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 300/10000 | Disc Loss: 1.2934083938598633 | Gen Loss: 0.7321257591247559
# El código tardó 15.07706 segundos en ejecutarse.
# tensor([[-0.8788,  3.7340, -0.6942,  ...,  0.1334,  0.3452, -0.1333],
#         [-0.8788,  3.7332, -0.6938,  ...,  0.1335,  0.3446, -0.1337],
#         [-0.8778,  3.7354, -0.6959,  ...,  0.1323,  0.3470, -0.1333],
#         ...,
#         [-0.8792,  3.7329, -0.6933,  ...,  0.1339,  0.3440, -0.1337],
#         [-0.8782,  3.7344, -0.6949,  ...,  0.1329,  0.3459, -0.1333],
#         [-0.8783,  3.7340, -0.6946,  ...,  0.1331,  0.3455, -0.1336]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 400/10000 | Disc Loss: 1.6439354419708252 | Gen Loss: 0.3484301269054413
# El código tardó 15.73829 segundos en ejecutarse.
# tensor([[ 0.2366,  9.7241, -2.4922,  ...,  3.1112,  0.0910,  3.0770],
#         [ 0.2422,  9.7379, -2.5256,  ...,  3.1504,  0.0895,  3.1089],
#         [ 0.2307,  9.7063, -2.4509,  ...,  3.0631,  0.0930,  3.0381],
#         ...,
#         [ 0.2072,  9.6516, -2.3458,  ...,  2.9312,  0.0904,  2.9474],
#         [ 0.2977,  9.8370, -2.8202,  ...,  3.5000,  0.0882,  3.3712],
#         [ 0.2910,  9.8295, -2.7934,  ...,  3.4682,  0.0865,  3.3500]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 500/10000 | Disc Loss: 1.349205732345581 | Gen Loss: 0.8941594958305359
# El código tardó 15.70869 segundos en ejecutarse.
# tensor([[-6.5780e-01,  6.4080e+00, -9.0569e-01,  ...,  9.8448e-01,
#          -3.8267e-03,  1.2137e+00],
#         [-6.5926e-01,  6.4236e+00, -9.1346e-01,  ...,  9.9139e-01,
#          -5.1349e-03,  1.2172e+00],
#         [-6.7212e-01,  6.5855e+00, -9.9756e-01,  ...,  1.0686e+00,
#          -1.9448e-02,  1.2543e+00],
#         ...,
#         [-6.5537e-01,  6.3855e+00, -8.9391e-01,  ...,  9.7307e-01,
#          -1.9135e-03,  1.2089e+00],
#         [-6.4942e-01,  6.3354e+00, -8.6800e-01,  ...,  9.4994e-01,
#           2.3793e-03,  1.1980e+00],
#         [-6.5417e-01,  6.3704e+00, -8.8648e-01,  ...,  9.6699e-01,
#          -8.8966e-04,  1.2059e+00]], device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 600/10000 | Disc Loss: 1.3035953044891357 | Gen Loss: 0.7508924603462219
# El código tardó 15.79490 segundos en ejecutarse.
# tensor([[-0.6275,  5.6208, -0.3871,  ...,  0.8693,  0.1376,  0.7293],
#         [-0.6262,  5.6197, -0.3875,  ...,  0.8598,  0.1410,  0.7235],
#         [-0.6200,  5.6087, -0.3920,  ...,  0.8315,  0.1510,  0.7035],
#         ...,
#         [-0.6244,  5.6187, -0.3878,  ...,  0.8598,  0.1395,  0.7246],
#         [-0.6287,  5.6215, -0.3864,  ...,  0.8652,  0.1398,  0.7263],
#         [-0.6320,  5.6259, -0.3860,  ...,  0.8736,  0.1366,  0.7325]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 700/10000 | Disc Loss: 1.25046968460083 | Gen Loss: 0.7923097610473633
# El código tardó 15.82909 segundos en ejecutarse.
# tensor([[-0.7107,  6.0330, -0.5532,  ...,  0.7883,  0.0351,  0.9972],
#         [-0.7115,  6.0368, -0.5538,  ...,  0.7891,  0.0366,  0.9968],
#         [-0.7109,  6.0320, -0.5531,  ...,  0.7901,  0.0348,  0.9970],
#         ...,
#         [-0.7108,  6.0316, -0.5537,  ...,  0.7908,  0.0338,  0.9976],
#         [-0.7103,  6.0315, -0.5540,  ...,  0.7914,  0.0321,  0.9989],
#         [-0.7104,  6.0291, -0.5528,  ...,  0.7895,  0.0335,  0.9980]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 800/10000 | Disc Loss: 1.2438453435897827 | Gen Loss: 0.8025887608528137
# El código tardó 15.80740 segundos en ejecutarse.
# tensor([[-0.7405,  6.3275, -0.6149,  ...,  1.0914, -0.0817,  0.7657],
#         [-0.7439,  6.3447, -0.6206,  ...,  1.0979, -0.0799,  0.7642],
#         [-0.7453,  6.3234, -0.6150,  ...,  1.0971, -0.0794,  0.7590],
#         ...,
#         [-0.7435,  6.2802, -0.6038,  ...,  1.0936, -0.0802,  0.7533],
#         [-0.7420,  6.3078, -0.6098,  ...,  1.0918, -0.0812,  0.7605],
#         [-0.7427,  6.3205, -0.6132,  ...,  1.0931, -0.0811,  0.7621]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 900/10000 | Disc Loss: 1.2483868598937988 | Gen Loss: 0.7956069111824036
# El código tardó 15.92833 segundos en ejecutarse.
# tensor([[-0.6510,  6.4143, -0.1123,  ...,  0.4479,  0.7557,  1.2559],
#         [-0.6506,  6.4109, -0.1125,  ...,  0.4481,  0.7548,  1.2547],
#         [-0.6510,  6.4146, -0.1127,  ...,  0.4477,  0.7551,  1.2567],
#         ...,
#         [-0.6509,  6.4134, -0.1125,  ...,  0.4478,  0.7553,  1.2558],
#         [-0.6514,  6.4179, -0.1119,  ...,  0.4477,  0.7570,  1.2569],
#         [-0.6510,  6.4146, -0.1124,  ...,  0.4479,  0.7556,  1.2563]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 1000/10000 | Disc Loss: 1.4617226123809814 | Gen Loss: 0.8388914465904236
# El código tardó 15.88806 segundos en ejecutarse.
# tensor([[-0.8718,  8.8864, -1.5734,  ...,  2.2138,  0.2341,  1.3636],
#         [-0.8950,  9.0041, -1.6415,  ...,  2.3048,  0.2498,  1.4188],
#         [-0.8763,  8.9080, -1.5853,  ...,  2.2298,  0.2370,  1.3731],
#         ...,
#         [-0.8692,  8.8701, -1.5643,  ...,  2.2019,  0.2322,  1.3562],
#         [-0.9781,  9.3456, -1.8892,  ...,  2.6388,  0.3079,  1.6233],
#         [-0.8549,  8.7897, -1.5222,  ...,  2.1457,  0.2222,  1.3221]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 1100/10000 | Disc Loss: 1.2517931461334229 | Gen Loss: 0.8410887718200684
# El código tardó 24.16225 segundos en ejecutarse.
# tensor([[-0.9445,  6.2065, -0.6518,  ...,  0.9041, -0.0138,  0.8938],
#         [-0.8762,  5.9309, -0.6049,  ...,  0.8391, -0.0265,  0.8323],
#         [-0.7630,  5.4475, -0.5244,  ...,  0.7285, -0.0476,  0.7293],
#         ...,
#         [-0.7504,  5.3919, -0.5147,  ...,  0.7139, -0.0500,  0.7180],
#         [-0.7376,  5.3550, -0.5034,  ...,  0.7043, -0.0513,  0.7092],
#         [-0.7260,  5.3105, -0.4959,  ...,  0.6921, -0.0537,  0.7010]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 1200/10000 | Disc Loss: 1.2460601329803467 | Gen Loss: 0.77974933385849
# El código tardó 30.25438 segundos en ejecutarse.
# tensor([[-0.5213,  4.6516, -0.4160,  ...,  0.7999, -0.0286,  0.6996],
#         [-0.5185,  4.5872, -0.4048,  ...,  0.7944, -0.0352,  0.6941],
#         [-0.5215,  4.6963, -0.4243,  ...,  0.8065, -0.0245,  0.7038],
#         ...,
#         [-0.5211,  4.6806, -0.4227,  ...,  0.8045, -0.0264,  0.7022],
#         [-0.5207,  4.6589, -0.4177,  ...,  0.8033, -0.0286,  0.7008],
#         [-0.5208,  4.6664, -0.4190,  ...,  0.8039, -0.0278,  0.7016]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 1300/10000 | Disc Loss: 1.2503113746643066 | Gen Loss: 0.8220520615577698
# El código tardó 30.52710 segundos en ejecutarse.
# tensor([[-0.4126,  5.5471, -0.5019,  ...,  1.2980, -0.0757,  0.9342],
#         [-0.4123,  5.5478, -0.5024,  ...,  1.2973, -0.0748,  0.9338],
#         [-0.4119,  5.5513, -0.5026,  ...,  1.3022, -0.0750,  0.9371],
#         ...,
#         [-0.4117,  5.5532, -0.5028,  ...,  1.3033, -0.0751,  0.9380],
#         [-0.4119,  5.5510, -0.5025,  ...,  1.3009, -0.0750,  0.9364],
#         [-0.4122,  5.5492, -0.5023,  ...,  1.3008, -0.0750,  0.9361]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 1400/10000 | Disc Loss: 1.2492353916168213 | Gen Loss: 0.8243756890296936
# El código tardó 30.59228 segundos en ejecutarse.
# tensor([[-0.3895,  6.1306, -1.0600,  ...,  0.8123, -0.1873,  1.6141],
#         [-0.3760,  6.4169, -1.1449,  ...,  0.8469, -0.2234,  1.7858],
#         [-0.3949,  6.0177, -1.0278,  ...,  0.7993, -0.1727,  1.5471],
#         ...,
#         [-0.3696,  6.5308, -1.1793,  ...,  0.8614, -0.2393,  1.8588],
#         [-0.3826,  6.2676, -1.1000,  ...,  0.8286, -0.2047,  1.6961],
#         [-0.3607,  6.7303, -1.2418,  ...,  0.8873, -0.2676,  1.9874]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 1500/10000 | Disc Loss: 1.3469719886779785 | Gen Loss: 0.6938765048980713
# El código tardó 40.12319 segundos en ejecutarse.
# tensor([[-0.6739,  5.7133, -0.4334,  ...,  0.6900,  0.0239,  0.8211],
#         [-0.6756,  5.7197, -0.4343,  ...,  0.6920,  0.0243,  0.8211],
#         [-0.6781,  5.7322, -0.4360,  ...,  0.6946,  0.0246,  0.8224],
#         ...,
#         [-0.6737,  5.7115, -0.4331,  ...,  0.6899,  0.0240,  0.8207],
#         [-0.6774,  5.7283, -0.4354,  ...,  0.6939,  0.0246,  0.8219],
#         [-0.6749,  5.7164, -0.4339,  ...,  0.6911,  0.0241,  0.8211]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 1600/10000 | Disc Loss: 1.3410191535949707 | Gen Loss: 0.7392522692680359
# El código tardó 47.98272 segundos en ejecutarse.
# tensor([[-0.5758,  4.9450, -0.6179,  ...,  0.4806,  0.0747,  0.8845],
#         [-0.5758,  4.9449, -0.6179,  ...,  0.4806,  0.0747,  0.8845],
#         [-0.5758,  4.9451, -0.6179,  ...,  0.4806,  0.0747,  0.8846],
#         ...,
#         [-0.5758,  4.9449, -0.6179,  ...,  0.4806,  0.0747,  0.8845],
#         [-0.5758,  4.9450, -0.6179,  ...,  0.4806,  0.0747,  0.8845],
#         [-0.5758,  4.9449, -0.6179,  ...,  0.4806,  0.0747,  0.8845]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 1700/10000 | Disc Loss: 1.486647367477417 | Gen Loss: 0.42829883098602295
# El código tardó 47.76683 segundos en ejecutarse.
# tensor([[-0.5694,  5.5966, -0.5636,  ...,  0.8325,  0.0073,  0.8230],
#         [-0.5694,  5.5966, -0.5636,  ...,  0.8325,  0.0073,  0.8230],
#         [-0.5694,  5.5966, -0.5636,  ...,  0.8325,  0.0073,  0.8230],
#         ...,
#         [-0.5694,  5.5966, -0.5636,  ...,  0.8325,  0.0073,  0.8230],
#         [-0.5694,  5.5966, -0.5636,  ...,  0.8325,  0.0073,  0.8230],
#         [-0.5694,  5.5966, -0.5636,  ...,  0.8325,  0.0073,  0.8230]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 1800/10000 | Disc Loss: 0.8815646171569824 | Gen Loss: 1.9212872982025146
# El código tardó 47.61749 segundos en ejecutarse.
# tensor([[-0.6836,  5.7843, -0.6286,  ...,  0.5799,  0.0340,  1.0565],
#         [-0.6836,  5.7843, -0.6286,  ...,  0.5799,  0.0340,  1.0565],
#         [-0.6836,  5.7843, -0.6286,  ...,  0.5799,  0.0340,  1.0565],
#         ...,
#         [-0.6836,  5.7843, -0.6286,  ...,  0.5799,  0.0340,  1.0565],
#         [-0.6836,  5.7843, -0.6286,  ...,  0.5799,  0.0340,  1.0565],
#         [-0.6836,  5.7843, -0.6286,  ...,  0.5799,  0.0340,  1.0565]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 1900/10000 | Disc Loss: 0.453838974237442 | Gen Loss: 5.106383323669434
# El código tardó 47.52676 segundos en ejecutarse.
# tensor([[-0.7087,  6.6146, -0.6604,  ...,  1.2724,  0.0337,  0.9896],
#         [-0.7087,  6.6146, -0.6604,  ...,  1.2724,  0.0337,  0.9896],
#         [-0.7087,  6.6146, -0.6604,  ...,  1.2724,  0.0337,  0.9896],
#         ...,
#         [-0.7087,  6.6146, -0.6604,  ...,  1.2724,  0.0337,  0.9896],
#         [-0.7087,  6.6146, -0.6604,  ...,  1.2724,  0.0337,  0.9896],
#         [-0.7087,  6.6146, -0.6604,  ...,  1.2724,  0.0337,  0.9896]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 2000/10000 | Disc Loss: 1.076694369316101 | Gen Loss: 2.3562779426574707
# El código tardó 47.44772 segundos en ejecutarse.
# tensor([[-3.2354,  9.9926, -1.1168,  ..., -5.4525, -4.8801,  4.4976],
#         [-3.2161,  9.9921, -1.1068,  ..., -5.3998, -4.8371,  4.4590],
#         [-3.0305,  9.9828, -0.9955,  ..., -4.8449, -4.3884,  4.0341],
#         ...,
#         [-3.1745,  9.9906, -1.0819,  ..., -5.2805, -4.7405,  4.3674],
#         [-3.5227,  9.9979, -1.2995,  ..., -6.2230, -5.5318,  5.1297],
#         [-2.9901,  9.9799, -0.9751,  ..., -4.7252, -4.2934,  3.9489]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 2100/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.39333 segundos en ejecutarse.
# tensor([[-3.2636,  9.9935, -1.1346,  ..., -5.5326, -4.9459,  4.5615],
#         [-3.3910,  9.9962, -1.2156,  ..., -5.8799, -5.2378,  4.8446],
#         [-3.2307,  9.9925, -1.1138,  ..., -5.4381, -4.8688,  4.4877],
#         ...,
#         [-3.9759,  9.9997, -1.5988,  ..., -7.2864, -6.4822,  6.0801],
#         [-3.5085,  9.9977, -1.2893,  ..., -6.1845, -5.4984,  5.0967],
#         [-3.2903,  9.9942, -1.1520,  ..., -5.6084, -5.0090,  4.6229]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 2200/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.53746 segundos en ejecutarse.
# tensor([[-3.8322,  9.9995, -1.5021,  ..., -6.9723, -6.1932,  5.7899],
#         [-3.3059,  9.9946, -1.1632,  ..., -5.6536, -5.0475,  4.6618],
#         [-3.1710,  9.9904, -1.0785,  ..., -5.2658, -4.7285,  4.3549],
#         ...,
#         [-3.4843,  9.9975, -1.2750,  ..., -6.1232, -5.4462,  5.0472],
#         [-3.1442,  9.9893, -1.0631,  ..., -5.1887, -4.6660,  4.2966],
#         [-3.0624,  9.9849, -1.0141,  ..., -4.9408, -4.4652,  4.1067]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 2300/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.47155 segundos en ejecutarse.
# tensor([[ 5.6018e-01,  9.9824e+00,  1.9865e+00,  ..., -5.0058e+00,
#          -6.7257e-01,  3.0589e-01],
#         [ 2.5017e-01,  9.9621e+00,  1.6602e+00,  ..., -4.3492e+00,
#          -6.5199e-01,  3.9969e-01],
#         [ 5.3600e-03,  9.9346e+00,  1.4088e+00,  ..., -3.8280e+00,
#          -6.3846e-01,  4.8903e-01],
#         ...,
#         [ 6.9534e-01,  9.9874e+00,  2.1301e+00,  ..., -5.2795e+00,
#          -6.8284e-01,  2.6454e-01],
#         [ 4.3082e-01,  9.9758e+00,  1.8524e+00,  ..., -4.7415e+00,
#          -6.6469e-01,  3.4437e-01],
#         [ 6.5892e-01,  9.9863e+00,  2.0922e+00,  ..., -5.2086e+00,
#          -6.8027e-01,  2.7522e-01]], device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 2400/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.39116 segundos en ejecutarse.
# tensor([[ 0.4813,  9.9786,  1.9036,  ..., -4.8430, -0.6672,  0.3295],
#         [ 0.3696,  9.9716,  1.7841,  ..., -4.6040, -0.6587,  0.3640],
#         [ 0.5286,  9.9810,  1.9543,  ..., -4.9424, -0.6708,  0.3155],
#         ...,
#         [ 0.1649,  9.9538,  1.5716,  ..., -4.1666, -0.6464,  0.4289],
#         [ 0.0963,  9.9464,  1.5019,  ..., -4.0227, -0.6429,  0.4551],
#         [ 0.0463,  9.9401,  1.4500,  ..., -3.9151, -0.6401,  0.4736]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 2500/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.52718 segundos en ejecutarse.
# tensor([[ 0.3181,  9.9679,  1.7314,  ..., -4.4963, -0.6561,  0.3792],
#         [ 0.3518,  9.9706,  1.7689,  ..., -4.5724, -0.6592,  0.3687],
#         [ 0.4252,  9.9754,  1.8455,  ..., -4.7276, -0.6639,  0.3465],
#         ...,
#         [ 0.2412,  9.9611,  1.6493,  ..., -4.3268, -0.6506,  0.4027],
#         [ 0.2534,  9.9623,  1.6625,  ..., -4.3547, -0.6515,  0.3990],
#         [ 0.2922,  9.9658,  1.7041,  ..., -4.4400, -0.6544,  0.3868]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 2600/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.45162 segundos en ejecutarse.
# tensor([[-0.2483,  9.8850,  1.1429,  ..., -3.2564, -0.6232,  0.5854],
#         [ 0.1457,  9.9521,  1.5548,  ..., -4.1318, -0.6467,  0.4355],
#         [ 0.5648,  9.9827,  1.9948,  ..., -5.0208, -0.6746,  0.3037],
#         ...,
#         [ 0.3144,  9.9677,  1.7293,  ..., -4.4924, -0.6566,  0.3799],
#         [ 0.1683,  9.9541,  1.5744,  ..., -4.1723, -0.6465,  0.4280],
#         [ 0.2459,  9.9615,  1.6528,  ..., -4.3348, -0.6502,  0.4016]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 2700/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.40088 segundos en ejecutarse.
# tensor([[ 0.1035,  9.9470,  1.5070,  ..., -4.0327, -0.6423,  0.4526],
#         [ 0.3196,  9.9681,  1.7339,  ..., -4.5017, -0.6567,  0.3784],
#         [ 0.1215,  9.9494,  1.5293,  ..., -4.0790, -0.6452,  0.4450],
#         ...,
#         [ 0.1479,  9.9520,  1.5537,  ..., -4.1291, -0.6452,  0.4356],
#         [ 0.2525,  9.9623,  1.6622,  ..., -4.3541, -0.6517,  0.3991],
#         [ 0.2606,  9.9630,  1.6712,  ..., -4.3723, -0.6526,  0.3965]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 2800/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.43377 segundos en ejecutarse.
# tensor([[ 0.0564,  9.9411,  1.4581,  ..., -3.9311, -0.6395,  0.4705],
#         [ 0.0375,  9.9383,  1.4363,  ..., -3.8854, -0.6372,  0.4780],
#         [ 0.1672,  9.9538,  1.5711,  ..., -4.1654, -0.6453,  0.4291],
#         ...,
#         [ 0.1135,  9.9482,  1.5178,  ..., -4.0551, -0.6432,  0.4486],
#         [ 0.4112,  9.9745,  1.8294,  ..., -4.6952, -0.6622,  0.3508],
#         [ 0.0901,  9.9456,  1.4951,  ..., -4.0082, -0.6425,  0.4574]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 2900/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.39313 segundos en ejecutarse.
# tensor([[ 1.5186e-02,  9.9357e+00,  1.4166e+00,  ..., -3.8443e+00,
#          -6.3783e-01,  4.8584e-01],
#         [ 5.2356e-01,  9.9807e+00,  1.9480e+00,  ..., -4.9303e+00,
#          -6.7013e-01,  3.1714e-01],
#         [ 4.4130e-01,  9.9764e+00,  1.8623e+00,  ..., -4.7607e+00,
#          -6.6500e-01,  3.4194e-01],
#         ...,
#         [ 3.2023e-01,  9.9681e+00,  1.7341e+00,  ..., -4.5020e+00,
#          -6.5619e-01,  3.7841e-01],
#         [ 1.4667e-02,  9.9356e+00,  1.4163e+00,  ..., -3.8438e+00,
#          -6.3787e-01,  4.8607e-01],
#         [ 5.1901e-03,  9.9343e+00,  1.4067e+00,  ..., -3.8238e+00,
#          -6.3723e-01,  4.8977e-01]], device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 3000/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.42396 segundos en ejecutarse.
# tensor([[ 8.2947e-03,  9.9349e+00,  1.4105e+00,  ..., -3.8319e+00,
#          -6.3772e-01,  4.8844e-01],
#         [ 2.2834e-01,  9.9598e+00,  1.6350e+00,  ..., -4.2974e+00,
#          -6.4949e-01,  4.0671e-01],
#         [ 1.8042e-01,  9.9553e+00,  1.5864e+00,  ..., -4.1971e+00,
#          -6.4696e-01,  4.2349e-01],
#         ...,
#         [-1.8255e-02,  9.9306e+00,  1.3815e+00,  ..., -3.7696e+00,
#          -6.3563e-01,  4.9836e-01],
#         [ 4.8805e-01,  9.9789e+00,  1.9100e+00,  ..., -4.8558e+00,
#          -6.6736e-01,  3.2793e-01],
#         [ 4.2929e-01,  9.9756e+00,  1.8487e+00,  ..., -4.7336e+00,
#          -6.6371e-01,  3.4566e-01]], device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 3100/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.41181 segundos en ejecutarse.
# tensor([[ 0.7325,  9.9885,  2.1667,  ..., -5.3483, -0.6842,  0.2537],
#         [-0.1869,  9.8995,  1.2072,  ..., -3.3958, -0.6266,  0.5619],
#         [ 0.1963,  9.9567,  1.6012,  ..., -4.2275, -0.6472,  0.4184],
#         ...,
#         [ 0.2116,  9.9583,  1.6180,  ..., -4.2623, -0.6486,  0.4125],
#         [ 0.1994,  9.9572,  1.6071,  ..., -4.2394, -0.6488,  0.4164],
#         [ 0.2283,  9.9598,  1.6353,  ..., -4.2978, -0.6497,  0.4066]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 3200/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.44966 segundos en ejecutarse.
# tensor([[ 0.3391,  9.9696,  1.7554,  ..., -4.5445, -0.6583,  0.3726],
#         [-0.0420,  9.9270,  1.3569,  ..., -3.7183, -0.6342,  0.5077],
#         [ 0.2720,  9.9642,  1.6846,  ..., -4.3999, -0.6539,  0.3930],
#         ...,
#         [ 0.5325,  9.9812,  1.9585,  ..., -4.9515, -0.6712,  0.3137],
#         [ 0.6779,  9.9868,  2.1104,  ..., -5.2428, -0.6809,  0.2702],
#         [ 0.6539,  9.9860,  2.0851,  ..., -5.1950, -0.6793,  0.2776]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 3300/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.49703 segundos en ejecutarse.
# tensor([[ 0.0385,  9.9388,  1.4399,  ..., -3.8932, -0.6387,  0.4771],
#         [ 0.1433,  9.9516,  1.5496,  ..., -4.1208, -0.6454,  0.4370],
#         [ 0.2924,  9.9656,  1.7022,  ..., -4.4364, -0.6533,  0.3877],
#         ...,
#         [ 0.2949,  9.9660,  1.7065,  ..., -4.4452, -0.6543,  0.3864],
#         [ 0.5006,  9.9796,  1.9256,  ..., -4.8866, -0.6694,  0.3233],
#         [ 0.0371,  9.9389,  1.4401,  ..., -3.8943, -0.6394,  0.4774]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 3400/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.49200 segundos en ejecutarse.
# tensor([[ 0.0583,  9.9415,  1.4612,  ..., -3.9377, -0.6402,  0.4697],
#         [ 0.4024,  9.9740,  1.8212,  ..., -4.6788, -0.6622,  0.3536],
#         [ 0.5422,  9.9815,  1.9662,  ..., -4.9657, -0.6707,  0.3121],
#         ...,
#         [ 0.1913,  9.9564,  1.5979,  ..., -4.2208, -0.6478,  0.4196],
#         [ 0.2979,  9.9663,  1.7107,  ..., -4.4533, -0.6550,  0.3853],
#         [ 0.2286,  9.9600,  1.6376,  ..., -4.3024, -0.6507,  0.4060]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 3500/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.50922 segundos en ejecutarse.
# tensor([[-0.0119,  9.9318,  1.3892,  ..., -3.7861, -0.6366,  0.4959],
#         [ 0.3402,  9.9697,  1.7567,  ..., -4.5479, -0.6585,  0.3719],
#         [ 0.4666,  9.9778,  1.8883,  ..., -4.8124, -0.6663,  0.3341],
#         ...,
#         [ 0.4180,  9.9750,  1.8376,  ..., -4.7120, -0.6631,  0.3487],
#         [ 0.2037,  9.9576,  1.6115,  ..., -4.2490, -0.6490,  0.4149],
#         [ 0.3728,  9.9720,  1.7904,  ..., -4.6164, -0.6605,  0.3623]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 3600/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.56093 segundos en ejecutarse.
# tensor([[ 0.5716,  9.9828,  1.9977,  ..., -5.0269, -0.6730,  0.3028],
#         [-0.2674,  9.8804,  1.1244,  ..., -3.2158, -0.6229,  0.5925],
#         [ 0.5159,  9.9803,  1.9399,  ..., -4.9143, -0.6696,  0.3193],
#         ...,
#         [ 0.2767,  9.9645,  1.6884,  ..., -4.4078, -0.6537,  0.3916],
#         [ 0.2422,  9.9612,  1.6495,  ..., -4.3277, -0.6504,  0.4024],
#         [ 0.0816,  9.9445,  1.4853,  ..., -3.9885, -0.6413,  0.4607]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 3700/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.47251 segundos en ejecutarse.
# tensor([[ 0.4961,  9.9793,  1.9198,  ..., -4.8744, -0.6685,  0.3252],
#         [ 0.3884,  9.9730,  1.8062,  ..., -4.6487, -0.6612,  0.3577],
#         [-0.2188,  9.8924,  1.1748,  ..., -3.3259, -0.6252,  0.5741],
#         ...,
#         [ 0.5478,  9.9818,  1.9741,  ..., -4.9811, -0.6721,  0.3098],
#         [ 0.5119,  9.9801,  1.9363,  ..., -4.9069, -0.6696,  0.3209],
#         [-0.1428,  9.9091,  1.2540,  ..., -3.4981, -0.6295,  0.5453]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 3800/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.55785 segundos en ejecutarse.
# tensor([[-0.1144,  9.9144,  1.2826,  ..., -3.5589, -0.6305,  0.5346],
#         [ 0.2033,  9.9577,  1.6121,  ..., -4.2496, -0.6496,  0.4143],
#         [ 0.2720,  9.9643,  1.6861,  ..., -4.4028, -0.6546,  0.3925],
#         ...,
#         [ 0.6304,  9.9852,  2.0602,  ..., -5.1476, -0.6774,  0.2845],
#         [ 0.6939,  9.9874,  2.1265,  ..., -5.2736, -0.6817,  0.2653],
#         [ 0.2996,  9.9665,  1.7140,  ..., -4.4604, -0.6559,  0.3844]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 3900/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.47869 segundos en ejecutarse.
# tensor([[ 0.3998,  9.9738,  1.8184,  ..., -4.6724, -0.6621,  0.3547],
#         [ 0.0646,  9.9425,  1.4691,  ..., -3.9542, -0.6413,  0.4668],
#         [ 0.1250,  9.9497,  1.5319,  ..., -4.0843, -0.6449,  0.4439],
#         ...,
#         [ 0.3183,  9.9680,  1.7332,  ..., -4.4996, -0.6569,  0.3789],
#         [ 0.4800,  9.9785,  1.9037,  ..., -4.8430, -0.6679,  0.3303],
#         [ 0.1321,  9.9503,  1.5373,  ..., -4.0953, -0.6443,  0.4415]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 4000/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.53651 segundos en ejecutarse.
# tensor([[ 0.2838,  9.9652,  1.6971,  ..., -4.4262, -0.6547,  0.3889],
#         [ 0.1801,  9.9555,  1.5890,  ..., -4.2019, -0.6484,  0.4233],
#         [ 0.1990,  9.9573,  1.6072,  ..., -4.2400, -0.6490,  0.4163],
#         ...,
#         [ 0.5999,  9.9840,  2.0276,  ..., -5.0852, -0.6751,  0.2941],
#         [ 0.0869,  9.9453,  1.4925,  ..., -4.0030, -0.6426,  0.4585],
#         [ 0.4295,  9.9757,  1.8500,  ..., -4.7363, -0.6641,  0.3453]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 4100/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.49207 segundos en ejecutarse.
# tensor([[ 0.0151,  9.9359,  1.4181,  ..., -3.8475, -0.6386,  0.4856],
#         [ 0.2283,  9.9599,  1.6364,  ..., -4.2999, -0.6502,  0.4066],
#         [-0.0502,  9.9256,  1.3487,  ..., -3.7003, -0.6340,  0.5107],
#         ...,
#         [-0.0488,  9.9262,  1.3521,  ..., -3.7078, -0.6351,  0.5096],
#         [ 0.1859,  9.9559,  1.5925,  ..., -4.2098, -0.6475,  0.4217],
#         [ 0.3583,  9.9709,  1.7739,  ..., -4.5828, -0.6588,  0.3671]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 4200/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.54469 segundos en ejecutarse.
# tensor([[-0.0406,  9.9273,  1.3591,  ..., -3.7229, -0.6348,  0.5068],
#         [-0.0714,  9.9223,  1.3286,  ..., -3.6575, -0.6336,  0.5183],
#         [ 0.1869,  9.9557,  1.5909,  ..., -4.2060, -0.6463,  0.4219],
#         ...,
#         [ 0.4715,  9.9781,  1.8956,  ..., -4.8268, -0.6677,  0.3324],
#         [-0.2949,  9.8730,  1.0963,  ..., -3.1538, -0.6220,  0.6027],
#         [ 0.0611,  9.9420,  1.4651,  ..., -3.9460, -0.6409,  0.4684]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 4300/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.58335 segundos en ejecutarse.
# tensor([[-0.2949,  9.8726,  1.0941,  ..., -3.1497, -0.6207,  0.6032],
#         [ 0.4752,  9.9782,  1.8980,  ..., -4.8312, -0.6673,  0.3316],
#         [ 0.7232,  9.9883,  2.1592,  ..., -5.3341, -0.6848,  0.2560],
#         ...,
#         [ 0.3208,  9.9681,  1.7347,  ..., -4.5028, -0.6565,  0.3784],
#         [ 0.3253,  9.9685,  1.7401,  ..., -4.5140, -0.6571,  0.3768],
#         [ 0.0977,  9.9464,  1.5019,  ..., -4.0226, -0.6425,  0.4546]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 4400/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.60098 segundos en ejecutarse.
# tensor([[ 0.3896,  9.9733,  1.8117,  ..., -4.6588, -0.6633,  0.3570],
#         [ 1.0311,  9.9948,  2.4897,  ..., -5.9247, -0.7101,  0.1609],
#         [ 0.0401,  9.9391,  1.4422,  ..., -3.8987, -0.6390,  0.4765],
#         ...,
#         [-0.0338,  9.9285,  1.3673,  ..., -3.7404, -0.6356,  0.5040],
#         [ 0.1586,  9.9531,  1.5645,  ..., -4.1522, -0.6458,  0.4315],
#         [ 0.0494,  9.9404,  1.4523,  ..., -3.9189, -0.6398,  0.4729]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 4500/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.49180 segundos en ejecutarse.
# tensor([[ 0.1838,  9.9558,  1.5923,  ..., -4.2089, -0.6484,  0.4217],
#         [ 0.1927,  9.9566,  1.6001,  ..., -4.2251, -0.6482,  0.4189],
#         [-0.0709,  9.9222,  1.3270,  ..., -3.6546, -0.6328,  0.5184],
#         ...,
#         [-0.1564,  9.9062,  1.2396,  ..., -3.4667, -0.6287,  0.5507],
#         [ 0.7216,  9.9882,  2.1568,  ..., -5.3302, -0.6841,  0.2561],
#         [-0.1420,  9.9088,  1.2527,  ..., -3.4946, -0.6284,  0.5453]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 4600/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.55065 segundos en ejecutarse.
# tensor([[ 0.3631,  9.9713,  1.7795,  ..., -4.5940, -0.6595,  0.3653],
#         [ 0.8130,  9.9908,  2.2571,  ..., -5.5142, -0.6929,  0.2278],
#         [ 0.2564,  9.9626,  1.6664,  ..., -4.3623, -0.6521,  0.3980],
#         ...,
#         [ 0.3342,  9.9691,  1.7488,  ..., -4.5313, -0.6574,  0.3745],
#         [-0.0167,  9.9311,  1.3841,  ..., -3.7757, -0.6362,  0.4978],
#         [ 0.0724,  9.9433,  1.4753,  ..., -3.9674, -0.6407,  0.4645]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 4700/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.50232 segundos en ejecutarse.
# tensor([[ 0.3244,  9.9684,  1.7381,  ..., -4.5096, -0.6565,  0.3774],
#         [ 0.3625,  9.9712,  1.7787,  ..., -4.5925, -0.6593,  0.3657],
#         [ 0.0265,  9.9375,  1.4301,  ..., -3.8724, -0.6393,  0.4814],
#         ...,
#         [ 0.3851,  9.9729,  1.8052,  ..., -4.6459, -0.6621,  0.3588],
#         [ 0.0140,  9.9357,  1.4173,  ..., -3.8457, -0.6387,  0.4861],
#         [ 0.6661,  9.9865,  2.0992,  ..., -5.2217, -0.6806,  0.2730]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 4800/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.50000 segundos en ejecutarse.
# tensor([[ 0.0959,  9.9461,  1.4997,  ..., -4.0179, -0.6422,  0.4554],
#         [ 0.8475,  9.9915,  2.2936,  ..., -5.5798, -0.6953,  0.2176],
#         [ 0.2950,  9.9660,  1.7077,  ..., -4.4471, -0.6549,  0.3861],
#         ...,
#         [ 0.7515,  9.9891,  2.1904,  ..., -5.3917, -0.6875,  0.2471],
#         [ 0.2007,  9.9573,  1.6076,  ..., -4.2410, -0.6484,  0.4161],
#         [ 0.5961,  9.9839,  2.0254,  ..., -5.0803, -0.6757,  0.2946]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 4900/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.52287 segundos en ejecutarse.
# tensor([[ 0.2434,  9.9613,  1.6515,  ..., -4.3317, -0.6508,  0.4023],
#         [ 0.0828,  9.9445,  1.4851,  ..., -3.9881, -0.6409,  0.4606],
#         [ 0.3457,  9.9702,  1.7636,  ..., -4.5620, -0.6596,  0.3702],
#         ...,
#         [ 0.4770,  9.9785,  1.9026,  ..., -4.8407, -0.6688,  0.3303],
#         [-0.0543,  9.9251,  1.3451,  ..., -3.6932, -0.6341,  0.5123],
#         [-0.1890,  9.8991,  1.2051,  ..., -3.3918, -0.6266,  0.5630]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 5000/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.49913 segundos en ejecutarse.
# tensor([[ 0.4455,  9.9766,  1.8670,  ..., -4.7703, -0.6653,  0.3403],
#         [ 0.3396,  9.9695,  1.7528,  ..., -4.5403, -0.6569,  0.3732],
#         [ 0.1441,  9.9516,  1.5497,  ..., -4.1215, -0.6450,  0.4371],
#         ...,
#         [-0.2148,  9.8932,  1.1787,  ..., -3.3339, -0.6253,  0.5726],
#         [ 0.3359,  9.9692,  1.7497,  ..., -4.5337, -0.6570,  0.3740],
#         [ 0.2619,  9.9632,  1.6730,  ..., -4.3752, -0.6528,  0.3960]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 5100/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.65988 segundos en ejecutarse.
# tensor([[ 0.1189,  9.9489,  1.5247,  ..., -4.0696, -0.6441,  0.4464],
#         [ 0.0803,  9.9445,  1.4853,  ..., -3.9881, -0.6421,  0.4611],
#         [ 0.3251,  9.9686,  1.7412,  ..., -4.5163, -0.6577,  0.3766],
#         ...,
#         [ 0.3028,  9.9666,  1.7153,  ..., -4.4629, -0.6551,  0.3841],
#         [ 0.4219,  9.9751,  1.8407,  ..., -4.7180, -0.6630,  0.3478],
#         [ 0.0365,  9.9387,  1.4397,  ..., -3.8926, -0.6395,  0.4775]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 5200/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.47253 segundos en ejecutarse.
# tensor([[ 0.6139,  9.9846,  2.0443,  ..., -5.1169, -0.6770,  0.2893],
#         [-0.0366,  9.9276,  1.3612,  ..., -3.7273, -0.6339,  0.5058],
#         [ 0.0839,  9.9449,  1.4893,  ..., -3.9961, -0.6424,  0.4597],
#         ...,
#         [ 0.0823,  9.9444,  1.4846,  ..., -3.9863, -0.6409,  0.4607],
#         [ 0.1848,  9.9558,  1.5919,  ..., -4.2084, -0.6477,  0.4216],
#         [ 0.5517,  9.9820,  1.9781,  ..., -4.9893, -0.6723,  0.3086]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 5300/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.46757 segundos en ejecutarse.
# tensor([[ 0.4815,  9.9787,  1.9067,  ..., -4.8485, -0.6687,  0.3293],
#         [ 0.6330,  9.9853,  2.0621,  ..., -5.1513, -0.6772,  0.2842],
#         [ 0.3472,  9.9703,  1.7652,  ..., -4.5643, -0.6596,  0.3699],
#         ...,
#         [ 0.5802,  9.9832,  2.0079,  ..., -5.0469, -0.6740,  0.3000],
#         [-0.1235,  9.9127,  1.2730,  ..., -3.5390, -0.6301,  0.5383],
#         [ 0.3989,  9.9738,  1.8179,  ..., -4.6717, -0.6622,  0.3547]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 5400/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.49896 segundos en ejecutarse.
# tensor([[ 0.2726,  9.9641,  1.6836,  ..., -4.3977, -0.6532,  0.3928],
#         [-0.0987,  9.9172,  1.2982,  ..., -3.5932, -0.6312,  0.5290],
#         [ 0.1712,  9.9545,  1.5785,  ..., -4.1810, -0.6472,  0.4267],
#         ...,
#         [ 0.4729,  9.9781,  1.8957,  ..., -4.8270, -0.6671,  0.3322],
#         [-0.1404,  9.9094,  1.2559,  ..., -3.5018, -0.6293,  0.5446],
#         [ 0.1635,  9.9536,  1.5693,  ..., -4.1617, -0.6460,  0.4298]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 5500/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.53654 segundos en ejecutarse.
# tensor([[ 0.1190,  9.9491,  1.5259,  ..., -4.0722, -0.6446,  0.4461],
#         [ 0.0541,  9.9412,  1.4590,  ..., -3.9334, -0.6410,  0.4710],
#         [-0.0839,  9.9201,  1.3149,  ..., -3.6284, -0.6327,  0.5231],
#         ...,
#         [ 0.9420,  9.9934,  2.3973,  ..., -5.7641, -0.7044,  0.1881],
#         [ 0.2894,  9.9656,  1.7017,  ..., -4.4353, -0.6544,  0.3878],
#         [ 0.5370,  9.9814,  1.9637,  ..., -4.9602, -0.6717,  0.3127]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 5600/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.59011 segundos en ejecutarse.
# tensor([[ 0.0840,  9.9446,  1.4865,  ..., -3.9911, -0.6410,  0.4600],
#         [ 0.3039,  9.9667,  1.7152,  ..., -4.4633, -0.6544,  0.3837],
#         [ 0.6323,  9.9853,  2.0636,  ..., -5.1535, -0.6783,  0.2836],
#         ...,
#         [ 0.0248,  9.9370,  1.4265,  ..., -3.8653, -0.6383,  0.4822],
#         [ 0.8315,  9.9912,  2.2763,  ..., -5.5485, -0.6939,  0.2224],
#         [ 0.1167,  9.9486,  1.5215,  ..., -4.0632, -0.6436,  0.4472]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 5700/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.53899 segundos en ejecutarse.
# tensor([[ 0.1442,  9.9516,  1.5496,  ..., -4.1211, -0.6449,  0.4370],
#         [ 0.6458,  9.9859,  2.0809,  ..., -5.1865, -0.6809,  0.2790],
#         [ 0.2863,  9.9653,  1.6981,  ..., -4.4278, -0.6540,  0.3888],
#         ...,
#         [ 0.3132,  9.9675,  1.7271,  ..., -4.4874, -0.6561,  0.3806],
#         [ 0.0677,  9.9427,  1.4709,  ..., -3.9581, -0.6407,  0.4661],
#         [ 0.3093,  9.9671,  1.7201,  ..., -4.4737, -0.6546,  0.3822]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 5800/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.45418 segundos en ejecutarse.
# tensor([[ 0.2935,  9.9660,  1.7071,  ..., -4.4460, -0.6553,  0.3863],
#         [ 0.1615,  9.9536,  1.5691,  ..., -4.1614, -0.6468,  0.4299],
#         [ 0.7447,  9.9890,  2.1858,  ..., -5.3826, -0.6883,  0.2484],
#         ...,
#         [ 0.5269,  9.9808,  1.9514,  ..., -4.9370, -0.6702,  0.3165],
#         [ 0.1079,  9.9474,  1.5108,  ..., -4.0414, -0.6422,  0.4510],
#         [ 0.3761,  9.9722,  1.7931,  ..., -4.6215, -0.6602,  0.3615]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 5900/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.51568 segundos en ejecutarse.
# tensor([[ 0.3764,  9.9723,  1.7943,  ..., -4.6239, -0.6608,  0.3612],
#         [ 0.1782,  9.9551,  1.5849,  ..., -4.1940, -0.6472,  0.4243],
#         [ 0.0948,  9.9460,  1.4985,  ..., -4.0155, -0.6420,  0.4559],
#         ...,
#         [-0.0310,  9.9288,  1.3689,  ..., -3.7436, -0.6353,  0.5033],
#         [ 0.2043,  9.9575,  1.6095,  ..., -4.2448, -0.6479,  0.4151],
#         [ 0.2584,  9.9629,  1.6702,  ..., -4.3701, -0.6531,  0.3969]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 6000/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.47955 segundos en ejecutarse.
# tensor([[-8.4884e-04,  9.9333e+00,  1.3993e+00,  ..., -3.8077e+00,
#          -6.3645e-01,  4.9208e-01],
#         [ 5.2657e-02,  9.9408e+00,  1.4559e+00,  ..., -3.9263e+00,
#          -6.4016e-01,  4.7161e-01],
#         [-8.1032e-02,  9.9206e+00,  1.3181e+00,  ..., -3.6354e+00,
#          -6.3298e-01,  5.2214e-01],
#         ...,
#         [-6.3405e-02,  9.9232e+00,  1.3335e+00,  ..., -3.6682e+00,
#          -6.3242e-01,  5.1570e-01],
#         [ 5.1556e-02,  9.9405e+00,  1.4532e+00,  ..., -3.9213e+00,
#          -6.3936e-01,  4.7229e-01],
#         [ 1.7208e-02,  9.9359e+00,  1.4186e+00,  ..., -3.8483e+00,
#          -6.3784e-01,  4.8499e-01]], device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 6100/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.58028 segundos en ejecutarse.
# tensor([[ 0.7891,  9.9901,  2.2300,  ..., -5.4642, -0.6901,  0.2358],
#         [ 0.2195,  9.9589,  1.6253,  ..., -4.2776, -0.6488,  0.4095],
#         [ 0.3594,  9.9710,  1.7755,  ..., -4.5860, -0.6591,  0.3667],
#         ...,
#         [-0.2530,  9.8839,  1.1385,  ..., -3.2465, -0.6231,  0.5873],
#         [ 0.2656,  9.9634,  1.6749,  ..., -4.3802, -0.6521,  0.3954],
#         [ 0.4086,  9.9743,  1.8256,  ..., -4.6875, -0.6615,  0.3523]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 6200/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.52427 segundos en ejecutarse.
# tensor([[ 0.5865,  9.9835,  2.0143,  ..., -5.0593, -0.6746,  0.2979],
#         [ 0.1517,  9.9523,  1.5566,  ..., -4.1354, -0.6450,  0.4345],
#         [ 0.1614,  9.9534,  1.5672,  ..., -4.1574, -0.6459,  0.4307],
#         ...,
#         [ 0.3890,  9.9731,  1.8073,  ..., -4.6508, -0.6614,  0.3575],
#         [ 0.2918,  9.9659,  1.7057,  ..., -4.4430, -0.6553,  0.3868],
#         [ 0.1585,  9.9532,  1.5653,  ..., -4.1529, -0.6463,  0.4314]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 6300/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.62184 segundos en ejecutarse.
# tensor([[-0.1431,  9.9087,  1.2521,  ..., -3.4932, -0.6287,  0.5456],
#         [ 0.1337,  9.9507,  1.5408,  ..., -4.1030, -0.6454,  0.4406],
#         [ 0.1068,  9.9474,  1.5103,  ..., -4.0402, -0.6424,  0.4513],
#         ...,
#         [ 0.2833,  9.9651,  1.6963,  ..., -4.4240, -0.6545,  0.3897],
#         [-0.0925,  9.9188,  1.3074,  ..., -3.6130, -0.6330,  0.5260],
#         [ 0.1665,  9.9541,  1.5742,  ..., -4.1718, -0.6471,  0.4283]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 6400/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.59946 segundos en ejecutarse.
# tensor([[ 1.2451e-03,  9.9339e+00,  1.4040e+00,  ..., -3.8171e+00,
#          -6.3795e-01,  4.9072e-01],
#         [ 4.1741e-01,  9.9749e+00,  1.8360e+00,  ..., -4.7082e+00,
#          -6.6269e-01,  3.4928e-01],
#         [ 7.6847e-01,  9.9896e+00,  2.2068e+00,  ..., -5.4225e+00,
#          -6.8784e-01,  2.4221e-01],
#         ...,
#         [ 2.0198e-01,  9.9574e+00,  1.6084e+00,  ..., -4.2423e+00,
#          -6.4822e-01,  4.1579e-01],
#         [ 4.7625e-01,  9.9783e+00,  1.8985e+00,  ..., -4.8327e+00,
#          -6.6690e-01,  3.3106e-01],
#         [ 3.7003e-01,  9.9719e+00,  1.7889e+00,  ..., -4.6127e+00,
#          -6.6094e-01,  3.6313e-01]], device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 6500/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.49699 segundos en ejecutarse.
# tensor([[ 6.7000e-01,  9.9866e+00,  2.1040e+00,  ..., -5.2308e+00,
#          -6.8136e-01,  2.7173e-01],
#         [ 1.3173e-01,  9.9503e+00,  1.5377e+00,  ..., -4.0961e+00,
#          -6.4453e-01,  4.4155e-01],
#         [-2.4986e-01,  9.8848e+00,  1.1423e+00,  ..., -3.2552e+00,
#          -6.2370e-01,  5.8576e-01],
#         ...,
#         [-4.0189e-03,  9.9331e+00,  1.3981e+00,  ..., -3.8052e+00,
#          -6.3746e-01,  4.9284e-01],
#         [-3.6734e-02,  9.9281e+00,  1.3644e+00,  ..., -3.7340e+00,
#          -6.3564e-01,  5.0536e-01],
#         [ 6.8165e-02,  9.9429e+00,  1.4724e+00,  ..., -3.9616e+00,
#          -6.4126e-01,  4.6525e-01]], device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 6600/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.45586 segundos en ejecutarse.
# tensor([[ 4.2790e-01,  9.9756e+00,  1.8497e+00,  ..., -4.7353e+00,
#          -6.6479e-01,  3.4531e-01],
#         [ 3.6616e-01,  9.9715e+00,  1.7829e+00,  ..., -4.6013e+00,
#          -6.5970e-01,  3.6514e-01],
#         [ 1.5994e-01,  9.9534e+00,  1.5676e+00,  ..., -4.1586e+00,
#          -6.4666e-01,  4.3058e-01],
#         ...,
#         [ 3.0987e-01,  9.9672e+00,  1.7229e+00,  ..., -4.4785e+00,
#          -6.5561e-01,  3.8196e-01],
#         [ 2.6740e-03,  9.9339e+00,  1.4036e+00,  ..., -3.8174e+00,
#          -6.3702e-01,  4.9059e-01],
#         [ 3.2017e-01,  9.9680e+00,  1.7327e+00,  ..., -4.4989e+00,
#          -6.5581e-01,  3.7893e-01]], device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 6700/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.59100 segundos en ejecutarse.
# tensor([[ 0.0713,  9.9433,  1.4755,  ..., -3.9676, -0.6414,  0.4645],
#         [ 0.2562,  9.9626,  1.6657,  ..., -4.3607, -0.6519,  0.3981],
#         [ 0.2238,  9.9594,  1.6307,  ..., -4.2878, -0.6495,  0.4083],
#         ...,
#         [ 0.3801,  9.9725,  1.7971,  ..., -4.6301, -0.6605,  0.3608],
#         [ 0.5469,  9.9818,  1.9741,  ..., -4.9805, -0.6724,  0.3101],
#         [ 0.3077,  9.9670,  1.7195,  ..., -4.4712, -0.6549,  0.3824]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 6800/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.58061 segundos en ejecutarse.
# tensor([[ 0.4133,  9.9746,  1.8312,  ..., -4.6988, -0.6622,  0.3506],
#         [-0.0347,  9.9281,  1.3644,  ..., -3.7338, -0.6347,  0.5049],
#         [ 0.4141,  9.9746,  1.8315,  ..., -4.6989, -0.6620,  0.3505],
#         ...,
#         [ 0.4250,  9.9754,  1.8449,  ..., -4.7259, -0.6636,  0.3465],
#         [ 0.5746,  9.9830,  2.0024,  ..., -5.0364, -0.6740,  0.3014],
#         [ 0.1693,  9.9543,  1.5766,  ..., -4.1769, -0.6471,  0.4274]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 6900/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 47.51591 segundos en ejecutarse.
# tensor([[-0.2026,  9.8958,  1.1897,  ..., -3.3587, -0.6251,  0.5683],
#         [ 0.3491,  9.9703,  1.7648,  ..., -4.5646, -0.6585,  0.3699],
#         [ 0.3182,  9.9679,  1.7317,  ..., -4.4967, -0.6561,  0.3789],
#         ...,
#         [ 0.4615,  9.9775,  1.8835,  ..., -4.8034, -0.6662,  0.3354],
#         [ 0.2358,  9.9606,  1.6439,  ..., -4.3161, -0.6505,  0.4045],
#         [ 0.3860,  9.9728,  1.8015,  ..., -4.6392, -0.6598,  0.3596]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 7000/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 30.82915 segundos en ejecutarse.
# tensor([[ 0.1815,  9.9554,  1.5877,  ..., -4.1997, -0.6470,  0.4231],
#         [ 0.2426,  9.9613,  1.6512,  ..., -4.3311, -0.6510,  0.4022],
#         [ 0.6122,  9.9845,  2.0423,  ..., -5.1132, -0.6766,  0.2899],
#         ...,
#         [ 0.3460,  9.9701,  1.7618,  ..., -4.5581, -0.6584,  0.3703],
#         [ 0.3460,  9.9700,  1.7608,  ..., -4.5562, -0.6580,  0.3710],
#         [ 0.5653,  9.9825,  1.9907,  ..., -5.0138, -0.6724,  0.3046]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 7100/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 31.87338 segundos en ejecutarse.
# tensor([[ 0.5887,  9.9837,  2.0194,  ..., -5.0684, -0.6760,  0.2962],
#         [ 0.1454,  9.9517,  1.5506,  ..., -4.1237, -0.6448,  0.4366],
#         [ 0.3417,  9.9697,  1.7565,  ..., -4.5478, -0.6578,  0.3721],
#         ...,
#         [ 0.3585,  9.9709,  1.7732,  ..., -4.5819, -0.6584,  0.3673],
#         [ 0.5602,  9.9824,  1.9877,  ..., -5.0076, -0.6731,  0.3057],
#         [ 0.2817,  9.9650,  1.6946,  ..., -4.4205, -0.6544,  0.3901]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 7200/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 30.22731 segundos en ejecutarse.
# tensor([[ 0.4119,  9.9745,  1.8298,  ..., -4.6961, -0.6622,  0.3509],
#         [ 0.0253,  9.9372,  1.4282,  ..., -3.8683, -0.6390,  0.4817],
#         [ 0.5823,  9.9834,  2.0109,  ..., -5.0533, -0.6746,  0.2985],
#         ...,
#         [-0.0687,  9.9229,  1.3316,  ..., -3.6647, -0.6340,  0.5172],
#         [-0.0900,  9.9188,  1.3077,  ..., -3.6127, -0.6317,  0.5258],
#         [-0.1341,  9.9106,  1.2617,  ..., -3.5145, -0.6293,  0.5423]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 7300/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 30.47749 segundos en ejecutarse.
# tensor([[ 0.2630,  9.9632,  1.6729,  ..., -4.3759, -0.6523,  0.3960],
#         [ 0.0423,  9.9396,  1.4455,  ..., -3.9055, -0.6396,  0.4755],
#         [ 0.1489,  9.9520,  1.5540,  ..., -4.1298, -0.6449,  0.4356],
#         ...,
#         [ 0.6592,  9.9863,  2.0922,  ..., -5.2088, -0.6800,  0.2749],
#         [ 0.5054,  9.9797,  1.9272,  ..., -4.8898, -0.6679,  0.3227],
#         [ 0.2626,  9.9632,  1.6725,  ..., -4.3752, -0.6522,  0.3957]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 7400/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 29.81772 segundos en ejecutarse.
# tensor([[ 0.0915,  9.9456,  1.4949,  ..., -4.0081, -0.6418,  0.4571],
#         [ 0.0686,  9.9428,  1.4713,  ..., -3.9595, -0.6405,  0.4656],
#         [ 0.4791,  9.9784,  1.9015,  ..., -4.8387, -0.6672,  0.3305],
#         ...,
#         [ 0.5280,  9.9810,  1.9540,  ..., -4.9422, -0.6711,  0.3155],
#         [ 0.1137,  9.9484,  1.5197,  ..., -4.0602, -0.6440,  0.4482],
#         [ 0.3731,  9.9719,  1.7889,  ..., -4.6136, -0.6595,  0.3629]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 7500/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 29.58246 segundos en ejecutarse.
# tensor([[ 0.1213,  9.9489,  1.5242,  ..., -4.0691, -0.6427,  0.4462],
#         [ 0.3972,  9.9736,  1.8153,  ..., -4.6665, -0.6616,  0.3555],
#         [ 0.3988,  9.9737,  1.8168,  ..., -4.6692, -0.6618,  0.3546],
#         ...,
#         [ 0.3770,  9.9723,  1.7957,  ..., -4.6269, -0.6611,  0.3607],
#         [ 0.7392,  9.9888,  2.1772,  ..., -5.3677, -0.6865,  0.2510],
#         [ 0.6238,  9.9850,  2.0546,  ..., -5.1364, -0.6776,  0.2863]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 7600/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 29.71577 segundos en ejecutarse.
# tensor([[-1.5472e-03,  9.9335e+00,  1.4012e+00,  ..., -3.8120e+00,
#          -6.3780e-01,  4.9185e-01],
#         [ 2.3985e-01,  9.9609e+00,  1.6470e+00,  ..., -4.3222e+00,
#          -6.5014e-01,  4.0353e-01],
#         [ 2.0593e-01,  9.9578e+00,  1.6128e+00,  ..., -4.2514e+00,
#          -6.4864e-01,  4.1422e-01],
#         ...,
#         [ 1.6975e-02,  9.9358e+00,  1.4173e+00,  ..., -3.8456e+00,
#          -6.3716e-01,  4.8553e-01],
#         [-9.9519e-02,  9.9172e+00,  1.2978e+00,  ..., -3.5920e+00,
#          -6.3130e-01,  5.2915e-01],
#         [ 5.9712e-02,  9.9419e+00,  1.4638e+00,  ..., -3.9437e+00,
#          -6.4082e-01,  4.6887e-01]], device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 7700/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 29.65893 segundos en ejecutarse.
# tensor([[ 0.2939,  9.9660,  1.7070,  ..., -4.4456, -0.6551,  0.3865],
#         [ 0.6485,  9.9858,  2.0782,  ..., -5.1819, -0.6781,  0.2792],
#         [ 0.1202,  9.9490,  1.5253,  ..., -4.0708, -0.6439,  0.4460],
#         ...,
#         [-0.0239,  9.9301,  1.3781,  ..., -3.7628, -0.6365,  0.5004],
#         [ 0.1751,  9.9549,  1.5822,  ..., -4.1883, -0.6472,  0.4251],
#         [ 0.2769,  9.9646,  1.6898,  ..., -4.4108, -0.6543,  0.3914]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 7800/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 29.58766 segundos en ejecutarse.
# tensor([[ 0.3954,  9.9736,  1.8163,  ..., -4.6680, -0.6630,  0.3552],
#         [ 0.1571,  9.9529,  1.5627,  ..., -4.1481, -0.6456,  0.4321],
#         [ 0.0942,  9.9459,  1.4972,  ..., -4.0130, -0.6417,  0.4563],
#         ...,
#         [ 0.6303,  9.9852,  2.0605,  ..., -5.1477, -0.6775,  0.2847],
#         [ 0.4735,  9.9783,  1.8980,  ..., -4.8320, -0.6680,  0.3314],
#         [ 0.4151,  9.9747,  1.8328,  ..., -4.7016, -0.6622,  0.3500]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 7900/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 29.67523 segundos en ejecutarse.
# tensor([[ 0.6707,  9.9866,  2.1028,  ..., -5.2282, -0.6805,  0.2727],
#         [ 0.5599,  9.9824,  1.9884,  ..., -5.0084, -0.6737,  0.3057],
#         [-0.0760,  9.9213,  1.3220,  ..., -3.6438, -0.6325,  0.5205],
#         ...,
#         [ 0.0885,  9.9453,  1.4929,  ..., -4.0037, -0.6422,  0.4581],
#         [ 0.0741,  9.9435,  1.4770,  ..., -3.9709, -0.6408,  0.4636],
#         [ 0.7652,  9.9895,  2.2041,  ..., -5.4172, -0.6880,  0.2434]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 8000/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 32.73931 segundos en ejecutarse.
# tensor([[ 0.2362,  9.9606,  1.6435,  ..., -4.3155, -0.6502,  0.4045],
#         [ 0.6068,  9.9843,  2.0367,  ..., -5.1023, -0.6764,  0.2912],
#         [ 0.2135,  9.9587,  1.6239,  ..., -4.2739, -0.6508,  0.4106],
#         ...,
#         [ 0.2691,  9.9640,  1.6825,  ..., -4.3951, -0.6543,  0.3937],
#         [ 0.3278,  9.9686,  1.7411,  ..., -4.5158, -0.6564,  0.3763],
#         [ 0.4340,  9.9759,  1.8532,  ..., -4.7429, -0.6636,  0.3445]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 8100/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 35.31128 segundos en ejecutarse.
# tensor([[ 7.1109e-03,  9.9345e+00,  1.4084e+00,  ..., -3.8264e+00,
#          -6.3731e-01,  4.8918e-01],
#         [-6.1526e-03,  9.9327e+00,  1.3957e+00,  ..., -3.8004e+00,
#          -6.3719e-01,  4.9384e-01],
#         [ 1.9590e-01,  9.9568e+00,  1.6024e+00,  ..., -4.2301e+00,
#          -6.4803e-01,  4.1764e-01],
#         ...,
#         [ 2.1943e-01,  9.9591e+00,  1.6279e+00,  ..., -4.2820e+00,
#          -6.5008e-01,  4.0906e-01],
#         [ 5.3500e-01,  9.9812e+00,  1.9603e+00,  ..., -4.9545e+00,
#          -6.7081e-01,  3.1366e-01],
#         [ 4.5675e-01,  9.9772e+00,  1.8783e+00,  ..., -4.7925e+00,
#          -6.6581e-01,  3.3728e-01]], device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 8200/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 33.62545 segundos en ejecutarse.
# tensor([[ 0.2503,  9.9621,  1.6598,  ..., -4.3491, -0.6517,  0.3997],
#         [ 0.1242,  9.9494,  1.5288,  ..., -4.0783, -0.6437,  0.4445],
#         [ 0.2249,  9.9596,  1.6325,  ..., -4.2922, -0.6498,  0.4075],
#         ...,
#         [ 0.3522,  9.9706,  1.7688,  ..., -4.5727, -0.6592,  0.3685],
#         [ 0.2926,  9.9658,  1.7050,  ..., -4.4424, -0.6547,  0.3868],
#         [ 0.2560,  9.9626,  1.6664,  ..., -4.3622, -0.6523,  0.3981]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 8300/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 29.98301 segundos en ejecutarse.
# tensor([[ 0.1459,  9.9517,  1.5504,  ..., -4.1227, -0.6445,  0.4367],
#         [ 0.1785,  9.9552,  1.5855,  ..., -4.1951, -0.6473,  0.4240],
#         [-0.0284,  9.9296,  1.3748,  ..., -3.7563, -0.6370,  0.5015],
#         ...,
#         [-0.0250,  9.9297,  1.3747,  ..., -3.7561, -0.6353,  0.5010],
#         [ 0.3274,  9.9686,  1.7413,  ..., -4.5166, -0.6568,  0.3763],
#         [ 0.0437,  9.9395,  1.4453,  ..., -3.9047, -0.6390,  0.4752]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 8400/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 29.88398 segundos en ejecutarse.
# tensor([[ 0.1516,  9.9525,  1.5587,  ..., -4.1395, -0.6461,  0.4337],
#         [ 0.3420,  9.9699,  1.7591,  ..., -4.5527, -0.6589,  0.3714],
#         [ 0.0278,  9.9372,  1.4277,  ..., -3.8679, -0.6375,  0.4816],
#         ...,
#         [ 0.0569,  9.9413,  1.4594,  ..., -3.9341, -0.6400,  0.4702],
#         [ 0.3441,  9.9700,  1.7602,  ..., -4.5549, -0.6585,  0.3713],
#         [ 0.0804,  9.9442,  1.4832,  ..., -3.9839, -0.6410,  0.4613]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 8500/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 31.96775 segundos en ejecutarse.
# tensor([[ 0.2539,  9.9622,  1.6616,  ..., -4.3529, -0.6509,  0.3993],
#         [ 0.2245,  9.9596,  1.6329,  ..., -4.2923, -0.6502,  0.4075],
#         [ 0.4458,  9.9767,  1.8678,  ..., -4.7717, -0.6655,  0.3403],
#         ...,
#         [ 0.2037,  9.9575,  1.6098,  ..., -4.2456, -0.6482,  0.4151],
#         [ 0.7602,  9.9894,  2.2003,  ..., -5.4097, -0.6884,  0.2442],
#         [ 0.8081,  9.9906,  2.2503,  ..., -5.5018, -0.6916,  0.2294]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 8600/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 40.89498 segundos en ejecutarse.
# tensor([[ 0.3860,  9.9730,  1.8053,  ..., -4.6463, -0.6618,  0.3582],
#         [-0.2481,  9.8850,  1.1429,  ..., -3.2566, -0.6231,  0.5854],
#         [ 0.4120,  9.9746,  1.8318,  ..., -4.6996, -0.6632,  0.3504],
#         ...,
#         [ 0.3243,  9.9685,  1.7394,  ..., -4.5124, -0.6572,  0.3771],
#         [ 0.3230,  9.9683,  1.7365,  ..., -4.5067, -0.6564,  0.3780],
#         [ 0.3703,  9.9718,  1.7874,  ..., -4.6100, -0.6601,  0.3634]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 8700/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 44.98763 segundos en ejecutarse.
# tensor([[ 0.2492,  9.9620,  1.6589,  ..., -4.3468, -0.6517,  0.4001],
#         [ 0.3480,  9.9702,  1.7643,  ..., -4.5629, -0.6588,  0.3702],
#         [-0.0335,  9.9285,  1.3669,  ..., -3.7390, -0.6354,  0.5040],
#         ...,
#         [ 0.2690,  9.9637,  1.6793,  ..., -4.3889, -0.6527,  0.3941],
#         [-0.0921,  9.9184,  1.3047,  ..., -3.6068, -0.6313,  0.5266],
#         [ 0.2987,  9.9666,  1.7149,  ..., -4.4617, -0.6567,  0.3843]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 8800/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 46.65239 segundos en ejecutarse.
# tensor([[ 0.4193,  9.9750,  1.8383,  ..., -4.7129, -0.6630,  0.3487],
#         [-0.0965,  9.9178,  1.3014,  ..., -3.6000, -0.6317,  0.5282],
#         [ 0.5313,  9.9811,  1.9573,  ..., -4.9487, -0.6708,  0.3140],
#         ...,
#         [ 0.1955,  9.9568,  1.6027,  ..., -4.2306, -0.6484,  0.4177],
#         [ 0.3755,  9.9721,  1.7921,  ..., -4.6201, -0.6601,  0.3618],
#         [-0.0141,  9.9317,  1.3886,  ..., -3.7850, -0.6374,  0.4964]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 8900/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 46.53395 segundos en ejecutarse.
# tensor([[ 0.2345,  9.9604,  1.6418,  ..., -4.3113, -0.6501,  0.4051],
#         [ 0.1920,  9.9564,  1.5979,  ..., -4.2205, -0.6475,  0.4196],
#         [ 0.5967,  9.9840,  2.0271,  ..., -5.0834, -0.6762,  0.2940],
#         ...,
#         [ 0.3852,  9.9728,  1.8028,  ..., -4.6413, -0.6610,  0.3586],
#         [ 0.3771,  9.9724,  1.7962,  ..., -4.6272, -0.6612,  0.3610],
#         [ 0.1686,  9.9542,  1.5750,  ..., -4.1740, -0.6463,  0.4276]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 9000/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 46.48709 segundos en ejecutarse.
# tensor([[-0.1540,  9.9063,  1.2399,  ..., -3.4671, -0.6276,  0.5499],
#         [-0.1664,  9.9039,  1.2279,  ..., -3.4415, -0.6273,  0.5545],
#         [ 0.5128,  9.9802,  1.9373,  ..., -4.9090, -0.6697,  0.3200],
#         ...,
#         [ 0.1630,  9.9535,  1.5681,  ..., -4.1594, -0.6456,  0.4301],
#         [ 0.2317,  9.9601,  1.6382,  ..., -4.3042, -0.6496,  0.4060],
#         [ 0.3312,  9.9690,  1.7469,  ..., -4.5278, -0.6579,  0.3749]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 9100/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 46.51477 segundos en ejecutarse.
# tensor([[-2.1676e-02,  9.9302e+00,  1.3786e+00,  ..., -3.7641e+00,
#          -6.3561e-01,  4.9980e-01],
#         [ 6.1400e-01,  9.9846e+00,  2.0456e+00,  ..., -5.1191e+00,
#          -6.7758e-01,  2.8893e-01],
#         [ 6.2130e-03,  9.9345e+00,  1.4082e+00,  ..., -3.8270e+00,
#          -6.3760e-01,  4.8920e-01],
#         ...,
#         [ 7.8267e-01,  9.9900e+00,  2.2238e+00,  ..., -5.4528e+00,
#          -6.8986e-01,  2.3784e-01],
#         [-7.3187e-02,  9.9218e+00,  1.3252e+00,  ..., -3.6506e+00,
#          -6.3295e-01,  5.1917e-01],
#         [ 1.6947e-01,  9.9542e+00,  1.5750e+00,  ..., -4.1737e+00,
#          -6.4623e-01,  4.2764e-01]], device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 9200/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 46.63431 segundos en ejecutarse.
# tensor([[ 0.0579,  9.9414,  1.4604,  ..., -3.9358, -0.6399,  0.4698],
#         [ 0.0968,  9.9463,  1.5006,  ..., -4.0202, -0.6422,  0.4549],
#         [ 0.0408,  9.9392,  1.4429,  ..., -3.8996, -0.6391,  0.4763],
#         ...,
#         [ 0.0279,  9.9378,  1.4329,  ..., -3.8783, -0.6401,  0.4805],
#         [-0.2093,  9.8943,  1.1831,  ..., -3.3439, -0.6250,  0.5708],
#         [ 0.3027,  9.9667,  1.7155,  ..., -4.4637, -0.6553,  0.3837]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 9300/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 46.65242 segundos en ejecutarse.
# tensor([[ 0.5464,  9.9817,  1.9719,  ..., -4.9769, -0.6715,  0.3102],
#         [ 0.4421,  9.9764,  1.8634,  ..., -4.7634, -0.6650,  0.3415],
#         [ 0.3490,  9.9703,  1.7647,  ..., -4.5638, -0.6584,  0.3701],
#         ...,
#         [-0.0648,  9.9233,  1.3346,  ..., -3.6701, -0.6336,  0.5159],
#         [ 0.1120,  9.9481,  1.5175,  ..., -4.0547, -0.6436,  0.4490],
#         [ 0.2771,  9.9643,  1.6862,  ..., -4.4038, -0.6523,  0.3922]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 9400/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 46.77380 segundos en ejecutarse.
# tensor([[ 0.2578,  9.9626,  1.6662,  ..., -4.3625, -0.6513,  0.3980],
#         [-0.0220,  9.9300,  1.3768,  ..., -3.7603, -0.6350,  0.5001],
#         [ 0.0644,  9.9423,  1.4681,  ..., -3.9518, -0.6409,  0.4671],
#         ...,
#         [ 0.4930,  9.9792,  1.9158,  ..., -4.8668, -0.6680,  0.3263],
#         [ 0.2068,  9.9579,  1.6147,  ..., -4.2550, -0.6492,  0.4139],
#         [ 0.0918,  9.9457,  1.4960,  ..., -4.0102, -0.6422,  0.4568]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 9500/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 46.80313 segundos en ejecutarse.
# tensor([[-4.1367e-02,  9.9271e+00,  1.3579e+00,  ..., -3.7204e+00,
#          -6.3449e-01,  5.0736e-01],
#         [ 1.2111e-01,  9.9491e+00,  1.5260e+00,  ..., -4.0724e+00,
#          -6.4373e-01,  4.4583e-01],
#         [ 7.5467e-04,  9.9336e+00,  1.4019e+00,  ..., -3.8134e+00,
#          -6.3695e-01,  4.9146e-01],
#         ...,
#         [ 4.7918e-01,  9.9784e+00,  1.9015e+00,  ..., -4.8381e+00,
#          -6.6705e-01,  3.3079e-01],
#         [ 4.6902e-01,  9.9780e+00,  1.8931e+00,  ..., -4.8219e+00,
#          -6.6760e-01,  3.3337e-01],
#         [ 2.6162e-01,  9.9630e+00,  1.6702e+00,  ..., -4.3705e+00,
#          -6.5158e-01,  3.9689e-01]], device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 9600/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 46.75708 segundos en ejecutarse.
# tensor([[ 0.4273,  9.9756,  1.8486,  ..., -4.7334, -0.6645,  0.3457],
#         [ 0.2501,  9.9619,  1.6585,  ..., -4.3462, -0.6511,  0.3999],
#         [ 0.7793,  9.9899,  2.2198,  ..., -5.4462, -0.6896,  0.2386],
#         ...,
#         [ 0.1028,  9.9471,  1.5076,  ..., -4.0345, -0.6429,  0.4526],
#         [ 0.2962,  9.9661,  1.7080,  ..., -4.4479, -0.6544,  0.3860],
#         [ 0.1080,  9.9478,  1.5143,  ..., -4.0483, -0.6437,  0.4505]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 9700/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 46.90651 segundos en ejecutarse.
# tensor([[ 0.4936,  9.9793,  1.9189,  ..., -4.8729, -0.6690,  0.3256],
#         [ 0.3410,  9.9697,  1.7556,  ..., -4.5457, -0.6576,  0.3725],
#         [ 0.2058,  9.9578,  1.6127,  ..., -4.2511, -0.6486,  0.4143],
#         ...,
#         [ 0.0174,  9.9360,  1.4191,  ..., -3.8496, -0.6380,  0.4850],
#         [ 0.1487,  9.9520,  1.5535,  ..., -4.1289, -0.6448,  0.4355],
#         [ 0.1442,  9.9517,  1.5508,  ..., -4.1235, -0.6455,  0.4368]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 9800/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 46.86289 segundos en ejecutarse.
# tensor([[ 0.2153,  9.9588,  1.6247,  ..., -4.2758, -0.6504,  0.4101],
#         [ 0.4872,  9.9788,  1.9086,  ..., -4.8528, -0.6668,  0.3285],
#         [ 0.4219,  9.9752,  1.8412,  ..., -4.7188, -0.6633,  0.3477],
#         ...,
#         [ 0.4459,  9.9766,  1.8669,  ..., -4.7700, -0.6651,  0.3403],
#         [ 0.3817,  9.9726,  1.8005,  ..., -4.6361, -0.6615,  0.3598],
#         [-0.0509,  9.9257,  1.3492,  ..., -3.7015, -0.6346,  0.5106]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 9900/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 46.91909 segundos en ejecutarse.
# tensor([[-0.0461,  9.9263,  1.3527,  ..., -3.7096, -0.6341,  0.5091],
#         [-0.1901,  9.8988,  1.2036,  ..., -3.3889, -0.6262,  0.5634],
#         [ 0.4639,  9.9775,  1.8829,  ..., -4.8018, -0.6648,  0.3359],
#         ...,
#         [ 0.3903,  9.9731,  1.8065,  ..., -4.6489, -0.6605,  0.3578],
#         [-0.1333,  9.9109,  1.2636,  ..., -3.5181, -0.6299,  0.5419],
#         [ 0.1024,  9.9469,  1.5061,  ..., -4.0309, -0.6425,  0.4529]],
#        device='cuda:0', grad_fn=<MulBackward0>)
# Epoch 10000/10000 | Disc Loss: 100.0 | Gen Loss: 0.0
# El código tardó 46.87716 segundos en ejecutarse.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns

# Generar datos de expresión sintética
gen2 = Generator(100, expression_data.shape[1]+methylation_data.shape[1]+assign_data.shape[1]).to(device)
gen2.load_state_dict(torch.load('generator_model.pth'))
gen2.eval()
expressions_list = []
for i in range(10000):
    noise = torch.randn(1, 100).to(device)
    synthetic_expression = gen2(noise).to(device)
    #print(synthetic_expression)
    expressions_list.append(synthetic_expression.detach().cpu().numpy().squeeze())

X = pd.DataFrame(expressions_list)
#X = X.apply(pd.to_numeric, errors='coerce')
y = X.iloc[:, -1].values.astype(int)  # Suponiendo que la asignación está en la primera columna

X = X.iloc[:, :-1]
# Dividimos los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Entrenamos el modelo SVC
clf = SVC()
clf.fit(X_train, y_train)

# Predicciones
y_pred = clf.predict(X_test)

# Métricas de clasificación
print(classification_report(y_test, y_pred))

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 30
#      28 # Entrenamos el modelo SVC
#      29 clf = SVC()
# ---> 30 clf.fit(X_train, y_train)
#      32 # Predicciones
#      33 y_pred = clf.predict(X_test)
#
# File ~/PyEnv/PB/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/PyEnv/PB/lib/python3.11/site-packages/sklearn/svm/_base.py:199, in BaseLibSVM.fit(self, X, y, sample_weight)
#     189 else:
#     190     X, y = self._validate_data(
#     191         X,
#     192         y,
#    (...)
#     196         accept_large_sparse=False,
#     197     )
# --> 199 y = self._validate_targets(y)
#     201 sample_weight = np.asarray(
#     202     [] if sample_weight is None else sample_weight, dtype=np.float64
#     203 )
#     204 solver_type = LIBSVM_IMPL.index(self._impl)
#
# File ~/PyEnv/PB/lib/python3.11/site-packages/sklearn/svm/_base.py:747, in BaseSVC._validate_targets(self, y)
#     745 self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#     746 if len(cls) < 2:
# --> 747     raise ValueError(
#     748         "The number of classes has to be greater than one; got %d class"
#     749         % len(cls)
#     750     )
#     752 self.classes_ = cls
#     754 return np.asarray(y, dtype=np.float64, order="C")
#
# ValueError: The number of classes has to be greater than one; got 1 class

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns

# Cargamos los datos
expr_data = pd.read_csv('exprLOW.csv')
meth_data = pd.read_csv('methylLOW.csv')
assig_data = pd.read_csv('assignLOW.csv')
expr_data = expr_data.iloc[:, 1:]
meth_data = meth_data.iloc[:, 1:]
assig_data = assig_data.iloc[:, 2:]

# Convertir todas las columnas a tipo float
expr_data = expr_data.apply(pd.to_numeric, errors='coerce')
meth_data = meth_data.apply(pd.to_numeric, errors='coerce')
assig_data = assig_data.apply(pd.to_numeric, errors='coerce')
# Lidiar con valores NaN (si los hay). Pone 0(CAMBIAR)
expr_data.fillna(0, inplace=True)
meth_data.fillna(0, inplace=True)
assig_data.fillna(0, inplace=True)
# Aseguramos que las dimensiones coincidan
assert expr_data.shape[0] == meth_data.shape[0] == assig_data.shape[0], "Las dimensiones de los archivos no coinciden"

# Combinamos los datos de expresión génica y metilación
X = pd.concat([expr_data, meth_data], axis=1)
y = assig_data.iloc[:, 0].values  # Suponiendo que la asignación está en la primera columna

# Dividimos los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Entrenamos el modelo SVC
clf = SVC()
clf.fit(X_train, y_train)

# Predicciones
y_pred = clf.predict(X_test)

# Métricas de clasificación
print(classification_report(y_test, y_pred))

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      2370
#            2       1.00      1.00      1.00       630
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sns

# Cargamos los datos
expr_data = pd.read_csv('exprMID.csv')
meth_data = pd.read_csv('methylMID.csv')
assig_data = pd.read_csv('assignMID.csv')
expr_data = expr_data.iloc[:, 1:]
meth_data = meth_data.iloc[:, 1:]
assig_data = assig_data.iloc[:, 2:]

# Convertir todas las columnas a tipo float
expr_data = expr_data.apply(pd.to_numeric, errors='coerce')
meth_data = meth_data.apply(pd.to_numeric, errors='coerce')
assig_data = assig_data.apply(pd.to_numeric, errors='coerce')
# Lidiar con valores NaN (si los hay). Pone 0(CAMBIAR)
expr_data.fillna(0, inplace=True)
meth_data.fillna(0, inplace=True)
assig_data.fillna(0, inplace=True)
# Aseguramos que las dimensiones coincidan
assert expr_data.shape[0] == meth_data.shape[0] == assig_data.shape[0], "Las dimensiones de los archivos no coinciden"

# Combinamos los datos de expresión génica y metilación
X = meth_data
y = assig_data.iloc[:, 0].values  # Suponiendo que la asignación está en la primera columna

# Dividimos los datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Entrenamos el modelo SVC
clf = SVC()
clf.fit(X_train, y_train)

# Predicciones
y_pred = clf.predict(X_test)

# Métricas de clasificación
print(classification_report(y_test, y_pred))

# Matriz de confusión
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     23934
#            2       1.00      1.00      1.00      6066
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
